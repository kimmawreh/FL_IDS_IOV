# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install shap -q
# !pip install hydra-core -q
# !pip install fedlab -q
# !pip install lime -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.5 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 37.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.5 MB/s eta 0:00:00
#   Building wheel for fedlab (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 21.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done

# %%
import random
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import copy
import statistics
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import yaml
import os
from fedlab.utils.dataset.partition import  BasicPartitioner
from torch.utils.data import Subset
import matplotlib.pyplot as plt
from collections import OrderedDict
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
import shap
import hydra
from hydra.core.hydra_config import HydraConfig
from omegaconf import DictConfig, OmegaConf
import random
import numpy as np
import torch
# Set seed for Python's random module
random.seed(42)
# Set seed for NumPy
np.random.seed(42)
# Set seed for PyTorch
torch.manual_seed(42)
import numpy as np
import torch
import torch.nn.functional as F
import random
from lime.lime_tabular import LimeTabularExplainer
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import os
# If you are using CUDA, you may also want to set the seed for GPU operations
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)  # For all GPUs if you have multiple

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ANNModel(nn.Module):
    def __init__(self, input_features=8):
        super(ANNModel, self).__init__()

        # Fully connected layers for a simple ANN
        self.fc1 = nn.Linear(input_features, 16)  # First hidden layer with 64 neurons
        self.fc2 = nn.Linear(16, 8)  # Second hidden layer with 32 neurons
        self.fc3 = nn.Linear(8, 1)  # Output layer for binary classification

        # Dropout layer to reduce overfitting
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # Forward pass through fully connected layers with ReLU and dropout
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x


def train(net, trainloader, optimizer, epochs):
    """
    Train a neural network model using a specified optimizer and dataset.

    This function trains the provided network on a training set for a specified number of epochs,
    computing the loss with `BCEWithLogitsLoss`. It also reports the total training time taken.

    Args:
        net (torch.nn.Module): The neural network model to be trained.
        trainloader (torch.utils.data.DataLoader): DataLoader for the training set, which yields input features and labels.
        optimizer (torch.optim.Optimizer): The optimizer to use for updating the network's weights.
        epochs (int): The number of training epochs (iterations over the full dataset).

    Returns:
        float: The total time (in seconds) taken to complete the training process.
    """
    criterion = nn.BCEWithLogitsLoss()
    net.train()

    start_time = time.time()  # Start time for the training

    for _ in range(epochs):
        for features, labels in trainloader:
            optimizer.zero_grad()
            output = net(features)
            loss = criterion(output.squeeze(1), labels.float())
            loss.backward()
            optimizer.step()


        #sleep_time = random.uniform(0, 3)
        time.sleep(1)


    end_time = time.time()  # End time for the training
    total_time = end_time - start_time

    return total_time

def evaluate_model(model, test_loader):
    """
    Evaluate a trained neural network model on a test dataset.

    This function computes the average loss, accuracy, precision, recall, F1 score, and confusion matrix for the model
    on the test set, using `binary_cross_entropy_with_logits` as the loss function. It assumes a binary classification task.

    Args:
        model (torch.nn.Module): The trained neural network model to evaluate.
        test_loader (torch.utils.data.DataLoader): DataLoader for the test set, which yields input features and labels.

    Returns:
        tuple:
            avg_loss (float): The average loss over the test set.
            accuracy (float): The accuracy of the model on the test set.
            precision (float): The precision score of the model.
            recall (float): The recall score of the model.
            f1 (float): The F1 score of the model.
            conf_matrix (numpy.ndarray): Confusion matrix of the model's predictions.
    """
    model.eval()  # Set the model to evaluation mode

    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data, labels
            outputs = model(data)
            outputs = outputs.squeeze(1)
            loss = F.binary_cross_entropy_with_logits(outputs, labels.float())

            total_loss += loss.item() * data.size(0)
            preds = torch.round(torch.sigmoid(outputs))
            total_correct += (preds == labels).sum().item()
            total_samples += data.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    conf_matrix = confusion_matrix(all_labels, all_preds)

    return avg_loss, accuracy, precision, recall, f1, conf_matrix

# %%
import collections
def weighted_aggregation(w, agg_weights):
    """
    Returns the average of the weights.
    """
    w_avg = copy.deepcopy(w[0].state_dict())
    total_agg_weights = sum(agg_weights)

    for key in w_avg.keys():
        w_avg[key] *= (agg_weights[0] / total_agg_weights)
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i].state_dict()[key] * (agg_weights[i] / total_agg_weights)
    return w_avg

import copy
from collections import OrderedDict

def weighted_aggregation(w, agg_weights):
    """
    Returns the weighted average of the weights.

    Parameters:
    w (list): A list of model instances or state dicts.
    agg_weights (list): A list of weights corresponding to each model/state dict.

    Returns:
    OrderedDict: The weighted average of the weights.
    """
    # Check if w is a list of model instances or state dicts
    if hasattr(w[0], 'state_dict'):
        # w is a list of model instances
        w_avg = copy.deepcopy(w[0].state_dict())
    else:
        # w is a list of state dicts (OrderedDict)
        w_avg = copy.deepcopy(w[0])

    total_agg_weights = sum(agg_weights)

    for key in w_avg.keys():
        w_avg[key] *= (agg_weights[0] / total_agg_weights)

    for key in w_avg.keys():
        for i in range(1, len(w)):
            if hasattr(w[i], 'state_dict'):
                # If w[i] is a model instance
                w_avg[key] += w[i].state_dict()[key] * (agg_weights[i] / total_agg_weights)
            else:
                # If w[i] is a state dict
                w_avg[key] += w[i][key] * (agg_weights[i] / total_agg_weights)

    return w_avg

def get_label_distribution(dataloader):
    labels = []
    for _, batch_labels in dataloader:
    # Append the batch of labels to the list
        labels.extend(batch_labels.tolist())
    return labels

def get_data_size(dataloader):
    return len(get_label_distribution(dataloader))

def get_labels_variance(dataloader):
    return statistics.variance(get_label_distribution(dataloader))


def analyze_dataloaders(dataloaders):
    """
    Analyze the data distribution of multiple DataLoader objects across different clients.

    This function calculates the label distribution, variance, and number of samples for each client
    from a list of DataLoader objects, which represent the data split for each client. It prints out
    details such as the set of unique labels, the number of samples, and label counts for each client.

    Args:
        dataloaders (list of torch.utils.data.DataLoader): A list of DataLoader objects, where each DataLoader corresponds to a client's data.
        client_ids (list of int or str): A list of client identifiers, which can be integers or strings, corresponding to each DataLoader.

    Returns:
        tuple:
            - label_distribution_per_client (list of list): A list of label distributions for each client. Each element contains the labels from one client's DataLoader.
            - variance_per_client (list of float): A list of variances in label distribution for each client.
            - num_samples_per_client (list of int): A list of the number of samples in each client's dataset.

    Prints:
        - Client ID and associated label information (unique labels, number of samples, label counts).
    """
    label_distribution_per_client = []
    variance_per_client = []
    num_samples_per_client = []
    j = 0

    for dataloader in dataloaders:
        labels = []

        for _, batch_labels in dataloader:
            # Append the batch of labels to the list
            labels.extend(batch_labels.tolist())

        label_distribution_per_client.append(labels)
        variance_per_client.append(statistics.variance(labels))
        num_samples_per_client.append(len(labels))

        # Count occurrences of each label
        label_counts = collections.Counter(labels)

        print("Label Category in Vehicle", j, ':', set(labels))
        print("Number of Samples in Vehicle", j, ':', num_samples_per_client[j])
        print("Label Counts in Vehicle", j, ':', dict(label_counts))  # Display value counts for each label
        print("*********")

        j += 1



def distribute_clients(trainloaders, num_nodes ,method='equal'):
    trainloaders_node = []
    num_clients = len(trainloaders)
    if method == 'equal':
        step = num_clients // num_nodes
        for i in range(0, num_clients, step):
            if i + step > num_clients:
                trainloaders_node.append(trainloaders_node[i:])
            else:
                trainloaders_node.append(trainloaders[i:i+step])

        return trainloaders_node
    elif method == 'random':
        steps = generate_random_list(num_nodes, num_clients)
        i = 0
        for step in steps:
            if step != 0:
                if i + step > num_clients:
                    trainloaders_node.append(trainloaders[i:])
                else:
                    trainloaders_node.append(trainloaders[i:i+step])
            else:
                trainloaders_node.append([])
            i = step

        return trainloaders_node


## new code for this

import random

import random

def divide_list_randomly(lst, M, min_size=3, max_size=8):
    """
    Divide a list into M random sublists with specified min and max sizes.

    Args:
        lst (list): The list to be divided.
        M (int): The number of sublists to create.
        min_size (int): Minimum number of items in each sublist.
        max_size (int): Maximum number of items in each sublist.

    Returns:
        list: A list of M sublists created from the original list.

    Raises:
        ValueError: If M is greater than the number of elements in the list or
                     if it is impossible to divide the list within the given limits.
    """
    N = len(lst)

    if M > N:
        raise ValueError("M cannot be greater than the number of elements in the list")

    if M * min_size > N or M * max_size < N:
        raise ValueError("Cannot divide the list into M sublists with the given min and max size constraints.")

    # Shuffle the list to ensure random distribution
    random.shuffle(lst)
    sublists = []
    remaining_vehicles = lst[:]

    # Calculate the average number of vehicles per edge server
    avg_size = N // M

    for i in range(M):
        if i == M - 1:
            # Assign the remaining vehicles to the last sublist
            sublist = remaining_vehicles
        else:
            # Choose a random size for this sublist, ensuring min_size <= sublist_size <= max_size
            sublist_size = random.randint(min_size, min(max_size, len(remaining_vehicles) - (M - i - 1) * min_size))
            sublist = remaining_vehicles[:sublist_size]
            remaining_vehicles = remaining_vehicles[sublist_size:]

        sublists.append(sublist)

    print(f"Spread {N} clients across {len(sublists)} edges, with each edge receiving a subset of clients.")
    return sublists

# %%
### Undersampling,Stratified Sampling while splitting and testing
def get_all_labels(dataset):
    all_labels = []

    for _, labels in dataset:
        all_labels.append(labels)
    all_labels_tensor = torch.stack(all_labels)

    return all_labels_tensor

def plot_flag_distribution(df, class_labels=None):
    """
    Plots the distribution of the 'flag' column in the dataset.

    Parameters:
        df (pd.DataFrame): The dataframe containing the 'flag' column.
        class_labels (dict, optional): A dictionary to map flag values to meaningful class names.
                                       Example: {"R": "Normal", "T": "Attack"}.
    """
    sns.countplot(x="label", data=df, palette="viridis", hue="label", legend=False)
    plt.title("Flag Value Counts")
    if class_labels:
        plt.xticks(
            ticks=range(len(class_labels)),
            labels=[class_labels[label] for label in class_labels]
        )
    plt.show()


def preprocess_dataset():
    processed_file = "/content/drive/MyDrive/car_hacking_dataset/Dataset/Car_Hacking_preprocessed_dataset.csv"
    class_labels = {"R": "Normal", "T": "Attack"}

    # Load processed dataset if it exists
    if os.path.isfile(processed_file):
        df = pd.read_csv(processed_file)
        if "flag" in df.columns and "label" not in df.columns:
            df.rename(columns={"flag": "label"}, inplace=True)
        plot_flag_distribution(df, class_labels)
        return df

    # Raw data file paths
    raw_files = {
        "normal": "/content/drive/MyDrive/Normal_data.csv",
        "dos": "/content/drive/MyDrive/DoS_dataset.csv",
        "fuzzy": "/content/drive/MyDrive/Fuzzy_dataset.csv",
        "gear": "/content/drive/MyDrive/gear_dataset.csv",
        "rpm": "/content/drive/MyDrive/RPM_dataset.csv"
    }

    column_names = ["Timestamp", "ID", "DLC", "Byte1", "Byte2", "Byte3", "Byte4", "Byte5", "Byte6", "Byte7", "Byte8", "flag"]
    dataframes = []

    # Load and process raw files
    for key, path in raw_files.items():
        df = pd.read_csv(path, names=column_names, index_col=False) if key != "normal" else pd.read_csv(path, index_col=False)
        if key == "normal":
            df["flag"] = "R"  # Assign flag for normal data
        dataframes.append(df)

    # Combine all datasets
    df = pd.concat(dataframes, axis=0, ignore_index=True)
    print(f"Total data shape before removing missing data: {df.shape}")

    # Drop rows with missing data
    df.dropna(inplace=True)
    print(f"Total data shape after removing missing data: {df.shape}")

    # Convert Hexadecimal Byte columns to Decimal and drop original Byte columns
    byte_columns = [f"Byte{i}" for i in range(1, 9)]
    for i, byte_col in enumerate(byte_columns):
        df[f"DATA_{i}"] = df[byte_col].apply(lambda x: int(str(x), 16))
    df.drop(columns=byte_columns, inplace=True)

    # Drop unnecessary columns
    df.drop(columns=["Timestamp", "ID", "DLC"], inplace=True)

    # Remove duplicate rows
    df.drop_duplicates(inplace=True)
    print(f"Data shape after removing duplicate entries: {df.shape}")

    # Save the processed dataset
    os.makedirs(os.path.dirname(processed_file), exist_ok=True)
    df.to_csv(processed_file, index=False)

    # Visualize and rename flag column
    plot_flag_distribution(df, class_labels)
    if "flag" in df.columns and "label" not in df.columns:
        df.rename(columns={"flag": "label"}, inplace=True)

    return df


def prepare_training_testing_data(dataset, test_size=0.30, output_dir="/content/drive/MyDrive/car_hacking_dataset/Dataset"):
    """
    Prepares and pre-processes the dataset for training and testing.

    This function shuffles the dataset, encodes labels, scales features, and splits the data
    into training and testing sets. It also saves the processed training and testing data into CSV files.

    Args:
        dataset (pd.DataFrame): The input dataset containing features and labels.
        test_size (float, optional): Proportion of the dataset to be used for testing. Defaults to 0.30.
        output_dir (str, optional): Directory where processed files will be saved. Defaults to a specified path.

    Returns:
        tuple:
            X_train_scaled (numpy.ndarray): Scaled feature matrix for the training set.
            X_test_scaled (numpy.ndarray): Scaled feature matrix for the test set.
    """
    # Shuffle the dataset
    dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

    # Encode labels
    label_mapping = {"R": 0, "T": 1}
    dataset['label'] = dataset['label'].map(label_mapping)

    # Split into train and test sets
    train_df, test_df = train_test_split(dataset, test_size=test_size, stratify=dataset['label'], random_state=42)

    # Split features and labels
    X_train, y_train = train_df.drop(columns=['label']), train_df['label']
    X_test, y_test = test_df.drop(columns=['label']), test_df['label']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Prepare scaled datasets for saving
    train_df_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    train_df_scaled['label'] = y_train.values

    test_df_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
    test_df_scaled['label'] = y_test.values

    # Save processed datasets
    os.makedirs(output_dir, exist_ok=True)
    train_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_trainset.csv"), index=False)
    test_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_testset.csv"), index=False)

    return X_train_scaled, X_test_scaled

def get_car_hacking_dataset():
    """
    Loads and prepares the CiCiov dataset for training and testing in PyTorch format.

    This function reads the pre-processed train and test CSV files, converts the data into PyTorch tensors,
    and creates TensorDataset objects for both the training and testing data. It also returns the target labels
    separately for both the train and test sets.

    Args:
        None

    Returns:
        tuple:
            train_tensor (torch.utils.data.TensorDataset): Tensor dataset containing training features and labels.
            test_tensor (torch.utils.data.TensorDataset): Tensor dataset containing test features and labels.
            train_target (torch.Tensor): Tensor containing training labels.
            test_target (torch.Tensor): Tensor containing test labels.
    """
    train = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_trainset.csv')
    test = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_testset.csv')
    train_target = torch.tensor(train['label'].values.astype(np.float32))
    train = torch.tensor(train.drop('label', axis = 1).values.astype(np.float32))
    train_tensor = TensorDataset(train, train_target)

    test_target = torch.tensor(test['label'].values.astype(np.float32))
    test = torch.tensor(test.drop('label', axis = 1).values.astype(np.float32))
    test_tensor = TensorDataset(test, test_target)

    return train_tensor , test_tensor ,train_target,test_target

def get_plot_label_distribution(train, test):
    train_0, train_1 = train['label'].value_counts()[0] / len(train.index), train['label'].value_counts()[1] / len(train.index)
    test_0, test_1 = test['label'].value_counts()[0] / len(test.index), test['label'].value_counts()[1] / len(test.index)
    print("In Train: there are {} % of class 0 and {} % of class 1".format(train_0, train_1))
    print("In Test: there are {} % of class 0 and {} % of class 1".format(test_0, test_1))
    # Plotting target label distribution
    plt.figure()
    plt.title("class distribution of train and test dataset")
    train['label'].value_counts().plot(kind="bar", color='b', label="train")
    test['label'].value_counts().plot(kind="bar", color='orange', label="test")
    plt.xlabel("Class")
    plt.ylabel("Count")
    plt.legend()
    plt.show()

def split_dataset(train_set, test_set ,num_clients, batch_size ,partition, dir_alpha=None ,major_classes_num=0):
    """
    Split the dataset into multiple clients for federated learning.

    Args:
        train_set (Dataset): The training dataset to be partitioned.
        test_set (Dataset): The testing dataset.
        num_clients (int): The number of clients to split the data among.
        batch_size (int): The batch size for the data loaders.
        partition (str): The type of partitioning ('iid' for independent and identically distributed).
        dir_alpha (float, optional): Dirichlet parameter for non-iid partitioning.
        major_classes_num (int, optional): Number of major classes for partitioning.

    Returns:
        list: A list of DataLoaders for the training sets of each client.
        DataLoader: A DataLoader for the test set.
    """
    partitioner = BasicPartitioner(get_all_labels(train_set) ,num_clients, partition=partition, dir_alpha=dir_alpha ,major_classes_num= major_classes_num, seed=2023)
    trainloaders =[]

    for client in range(num_clients):
        idx = partitioner.client_dict[client]
        trainset_ = Subset(train_set, idx)

        trainloaders.append(
            DataLoader(trainset_, batch_size=batch_size, shuffle=True)
        )


    testloader = DataLoader(test_set, batch_size=batch_size)
    # Create a DataLoader for the Training data to get trainig loss
    raw_train_loader = DataLoader(train_set, batch_size=batch_size)
    return raw_train_loader ,trainloaders, testloader

# %%
class EdgeServer():
    def __init__(self, vehicles, config,id):
        self.vehicles = vehicles
        self.local_model_storage = []
        self.agg_weight = []
        self.model = ANNModel()
        self.config = config
        self.id=id
        self.training_queue=[]

    def semi_async_with_model_version(self, cloud_server, threshold):
        """
        Trains vehicles asynchronously while considering their model versions.
        Vehicles that have a version greater than the specified threshold will synchronize
        their parameters with the cloud server instead of training.

        Args:
            cloud_server (CloudServer): The cloud server instance to sync with.
            threshold (int): The version threshold for vehicles to determine training or synchronization.

        Returns:
            list: A list containing the training times for each vehicle.
        """

        def train_vehicle(vehicle, edge_server, cloud_server):
            vehicle.set_parameters(self.model.state_dict().values())
            vehicle_time=0
            if vehicle.version>threshold:
                vehicle.set_parameters(cloud_server.get_parameters())
                print(f"Vehicle {vehicle.id} has version {vehicle.version}, which is greater than the threshold of {threshold}. Synchronizing model parameters.")
            else:
                w_vehicle, data_size_vehicle, vehicle_time,vehicle_version = vehicle.fit(self.config)
                print(f"vehicle {vehicle.id} from Edge Server {self.id}: trained sucessfully : Training time={vehicle_time}, version={vehicle.version}")
                edge_server.training_queue.append(vehicle)
                edge_server.local_model_storage = []
                edge_server.agg_weight = []
                edge_server.local_model_storage.append(w_vehicle)
                edge_server.agg_weight.append(data_size_vehicle)
                edge_server.aggregate_local_models()
                print(f"Edge Server {self.id}: Aggregating model from Vehicle {vehicle.id}.")
                cloud_server.update_global_model()
                cloud_server.update_edge_servers()
                # After training, update all vehicles with the latest edge server model
                edge_server.update_training_queue_vehicles()
                print(f"[Cloud Server: Global model updated after aggregation from Edge Server-{self.id}. after training vehicle-{vehicle.id}")
            return vehicle_time

        args = [(vehicle, self, cloud_server) for vehicle in self.vehicles]

        with concurrent.futures.ThreadPoolExecutor() as executor:
            results = list(executor.map(lambda p: train_vehicle(*p), args))

        return results

    def set_parameters(self ,parameters):
        """Receive parameters and apply them to the local model."""
        params_dict = zip(self.model.state_dict().keys(), parameters)

        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})

        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""

        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def aggregate_local_models(self):
        parameters = weighted_aggregation(self.local_model_storage, self.agg_weight)
        self.set_parameters(parameters.values())

    def update_training_queue_vehicles(self):
        for vehicle in self.training_queue:
            vehicle.set_parameters(self.get_parameters())
        self.training_queue.clear()

    def update_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.set_parameters(self.get_parameters())

# %%
class CloudServer():
    def __init__(self, edge_servers):
        self.edge_servers = edge_servers
        self.model = ANNModel()
        self.current_version = 0  # Initialize cloud model version

    def update_global_model(self):
        """Aggregate models from edge servers and update the global model."""
        sub_global_models = []
        agg_weights = []
        for edge_server in self.edge_servers:
            sub_global_models.append(edge_server.model)
            agg_weights.append(1)

        # Perform weighted aggregation of models
        aggregated_model = weighted_aggregation(sub_global_models, agg_weights)

        # Update global model parameters with the aggregated result
        self.set_parameters(aggregated_model.values())

    def update_edge_servers(self):
        """Update edge servers with the latest global model parameters."""
        for edge_server in self.edge_servers:
            edge_server.set_parameters(self.get_parameters())

    def set_parameters(self ,parameters):
        """Receive parameters and apply them to the local model."""
        params_dict = zip(self.model.state_dict().keys(), parameters)

        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})

        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""

        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

# %%
def spawn_edge_servers(vehicles, num_edges, config, parameters):
    """
    Spawns a specified number of edge servers, each assigned a subset of vehicles.

    Args:
        vehicles (list): List of vehicle instances to be managed by edge servers.
        num_edges (int): Number of edge servers to spawn.
        config (dict): Configuration parameters for the edge servers.
        parameters (dict): Parameters to set for the edge servers' models.

    Returns:
        tuple: A tuple containing:
            - edge_servers (list): List of spawned EdgeServer instances.
            - edge_server_vehicle_map (dict): Mapping of edge server IDs to their respective vehicle IDs.
    """
    edge_server_vehicle_map = {}

    edge_servers = []  # List to store edge server instances
    # Divide the vehicles randomly among the edge servers
    vehicles_per_edge = divide_list_randomly(vehicles, num_edges)
    for i in range(num_edges):
        # Create an EdgeServer instance for each edge server
        edge = EdgeServer(vehicles_per_edge[i], config, f"edge-{i}")
        edge.set_parameters(parameters)  # Set the model parameters for the edge server
        edge_servers.append(edge)  # Add the edge server to the list

        # Get IDs of vehicles assigned to the current edge server
        vehicle_ids = [vehicle.id for vehicle in vehicles_per_edge[i]]
        # Map the edge server ID to its corresponding vehicle IDs
        edge_server_vehicle_map[f"edge-{i}"] = vehicle_ids
    print(f"[spawn_edge_servers] Vehicle mapping to edge servers: {edge_server_vehicle_map}")
    return edge_servers, edge_server_vehicle_map

# %%
def launch_training_periodic_sync_version_control(edge, cloud_server, threshold):
    times = edge.semi_async_with_model_version(cloud_server, threshold)
    return times

def periodic_synchronization_version_control(edge_servers, cloud_server, threshold):
        # Using ProcessPoolExecutor for CPU-bound tasks
    args = [(edge_server, cloud_server, threshold) for edge_server in edge_servers]
    with concurrent.futures.ThreadPoolExecutor() as executor:
            # Use executor.map to pass multiple arguments
        results = list(executor.map(lambda p: launch_training_periodic_sync_version_control(*p), args))

    return max(results)

# %%
class Vehicle():
    """Define a Vehicle Client."""

    def __init__(self, trainloader,id) -> None:
        # the dataloaders that point to the data associated to this client
        self.trainloader = trainloader

        # a model that is randomly initialised at first
        self.model = ANNModel()
        self.id=id
        self.version = 0  # Initialize model version
        print(f"[Vehicle Init] Initialized vehicle client with ID: {self.id}.")

    def set_parameters(self, parameters):
        """Receive parameters and apply them to the local model."""
        params_dict = zip(self.model.state_dict().keys(), parameters)

        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})

        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""

        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def fit(self, config):
        """Train the model received by the server (parameters) using the data
        that belongs to this client. Then, send it back to the server.
        """
        lr = config["lr"]
        momentum = config["momentum"]
        epochs = config["local_epochs"]

        optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=momentum, weight_decay=0.01)


        # Directly await the asynchronous train function
        vehicle_time = train(self.model, self.trainloader, optim, epochs)

        # Increment the version number after training
        self.version += 1

        return self.model.state_dict(), len(self.trainloader), vehicle_time, self.version

    def get_current_version(self):
        """Return the current version of the global model."""
        return self.version
    def reset_version(self):
        self.version = 0

def generate_clients(trainloaders, model):
    """
    Generate client instances from the provided training loaders.

    Args:
        trainloaders (list): A list of DataLoaders for each client's training data.
        model (torch.nn.Module): The model instance to be set for each client.

    Returns:
        list: A list of client instances created from the training loaders.
        list: A list of client IDs corresponding to each created client.
    """
    print(f"Generating clients from {len(trainloaders)} trainloaders...")
    clients = []       # Initialize a list to store client instances
    client_ids = []    # Initialize a list to store client IDs

    # Iterate through the training loaders to create client instances
    for i, trainloader in enumerate(trainloaders):
        cc = Vehicle(trainloader, id=i)  # Create a client instance with the trainloader and a unique ID
        cc.set_parameters(model)           # Set the model parameters for the client
        clients.append(cc)                 # Add the client instance to the list
        client_ids.append(cc.id)           # Store the client ID for reference

    print(f"[generate_clients] Total clients generated: {len(clients)}.\n")
    return clients  # Return both the list of clients and their corresponding IDs

# %%
import matplotlib.pyplot as plt
import shap

def shap_method(model, method_name, x_train, x_test):
    """
    Generates SHAP (SHapley Additive exPlanations) summary plot for a given model and saves the results.

    This function computes SHAP values for a given trained model and test data using the DeepExplainer,
    creates a summary plot for feature importance, and saves the plot to a specified directory.

    Args:
        model (torch.nn.Module): The trained PyTorch model to be explained.
        method_name (str): The name of the method, used for naming and organizing output files.
        x_train (torch.Tensor): The training data tensor, used by the SHAP explainer to compute expected outputs.
        x_test (torch.Tensor): The test data tensor, used to compute SHAP values and generate the summary plot.

    Returns:
        None: The function saves the SHAP summary plot to the specified directory and prints the path to the saved plot.

    Side Effects:
        - Saves a SHAP summary plot as a PNG image in the specified directory.
        - Displays the SHAP plot inline (if running in an environment that supports plotting).
    """
    # Create the directory for saving SHAP results
    path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/shap_results"
    os.makedirs(path, exist_ok=True)

    model.eval()
    explainer = shap.DeepExplainer(model, x_train)

    # Calculate SHAP values
    shap_values = explainer.shap_values(x_test, check_additivity=False)

    # Reshape SHAP values if needed
    shap_values_reshaped = shap_values.squeeze()

    # Summary plot
    shap.summary_plot(shap_values_reshaped, x_test.numpy(), show=False)

    # Save the summary plot in the specified path
    plt.savefig(os.path.join(path, f'shap_summary_{method_name}.png'), bbox_inches='tight')

    # Show the summary plot
    plt.show()  # This will display the plot in the output

    plt.close()  # Close the plot to free memory

    print(f'SHAP summary plot saved as {os.path.join(path, f"shap_summary_{method_name}.png")}')

# %%
# Function to generate LIME explanation
def generate_lime_explanation(x_train_tensor, x_test_tensor, model, method_name, random_instance=True, instance_index=None):
    """
    Generate LIME explanations for a model and save the plot.

    Parameters:
    - x_train_tensor: Training data as a PyTorch tensor
    - x_test_tensor: Test data as a PyTorch tensor
    - model: The PyTorch model to explain
    - method_name: The name of the LIME method for labeling
    - random_instance: Whether to select a random instance from the test set
    - instance_index: Specific index of the instance to explain (optional)
    """

    # Create the directory for saving LIME results
    save_path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/lime_results"
    os.makedirs(save_path, exist_ok=True)

    # Convert tensors to NumPy arrays
    x_train_np = x_train_tensor.numpy()
    x_test_np = x_test_tensor.numpy()

    # Get feature names (assuming 8 features)
    num_features = x_train_np.shape[1]
    #features = [f"Feature {i+1}" for i in range(num_features)]
    features=["DATA_0",	"DATA_1",	"DATA_2",	"DATA_3",	"DATA_4",	"DATA_5",	"DATA_6",	"DATA_7"]
    # Ensure the model is in evaluation mode
    model.eval()

    # Randomly select an instance from the test dataset, or use a specific index if provided
    if random_instance:
        instance_index = random.randint(0, len(x_test_np) - 1)
    instance_index=153709
    selected_instance = x_test_np[instance_index]

    # Create a DataFrame for easier readability
    feature_values = pd.DataFrame(
        {"Feature": features, "Value": selected_instance}
    )
    print(f"Feature values for instance index {instance_index}:\n {feature_values}")
    # Create a LIME explainer for tabular data
    explainer = LimeTabularExplainer(x_train_np, feature_names=features, class_names=['Normal', 'Attack'],
                                     discretize_continuous=True)

    # Modified cnn_predict function to return probabilities for binary classification
    def cnn_predict(input_data):
        """
        Modified cnn_predict function to return probabilities for binary classification.

        Args:
        input_data (list of NumPy arrays): Input data to make predictions on.

        Returns:
        probabilities (NumPy array): Predicted probabilities for the positive class.
        """

        # Convert the input_data (list of NumPy arrays) to a single NumPy array before creating the tensor
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)

        # Ensure the model is in evaluation mode
        model.eval()

        with torch.no_grad():
            output = model(input_tensor)

            # Check for NaN or infinity values in the output
            if torch.isnan(output).any() or torch.isinf(output).any():
                raise ValueError("Model output contains NaN or infinity values.")

            # Apply sigmoid to get probabilities
            probabilities = torch.sigmoid(output).numpy()

        # Convert to 2-class probabilities (positive class and negative class)
        probabilities = np.hstack([1 - probabilities, probabilities])

        # Check for constant predictions
        if np.all(probabilities == probabilities[0]):
            print("Warning: Model returned constant predictions.")

        return probabilities

    # Generate LIME explanation for the selected instance with more samples (increased to 10000)
    explanation = explainer.explain_instance(selected_instance, cnn_predict, num_features=num_features, num_samples=10000)

    # Save the plot
    plot_path = f"{save_path}lime_explanation_{method_name}.png"
    explanation.as_pyplot_figure()
    #plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})-{method_name}-Global Model")
    plt.savefig(plot_path, bbox_inches='tight')
    plt.show()  # This will display the plot in the output
    plt.close()
    print(f"LIME explanation plot saved to {plot_path}")

    return explanation, selected_instance, instance_index

# Function to calculate local fidelity (R² score)
def evaluate_local_fidelity(explanation, model, selected_instance):
    # Get LIME's surrogate predictions
    lime_surrogate_predictions = explanation.local_pred

    # Get CNN model's predictions for the selected instance
    def cnn_predict(input_data):
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)
        with torch.no_grad():
            output = torch.sigmoid(model(input_tensor)).numpy()
        return output

    cnn_predictions = cnn_predict([selected_instance])[0]

    # Check for constant predictions
    if np.all(cnn_predictions == cnn_predictions[0]):
        print("Warning: Model returned constant predictions. R² score cannot be calculated.")
        return np.nan

    # Calculate R² score to measure local fidelity
    local_fidelity = r2_score(cnn_predictions, lime_surrogate_predictions)

    return local_fidelity

# Function to plot feature importance
def plot_feature_importance(explanation, instance_index):
    # Plot the feature importance from LIME
    explanation.as_pyplot_figure()
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.show()
import seaborn as sns
def plot_confusion_matrix(cm, title='Confusion Matrix', class_labels=['Class 0', 'Class 1'], figsize=(8, 6)):
    """
    Plots a confusion matrix using seaborn heatmap.

    Args:
    cm (numpy.ndarray): Confusion matrix (2x2) array.
    title (str): Title of the plot.
    class_labels (list): Custom labels for the classes.
    figsize (tuple): Size of the figure.

    Returns:
    None
    """
    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16}, linewidths=0.5)

    # Add labels, title, and axes
    plt.xlabel('Target (Actual Class)', fontsize=12)
    plt.ylabel('Output (Predicted Class)', fontsize=12)
    plt.title(title, fontsize=14)

    # Custom tick labels for the classes
    plt.xticks([0.5, 1.5], class_labels, rotation=0)
    plt.yticks([0.5, 1.5], class_labels, rotation=0)

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
import torch
import yaml

# Function to save the model with a specified name format
def save_model(model, round_num, method_name, file_path="model_checkpoint"):
    path=f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/{method_name}"
    os.makedirs(path, exist_ok=True)
    model_name = f"{path}/model_{method_name}_round_{round_num}.pth"
    torch.save(model.state_dict(), model_name)
    print(f"Model saved as {model_name}")

# Main Federated Learning (FL) training function
import pandas as pd
import os
import time
import collections
# Main Federated Learning (FL) training function
def run_fl_training(cfg, cloud_server, edge_servers,train_loader,  testloader, X_train_tensor, X_test_tensor,method_name,threshold, save_path="model_checkpoint"):
    # Initialize variables to store round results
    fl_time = []
    round_results = []
    train_losses = []  # Track training loss for each round
    test_losses = []   # Track testing loss for each round
    # Create the results folder if it doesn't exist
    results_path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/results"
    os.makedirs(results_path, exist_ok=True)
    r_sync=threshold
    # Record the start time
    start_time = time.time()
    total_time=0
    for round_num in range(1,cfg['num_rounds']+1):
        print(f'\n  FL Global Training Round SAFL2 - Validation: {round_num} \n')
        round_start_time = time.time()  # Start time for this round

        edge_times = periodic_synchronization_version_control(edge_servers, cloud_server, threshold)
        # Calculate the total time for this round
        total_round_time = time.time() - round_start_time  # Calculate round time
        fl_time.append(total_round_time)  # Store round time
        total_time += total_round_time ## Total time

        # Evaluating model performance
        loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
        print(f'Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 score = {f1}, Total Time for round {round_num }= {total_round_time:.2f} seconds')
        train_loss, _, _, _, _, _ = evaluate_model(cloud_server.model,train_loader)
        train_losses.append(train_loss)
        test_losses.append(loss)
        # Save the model after each round
        save_model(cloud_server.model, round_num , method_name, file_path=save_path)
        print(f"{200 * '*'}")

        # Append results to the round_results list
        round_results.append({
            "Round": round_num,
            "Loss": loss,
            "Accuracy": accuracy,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "edge nodes Time for each round": edge_times,
            "Train_Loss":train_loss,
            "Test_loss":loss
        })

    ## 8. Test After Final FL Round
    loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
    print(f'Final model results: loss = {loss}, accuracy = {accuracy}, precision = {precision}, recall = {recall}, F1 = {f1} \n confusion matrix: {conf_matrix}')

    # Collecting round results
    round_results.append({
        "Round": round_num,
        "Loss": loss,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "Total Round Time": total_round_time,  # Store the time taken for this round
    })

    print(f"{200 * '*'}")
    print(f"\nTotal training time for all rounds: {total_time:.2f} seconds\n")
    # Final model evaluation
    # Measure testing time
    start_time = time.time()
    loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
    end_time = time.time()

    testing_time = end_time - start_time

    print(f'Final model results: Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 = {f1}')
    print(f'Confusion Matrix:\n{conf_matrix}')
    print(f'Testing Time: {testing_time:.2f} seconds')
    # Appending the final round results
    round_results.append({
        "Round": "Final",
        "Loss": loss,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "FL Time": fl_time,  # Include all round times
        "Confusion Matrix": conf_matrix,
    })

    # Saving the final model
    save_model(cloud_server.model, cfg['num_rounds'], method_name, file_path=save_path)

    # Append total time to the round results
    round_results.append({
        "Round": "Total Time",
        "FL Time": total_time,
        "Round Times": fl_time,  # Optional: store each round time
        "Testing Time": testing_time })

    # Save results to CSV
    df_results = pd.DataFrame(round_results)
    df_results.to_csv(os.path.join(results_path, f"{method_name}_results.csv"), index=False)
    print(f"Training results saved to {results_path}/{method_name}_results.csv")
    plot_confusion_matrix(conf_matrix)
    ## Generate Lime explanation
    lime_start_time = time.time()
    explanation, selected_instance, instance_index = generate_lime_explanation(X_train_tensor, X_test_tensor, cloud_server.model, method_name)
    lime_end_time = time.time()

    lime_time = lime_end_time - lime_start_time
    print(f"Total time taken for Lime Explanation: {lime_time:.2f} seconds")

    # Running SHAP analysis
    shap_start_time = time.time()
    shap_method(cloud_server.model, method_name, X_train_tensor[:100], X_test_tensor)
    shap_end_time = time.time()
    shap_time = shap_end_time - shap_start_time
    print(f"Total time taken for Shap Explanation: {shap_time:.2f} seconds")

    return df_results
# Main function to run the Federated Learning process
def main():
    ## 1. Parse config & get configs
    with open('/content/drive/MyDrive/base-scalability.yaml', 'r') as file:
        cfg = yaml.safe_load(file)

    df = preprocess_dataset()
    ## 2. Prepare the dataset
    # Pre-process the dataset by splitting it into training and testing sets
    # The parameter test_size=0.3 indicates that 30% of the data will be used for testing
    x_train, x_test = prepare_training_testing_data(df,test_size=0.3)
    # Convert the training data (x_train) into a PyTorch tensor of type float32
    X_train_tensor = torch.tensor(x_train, dtype=torch.float32)

    # Convert the testing data (x_test) into a PyTorch tensor of type float32
    X_test_tensor = torch.tensor(x_test, dtype=torch.float32)

    # Load the dataset for a specific application (CICIDS dataset)
    # The function returns training and testing datasets, as well as their corresponding targets
    trainset, testset, train_target, test_target = get_car_hacking_dataset()
    print(" Label distribution in the Training data",np.unique(train_target, return_counts=True))
    print(" Label distribution in the Test data",np.unique(test_target, return_counts=True))
    raw_train_loader,trainloaders, testloader = split_dataset(trainset, testset, cfg['num_clients'], cfg['config_fit']['batch_size'], partition='noniid-labeldir', dir_alpha=1)

    analyze_dataloaders(trainloaders)

    ## 3. Define the clients and the model
    init_global_model = ANNModel()
    vehicles = generate_clients(trainloaders, init_global_model.state_dict().values())

    ## 4. Define the edge servers and the cloud server
    edge_servers,edge_server_vehicle_map = spawn_edge_servers(vehicles, cfg['num_edges'], cfg['config_fit'], init_global_model.state_dict().values())
    cloud_server = CloudServer(edge_servers)
    # Synchronization Period r_sync
    threshold=r_sync=3
    ## 6. Run the FL simulation based on user input
    results=run_fl_training(cfg, cloud_server, edge_servers,raw_train_loader, testloader, X_train_tensor, X_test_tensor, method_name="SAFL2",threshold=threshold, save_path="model_checkpoint")

if __name__ == "__main__":
    results = main()
# Out:
#  Label distribution in the Training data (array([0., 1.], dtype=float32), array([318065, 344295]))
#  Label distribution in the Test data (array([0., 1.], dtype=float32), array([136314, 147555]))
# Label Category in Vehicle 0 : {0.0, 1.0}
# Number of Samples in Vehicle 0 : 1204
# Label Counts in Vehicle 0 : {1.0: 632, 0.0: 572}
# *********
# Label Category in Vehicle 1 : {0.0, 1.0}
# Number of Samples in Vehicle 1 : 14567
# Label Counts in Vehicle 1 : {0.0: 10452, 1.0: 4115}
# *********
# Label Category in Vehicle 2 : {0.0}
# Number of Samples in Vehicle 2 : 11158
# Label Counts in Vehicle 2 : {0.0: 11158}
# *********
# Label Category in Vehicle 3 : {0.0, 1.0}
# Number of Samples in Vehicle 3 : 12601
# Label Counts in Vehicle 3 : {1.0: 8523, 0.0: 4078}
# *********
# Label Category in Vehicle 4 : {0.0, 1.0}
# Number of Samples in Vehicle 4 : 8783
# Label Counts in Vehicle 4 : {1.0: 5899, 0.0: 2884}
# *********
# Label Category in Vehicle 5 : {0.0}
# Number of Samples in Vehicle 5 : 20376
# Label Counts in Vehicle 5 : {0.0: 20376}
# *********
# Label Category in Vehicle 6 : {0.0, 1.0}
# Number of Samples in Vehicle 6 : 12299
# Label Counts in Vehicle 6 : {0.0: 5211, 1.0: 7088}
# *********
# Label Category in Vehicle 7 : {0.0}
# Number of Samples in Vehicle 7 : 14659
# Label Counts in Vehicle 7 : {0.0: 14659}
# *********
# Label Category in Vehicle 8 : {0.0, 1.0}
# Number of Samples in Vehicle 8 : 9399
# Label Counts in Vehicle 8 : {1.0: 5079, 0.0: 4320}
# *********
# Label Category in Vehicle 9 : {0.0, 1.0}
# Number of Samples in Vehicle 9 : 3292
# Label Counts in Vehicle 9 : {0.0: 2255, 1.0: 1037}
# *********
# Label Category in Vehicle 10 : {0.0}
# Number of Samples in Vehicle 10 : 14235
# Label Counts in Vehicle 10 : {0.0: 14235}
# *********
# Label Category in Vehicle 11 : {0.0, 1.0}
# Number of Samples in Vehicle 11 : 9069
# Label Counts in Vehicle 11 : {0.0: 6608, 1.0: 2461}
# *********
# Label Category in Vehicle 12 : {0.0, 1.0}
# Number of Samples in Vehicle 12 : 3842
# Label Counts in Vehicle 12 : {1.0: 1361, 0.0: 2481}
# *********
# Label Category in Vehicle 13 : {0.0, 1.0}
# Number of Samples in Vehicle 13 : 5800
# Label Counts in Vehicle 13 : {0.0: 4358, 1.0: 1442}
# *********
# Label Category in Vehicle 14 : {0.0, 1.0}
# Number of Samples in Vehicle 14 : 9334
# Label Counts in Vehicle 14 : {0.0: 6334, 1.0: 3000}
# *********
# Label Category in Vehicle 15 : {0.0, 1.0}
# Number of Samples in Vehicle 15 : 1857
# Label Counts in Vehicle 15 : {0.0: 1722, 1.0: 135}
# *********
# Label Category in Vehicle 16 : {0.0}
# Number of Samples in Vehicle 16 : 11260
# Label Counts in Vehicle 16 : {0.0: 11260}
# *********
# Label Category in Vehicle 17 : {0.0, 1.0}
# Number of Samples in Vehicle 17 : 7548
# Label Counts in Vehicle 17 : {0.0: 6919, 1.0: 629}
# *********
# Label Category in Vehicle 18 : {0.0, 1.0}
# Number of Samples in Vehicle 18 : 38873
# Label Counts in Vehicle 18 : {0.0: 7167, 1.0: 31706}
# *********
# Label Category in Vehicle 19 : {0.0, 1.0}
# Number of Samples in Vehicle 19 : 24045
# Label Counts in Vehicle 19 : {1.0: 21203, 0.0: 2842}
# *********
# Label Category in Vehicle 20 : {0.0, 1.0}
# Number of Samples in Vehicle 20 : 45844
# Label Counts in Vehicle 20 : {1.0: 44424, 0.0: 1420}
# *********
# Label Category in Vehicle 21 : {0.0, 1.0}
# Number of Samples in Vehicle 21 : 18207
# Label Counts in Vehicle 21 : {0.0: 4332, 1.0: 13875}
# *********
# Label Category in Vehicle 22 : {0.0, 1.0}
# Number of Samples in Vehicle 22 : 4757
# Label Counts in Vehicle 22 : {0.0: 4151, 1.0: 606}
# *********
# Label Category in Vehicle 23 : {0.0, 1.0}
# Number of Samples in Vehicle 23 : 14453
# Label Counts in Vehicle 23 : {1.0: 6151, 0.0: 8302}
# *********
# Label Category in Vehicle 24 : {0.0, 1.0}
# Number of Samples in Vehicle 24 : 2405
# Label Counts in Vehicle 24 : {1.0: 1507, 0.0: 898}
# *********
# Label Category in Vehicle 25 : {0.0}
# Number of Samples in Vehicle 25 : 19960
# Label Counts in Vehicle 25 : {0.0: 19960}
# *********
# Label Category in Vehicle 26 : {0.0, 1.0}
# Number of Samples in Vehicle 26 : 4406
# Label Counts in Vehicle 26 : {0.0: 3875, 1.0: 531}
# *********
# Label Category in Vehicle 27 : {0.0, 1.0}
# Number of Samples in Vehicle 27 : 4432
# Label Counts in Vehicle 27 : {0.0: 3920, 1.0: 512}
# *********
# Label Category in Vehicle 28 : {0.0, 1.0}
# Number of Samples in Vehicle 28 : 5116
# Label Counts in Vehicle 28 : {1.0: 4593, 0.0: 523}
# *********
# Label Category in Vehicle 29 : {0.0, 1.0}
# Number of Samples in Vehicle 29 : 7131
# Label Counts in Vehicle 29 : {0.0: 3121, 1.0: 4010}
# *********
# Label Category in Vehicle 30 : {0.0, 1.0}
# Number of Samples in Vehicle 30 : 21614
# Label Counts in Vehicle 30 : {1.0: 13498, 0.0: 8116}
# *********
# Label Category in Vehicle 31 : {0.0, 1.0}
# Number of Samples in Vehicle 31 : 10858
# Label Counts in Vehicle 31 : {0.0: 3894, 1.0: 6964}
# *********
# Label Category in Vehicle 32 : {0.0, 1.0}
# Number of Samples in Vehicle 32 : 9160
# Label Counts in Vehicle 32 : {0.0: 4434, 1.0: 4726}
# *********
# Label Category in Vehicle 33 : {0.0, 1.0}
# Number of Samples in Vehicle 33 : 11899
# Label Counts in Vehicle 33 : {1.0: 4187, 0.0: 7712}
# *********
# Label Category in Vehicle 34 : {0.0, 1.0}
# Number of Samples in Vehicle 34 : 5223
# Label Counts in Vehicle 34 : {1.0: 492, 0.0: 4731}
# *********
# Label Category in Vehicle 35 : {0.0, 1.0}
# Number of Samples in Vehicle 35 : 15004
# Label Counts in Vehicle 35 : {1.0: 13313, 0.0: 1691}
# *********
# Label Category in Vehicle 36 : {0.0}
# Number of Samples in Vehicle 36 : 12233
# Label Counts in Vehicle 36 : {0.0: 12233}
# *********
# Label Category in Vehicle 37 : {0.0, 1.0}
# Number of Samples in Vehicle 37 : 17685
# Label Counts in Vehicle 37 : {1.0: 12824, 0.0: 4861}
# *********
# Label Category in Vehicle 38 : {0.0, 1.0}
# Number of Samples in Vehicle 38 : 2443
# Label Counts in Vehicle 38 : {1.0: 2228, 0.0: 215}
# *********
# Label Category in Vehicle 39 : {0.0, 1.0}
# Number of Samples in Vehicle 39 : 5517
# Label Counts in Vehicle 39 : {1.0: 4391, 0.0: 1126}
# *********
# Label Category in Vehicle 40 : {0.0, 1.0}
# Number of Samples in Vehicle 40 : 3295
# Label Counts in Vehicle 40 : {0.0: 1763, 1.0: 1532}
# *********
# Label Category in Vehicle 41 : {0.0, 1.0}
# Number of Samples in Vehicle 41 : 9595
# Label Counts in Vehicle 41 : {0.0: 4487, 1.0: 5108}
# *********
# Label Category in Vehicle 42 : {0.0, 1.0}
# Number of Samples in Vehicle 42 : 11504
# Label Counts in Vehicle 42 : {0.0: 9549, 1.0: 1955}
# *********
# Label Category in Vehicle 43 : {0.0, 1.0}
# Number of Samples in Vehicle 43 : 33411
# Label Counts in Vehicle 43 : {0.0: 9263, 1.0: 24148}
# *********
# Label Category in Vehicle 44 : {0.0, 1.0}
# Number of Samples in Vehicle 44 : 5195
# Label Counts in Vehicle 44 : {0.0: 1388, 1.0: 3807}
# *********
# Label Category in Vehicle 45 : {0.0, 1.0}
# Number of Samples in Vehicle 45 : 5601
# Label Counts in Vehicle 45 : {1.0: 4741, 0.0: 860}
# *********
# Label Category in Vehicle 46 : {0.0, 1.0}
# Number of Samples in Vehicle 46 : 11161
# Label Counts in Vehicle 46 : {1.0: 9985, 0.0: 1176}
# *********
# Label Category in Vehicle 47 : {0.0, 1.0}
# Number of Samples in Vehicle 47 : 20484
# Label Counts in Vehicle 47 : {1.0: 13010, 0.0: 7474}
# *********
# Label Category in Vehicle 48 : {0.0, 1.0}
# Number of Samples in Vehicle 48 : 8046
# Label Counts in Vehicle 48 : {0.0: 3534, 1.0: 4512}
# *********
# Label Category in Vehicle 49 : {0.0, 1.0}
# Number of Samples in Vehicle 49 : 8429
# Label Counts in Vehicle 49 : {1.0: 8397, 0.0: 32}
# *********
# Label Category in Vehicle 50 : {0.0, 1.0}
# Number of Samples in Vehicle 50 : 22766
# Label Counts in Vehicle 50 : {1.0: 18530, 0.0: 4236}
# *********
# Label Category in Vehicle 51 : {0.0, 1.0}
# Number of Samples in Vehicle 51 : 7829
# Label Counts in Vehicle 51 : {0.0: 6421, 1.0: 1408}
# *********
# Label Category in Vehicle 52 : {0.0, 1.0}
# Number of Samples in Vehicle 52 : 4201
# Label Counts in Vehicle 52 : {0.0: 2784, 1.0: 1417}
# *********
# Label Category in Vehicle 53 : {0.0, 1.0}
# Number of Samples in Vehicle 53 : 296
# Label Counts in Vehicle 53 : {0.0: 78, 1.0: 218}
# *********
# Label Category in Vehicle 54 : {0.0, 1.0}
# Number of Samples in Vehicle 54 : 2505
# Label Counts in Vehicle 54 : {0.0: 643, 1.0: 1862}
# *********
# Label Category in Vehicle 55 : {0.0, 1.0}
# Number of Samples in Vehicle 55 : 11544
# Label Counts in Vehicle 55 : {0.0: 9883, 1.0: 1661}
# *********
# Label Category in Vehicle 56 : {0.0, 1.0}
# Number of Samples in Vehicle 56 : 9787
# Label Counts in Vehicle 56 : {1.0: 1700, 0.0: 8087}
# *********
# Label Category in Vehicle 57 : {0.0, 1.0}
# Number of Samples in Vehicle 57 : 1070
# Label Counts in Vehicle 57 : {0.0: 1048, 1.0: 22}
# *********
# Label Category in Vehicle 58 : {0.0, 1.0}
# Number of Samples in Vehicle 58 : 4275
# Label Counts in Vehicle 58 : {0.0: 2487, 1.0: 1788}
# *********
# Label Category in Vehicle 59 : {0.0, 1.0}
# Number of Samples in Vehicle 59 : 8818
# Label Counts in Vehicle 59 : {1.0: 5352, 0.0: 3466}
# *********
# Generating clients from 60 trainloaders...
# [Vehicle Init] Initialized vehicle client with ID: 0.
# [Vehicle Init] Initialized vehicle client with ID: 1.
# [Vehicle Init] Initialized vehicle client with ID: 2.
# [Vehicle Init] Initialized vehicle client with ID: 3.
# [Vehicle Init] Initialized vehicle client with ID: 4.
# [Vehicle Init] Initialized vehicle client with ID: 5.
# [Vehicle Init] Initialized vehicle client with ID: 6.
# [Vehicle Init] Initialized vehicle client with ID: 7.
# [Vehicle Init] Initialized vehicle client with ID: 8.
# [Vehicle Init] Initialized vehicle client with ID: 9.
# [Vehicle Init] Initialized vehicle client with ID: 10.
# [Vehicle Init] Initialized vehicle client with ID: 11.
# [Vehicle Init] Initialized vehicle client with ID: 12.
# [Vehicle Init] Initialized vehicle client with ID: 13.
# [Vehicle Init] Initialized vehicle client with ID: 14.
# [Vehicle Init] Initialized vehicle client with ID: 15.
# [Vehicle Init] Initialized vehicle client with ID: 16.
# [Vehicle Init] Initialized vehicle client with ID: 17.
# [Vehicle Init] Initialized vehicle client with ID: 18.
# [Vehicle Init] Initialized vehicle client with ID: 19.
# [Vehicle Init] Initialized vehicle client with ID: 20.
# [Vehicle Init] Initialized vehicle client with ID: 21.
# [Vehicle Init] Initialized vehicle client with ID: 22.
# [Vehicle Init] Initialized vehicle client with ID: 23.
# [Vehicle Init] Initialized vehicle client with ID: 24.
# [Vehicle Init] Initialized vehicle client with ID: 25.
# [Vehicle Init] Initialized vehicle client with ID: 26.
# [Vehicle Init] Initialized vehicle client with ID: 27.
# [Vehicle Init] Initialized vehicle client with ID: 28.
# [Vehicle Init] Initialized vehicle client with ID: 29.
# [Vehicle Init] Initialized vehicle client with ID: 30.
# [Vehicle Init] Initialized vehicle client with ID: 31.
# [Vehicle Init] Initialized vehicle client with ID: 32.
# [Vehicle Init] Initialized vehicle client with ID: 33.
# [Vehicle Init] Initialized vehicle client with ID: 34.
# [Vehicle Init] Initialized vehicle client with ID: 35.
# [Vehicle Init] Initialized vehicle client with ID: 36.
# [Vehicle Init] Initialized vehicle client with ID: 37.
# [Vehicle Init] Initialized vehicle client with ID: 38.
# [Vehicle Init] Initialized vehicle client with ID: 39.
# [Vehicle Init] Initialized vehicle client with ID: 40.
# [Vehicle Init] Initialized vehicle client with ID: 41.
# [Vehicle Init] Initialized vehicle client with ID: 42.
# [Vehicle Init] Initialized vehicle client with ID: 43.
# [Vehicle Init] Initialized vehicle client with ID: 44.
# [Vehicle Init] Initialized vehicle client with ID: 45.
# [Vehicle Init] Initialized vehicle client with ID: 46.
# [Vehicle Init] Initialized vehicle client with ID: 47.
# [Vehicle Init] Initialized vehicle client with ID: 48.
# [Vehicle Init] Initialized vehicle client with ID: 49.
# [Vehicle Init] Initialized vehicle client with ID: 50.
# [Vehicle Init] Initialized vehicle client with ID: 51.
# [Vehicle Init] Initialized vehicle client with ID: 52.
# [Vehicle Init] Initialized vehicle client with ID: 53.
# [Vehicle Init] Initialized vehicle client with ID: 54.
# [Vehicle Init] Initialized vehicle client with ID: 55.
# [Vehicle Init] Initialized vehicle client with ID: 56.
# [Vehicle Init] Initialized vehicle client with ID: 57.
# [Vehicle Init] Initialized vehicle client with ID: 58.
# [Vehicle Init] Initialized vehicle client with ID: 59.
# [generate_clients] Total clients generated: 60.
#
# Spread 60 clients across 10 edges, with each edge receiving a subset of clients.
# [spawn_edge_servers] Vehicle mapping to edge servers: {'edge-0': [38, 23, 54, 11, 16, 20, 55, 58], 'edge-1': [33, 19, 9, 36, 31, 45, 30], 'edge-2': [49, 3, 21, 50, 4], 'edge-3': [29, 10, 59, 22, 41, 24, 0], 'edge-4': [44, 25, 52, 18], 'edge-5': [28, 39, 26, 48, 12, 35, 42, 32], 'edge-6': [53, 13, 46], 'edge-7': [57, 2, 27], 'edge-8': [37, 5, 34, 51, 43, 6, 56, 8], 'edge-9': [14, 15, 17, 47, 1, 7, 40]}
#
#   FL Global Training Round SAFL2 - Validation: 1
#
# vehicle 53 from Edge Server edge-6: trained sucessfully : Training time=37.239081382751465, version=1
# Edge Server edge-6: Aggregating model from Vehicle 53.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-53
# vehicle 57 from Edge Server edge-7: trained sucessfully : Training time=78.97492814064026, version=1
# Edge Server edge-7: Aggregating model from Vehicle 57.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-57
# vehicle 0 from Edge Server edge-3: trained sucessfully : Training time=86.17778277397156, version=1
# Edge Server edge-3: Aggregating model from Vehicle 0.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-0
# vehicle 15 from Edge Server edge-9: trained sucessfully : Training time=121.25092458724976, version=1
# Edge Server edge-9: Aggregating model from Vehicle 15.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-15
# vehicle 24 from Edge Server edge-3: trained sucessfully : Training time=148.17086386680603, version=1
# Edge Server edge-3: Aggregating model from Vehicle 24.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-24
# vehicle 38 from Edge Server edge-0: trained sucessfully : Training time=152.70901799201965, version=1
# Edge Server edge-0: Aggregating model from Vehicle 38.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-38
# vehicle 54 from Edge Server edge-0: trained sucessfully : Training time=154.90534162521362, version=1
# Edge Server edge-0: Aggregating model from Vehicle 54.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-54
# vehicle 9 from Edge Server edge-1: trained sucessfully : Training time=193.47737860679626, version=1
# Edge Server edge-1: Aggregating model from Vehicle 9.
# vehicle 40 from Edge Server edge-9: trained sucessfully : Training time=193.60475945472717, version=1
# Edge Server edge-9: Aggregating model from Vehicle 40.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-9
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-40
# vehicle 12 from Edge Server edge-5: trained sucessfully : Training time=219.20561909675598, version=1
# Edge Server edge-5: Aggregating model from Vehicle 12.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-12
# vehicle 52 from Edge Server edge-4: trained sucessfully : Training time=234.23730516433716, version=1
# Edge Server edge-4: Aggregating model from Vehicle 52.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-52
# vehicle 58 from Edge Server edge-0: trained sucessfully : Training time=241.26562595367432, version=1
# Edge Server edge-0: Aggregating model from Vehicle 58.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-58
# vehicle 26 from Edge Server edge-5: trained sucessfully : Training time=243.18690299987793, version=1
# Edge Server edge-5: Aggregating model from Vehicle 26.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-26
# vehicle 27 from Edge Server edge-7: trained sucessfully : Training time=245.85789823532104, version=1
# Edge Server edge-7: Aggregating model from Vehicle 27.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-27
# vehicle 22 from Edge Server edge-3: trained sucessfully : Training time=259.8022644519806, version=1
# Edge Server edge-3: Aggregating model from Vehicle 22.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-22
# vehicle 28 from Edge Server edge-5: trained sucessfully : Training time=274.70600056648254, version=1
# Edge Server edge-5: Aggregating model from Vehicle 28.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-28
# vehicle 44 from Edge Server edge-4: trained sucessfully : Training time=277.0384497642517, version=1
# Edge Server edge-4: Aggregating model from Vehicle 44.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-44
# vehicle 34 from Edge Server edge-8: trained sucessfully : Training time=279.9119641780853, version=1
# Edge Server edge-8: Aggregating model from Vehicle 34.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-34
# vehicle 39 from Edge Server edge-5: trained sucessfully : Training time=291.6984670162201, version=1
# Edge Server edge-5: Aggregating model from Vehicle 39.
# vehicle 45 from Edge Server edge-1: trained sucessfully : Training time=292.35193634033203, version=1
# Edge Server edge-1: Aggregating model from Vehicle 45.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-39
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-45
# vehicle 13 from Edge Server edge-6: trained sucessfully : Training time=300.98305344581604, version=1
# Edge Server edge-6: Aggregating model from Vehicle 13.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-13
# vehicle 29 from Edge Server edge-3: trained sucessfully : Training time=349.18035435676575, version=1
# Edge Server edge-3: Aggregating model from Vehicle 29.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-29
# vehicle 17 from Edge Server edge-9: trained sucessfully : Training time=363.5924377441406, version=1
# Edge Server edge-9: Aggregating model from Vehicle 17.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-17
# vehicle 51 from Edge Server edge-8: trained sucessfully : Training time=374.2142593860626, version=1
# Edge Server edge-8: Aggregating model from Vehicle 51.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-51
# vehicle 48 from Edge Server edge-5: trained sucessfully : Training time=381.5880219936371, version=1
# Edge Server edge-5: Aggregating model from Vehicle 48.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-48
# vehicle 49 from Edge Server edge-2: trained sucessfully : Training time=392.02102065086365, version=1
# Edge Server edge-2: Aggregating model from Vehicle 49.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-49
# vehicle 4 from Edge Server edge-2: trained sucessfully : Training time=402.8499388694763, version=1
# Edge Server edge-2: Aggregating model from Vehicle 4.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-4
# vehicle 59 from Edge Server edge-3: trained sucessfully : Training time=404.6639268398285, version=1
# Edge Server edge-3: Aggregating model from Vehicle 59.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-59
# vehicle 11 from Edge Server edge-0: trained sucessfully : Training time=411.77305817604065, version=1
# Edge Server edge-0: Aggregating model from Vehicle 11.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-11
# vehicle 32 from Edge Server edge-5: trained sucessfully : Training time=416.1956684589386, version=1
# Edge Server edge-5: Aggregating model from Vehicle 32.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-32
# vehicle 14 from Edge Server edge-9: trained sucessfully : Training time=420.20270323753357, version=1
# Edge Server edge-9: Aggregating model from Vehicle 14.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-14
# vehicle 8 from Edge Server edge-8: trained sucessfully : Training time=422.3020670413971, version=1
# Edge Server edge-8: Aggregating model from Vehicle 8.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-8
# vehicle 41 from Edge Server edge-3: trained sucessfully : Training time=425.7892711162567, version=1
# Edge Server edge-3: Aggregating model from Vehicle 41.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-41
# vehicle 56 from Edge Server edge-8: trained sucessfully : Training time=432.05684518814087, version=1
# Edge Server edge-8: Aggregating model from Vehicle 56.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-56
# vehicle 31 from Edge Server edge-1: trained sucessfully : Training time=457.9093849658966, version=1
# Edge Server edge-1: Aggregating model from Vehicle 31.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-31
# vehicle 2 from Edge Server edge-7: trained sucessfully : Training time=463.96691846847534, version=1
# Edge Server edge-7: Aggregating model from Vehicle 2.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-2
# vehicle 46 from Edge Server edge-6: trained sucessfully : Training time=465.5667881965637, version=1
# Edge Server edge-6: Aggregating model from Vehicle 46.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-46
# vehicle 16 from Edge Server edge-0: trained sucessfully : Training time=466.5421829223633, version=1
# Edge Server edge-0: Aggregating model from Vehicle 16.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-16
# vehicle 42 from Edge Server edge-5: trained sucessfully : Training time=471.7677836418152, version=1
# Edge Server edge-5: Aggregating model from Vehicle 42.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-42
# vehicle 55 from Edge Server edge-0: trained sucessfully : Training time=472.5472149848938, version=1
# Edge Server edge-0: Aggregating model from Vehicle 55.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-55
# vehicle 33 from Edge Server edge-1: trained sucessfully : Training time=477.7990140914917, version=1
# Edge Server edge-1: Aggregating model from Vehicle 33.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-33
# vehicle 36 from Edge Server edge-1: trained sucessfully : Training time=485.4285337924957, version=1
# Edge Server edge-1: Aggregating model from Vehicle 36.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-36
# vehicle 6 from Edge Server edge-8: trained sucessfully : Training time=486.0081276893616, version=1
# Edge Server edge-8: Aggregating model from Vehicle 6.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-6
# vehicle 3 from Edge Server edge-2: trained sucessfully : Training time=490.23435282707214, version=1
# Edge Server edge-2: Aggregating model from Vehicle 3.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-3
# vehicle 10 from Edge Server edge-3: trained sucessfully : Training time=514.8468954563141, version=1
# Edge Server edge-3: Aggregating model from Vehicle 10.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-10
# vehicle 23 from Edge Server edge-0: trained sucessfully : Training time=518.2903106212616, version=1
# Edge Server edge-0: Aggregating model from Vehicle 23.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-23
# vehicle 1 from Edge Server edge-9: trained sucessfully : Training time=520.1972072124481, version=1
# Edge Server edge-9: Aggregating model from Vehicle 1.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-1
# vehicle 7 from Edge Server edge-9: trained sucessfully : Training time=522.0099799633026, version=1
# Edge Server edge-9: Aggregating model from Vehicle 7.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-7
# vehicle 35 from Edge Server edge-5: trained sucessfully : Training time=525.8051435947418, version=1
# Edge Server edge-5: Aggregating model from Vehicle 35.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-35
# vehicle 37 from Edge Server edge-8: trained sucessfully : Training time=553.4467487335205, version=1
# Edge Server edge-8: Aggregating model from Vehicle 37.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-37
# vehicle 21 from Edge Server edge-2: trained sucessfully : Training time=559.0425293445587, version=1
# Edge Server edge-2: Aggregating model from Vehicle 21.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-21
# vehicle 25 from Edge Server edge-4: trained sucessfully : Training time=573.1078732013702, version=1
# Edge Server edge-4: Aggregating model from Vehicle 25.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-25
# vehicle 5 from Edge Server edge-8: trained sucessfully : Training time=576.5373075008392, version=1
# Edge Server edge-8: Aggregating model from Vehicle 5.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-5
# vehicle 47 from Edge Server edge-9: trained sucessfully : Training time=576.850606918335, version=1
# Edge Server edge-9: Aggregating model from Vehicle 47.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-47
# vehicle 30 from Edge Server edge-1: trained sucessfully : Training time=581.726359128952, version=1
# Edge Server edge-1: Aggregating model from Vehicle 30.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-30
# vehicle 50 from Edge Server edge-2: trained sucessfully : Training time=585.7661597728729, version=1
# Edge Server edge-2: Aggregating model from Vehicle 50.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-50
# vehicle 19 from Edge Server edge-1: trained sucessfully : Training time=588.996702671051, version=1
# Edge Server edge-1: Aggregating model from Vehicle 19.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-19
# vehicle 43 from Edge Server edge-8: trained sucessfully : Training time=603.5735154151917, version=1
# Edge Server edge-8: Aggregating model from Vehicle 43.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-43
# vehicle 18 from Edge Server edge-4: trained sucessfully : Training time=609.3919939994812, version=1
# Edge Server edge-4: Aggregating model from Vehicle 18.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-18
# vehicle 20 from Edge Server edge-0: trained sucessfully : Training time=613.807939529419, version=1
# Edge Server edge-0: Aggregating model from Vehicle 20.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-20
# Loss = 0.36106778719068006, Accuracy = 0.9191528486731556, Precision = 0.9107414805878048, Recall = 0.9362203923960557, F1 score = 0.9233051951957973, Total Time for round 1= 617.89 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_1.pth
# ********************************************************************************************************************************************************************************************************
#
#   FL Global Training Round SAFL2 - Validation: 2
#
# vehicle 53 from Edge Server edge-6: trained sucessfully : Training time=36.71939015388489, version=2
# Edge Server edge-6: Aggregating model from Vehicle 53.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-53
# vehicle 57 from Edge Server edge-7: trained sucessfully : Training time=77.97417664527893, version=2
# Edge Server edge-7: Aggregating model from Vehicle 57.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-57
# vehicle 0 from Edge Server edge-3: trained sucessfully : Training time=83.65807628631592, version=2
# Edge Server edge-3: Aggregating model from Vehicle 0.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-0
# vehicle 15 from Edge Server edge-9: trained sucessfully : Training time=119.03376770019531, version=2
# Edge Server edge-9: Aggregating model from Vehicle 15.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-15
# vehicle 24 from Edge Server edge-3: trained sucessfully : Training time=147.19677567481995, version=2
# Edge Server edge-3: Aggregating model from Vehicle 24.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-24
# vehicle 38 from Edge Server edge-0: trained sucessfully : Training time=149.06993079185486, version=2
# Edge Server edge-0: Aggregating model from Vehicle 38.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-38
# vehicle 54 from Edge Server edge-0: trained sucessfully : Training time=152.87174725532532, version=2
# Edge Server edge-0: Aggregating model from Vehicle 54.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-54
# vehicle 9 from Edge Server edge-1: trained sucessfully : Training time=188.56554913520813, version=2
# Edge Server edge-1: Aggregating model from Vehicle 9.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-9
# vehicle 40 from Edge Server edge-9: trained sucessfully : Training time=190.07821583747864, version=2
# Edge Server edge-9: Aggregating model from Vehicle 40.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-40
# vehicle 12 from Edge Server edge-5: trained sucessfully : Training time=214.72386407852173, version=2
# Edge Server edge-5: Aggregating model from Vehicle 12.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-12
# vehicle 52 from Edge Server edge-4: trained sucessfully : Training time=228.8631398677826, version=2
# Edge Server edge-4: Aggregating model from Vehicle 52.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-52
# vehicle 58 from Edge Server edge-0: trained sucessfully : Training time=233.05311512947083, version=2
# Edge Server edge-0: Aggregating model from Vehicle 58.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-58
# vehicle 26 from Edge Server edge-5: trained sucessfully : Training time=237.15167760849, version=2
# Edge Server edge-5: Aggregating model from Vehicle 26.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-26
# vehicle 27 from Edge Server edge-7: trained sucessfully : Training time=240.20848536491394, version=2
# Edge Server edge-7: Aggregating model from Vehicle 27.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-27
# vehicle 22 from Edge Server edge-3: trained sucessfully : Training time=253.27008080482483, version=2
# Edge Server edge-3: Aggregating model from Vehicle 22.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-22
# vehicle 28 from Edge Server edge-5: trained sucessfully : Training time=266.9232349395752, version=2
# Edge Server edge-5: Aggregating model from Vehicle 28.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-28
# vehicle 44 from Edge Server edge-4: trained sucessfully : Training time=272.7757110595703, version=2
# Edge Server edge-4: Aggregating model from Vehicle 44.
# vehicle 34 from Edge Server edge-8: trained sucessfully : Training time=272.91411566734314, version=2
# Edge Server edge-8: Aggregating model from Vehicle 34.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-44
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-34
# vehicle 39 from Edge Server edge-5: trained sucessfully : Training time=284.7581114768982, version=2
# Edge Server edge-5: Aggregating model from Vehicle 39.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-39
# vehicle 45 from Edge Server edge-1: trained sucessfully : Training time=286.5550618171692, version=2
# Edge Server edge-1: Aggregating model from Vehicle 45.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-45
# vehicle 13 from Edge Server edge-6: trained sucessfully : Training time=293.9338541030884, version=2
# Edge Server edge-6: Aggregating model from Vehicle 13.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-13
# vehicle 29 from Edge Server edge-3: trained sucessfully : Training time=341.43827867507935, version=2
# Edge Server edge-3: Aggregating model from Vehicle 29.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-29
# vehicle 17 from Edge Server edge-9: trained sucessfully : Training time=354.8607814311981, version=2
# Edge Server edge-9: Aggregating model from Vehicle 17.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-17
# vehicle 51 from Edge Server edge-8: trained sucessfully : Training time=364.75427412986755, version=2
# Edge Server edge-8: Aggregating model from Vehicle 51.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-51
# vehicle 48 from Edge Server edge-5: trained sucessfully : Training time=372.5709664821625, version=2
# Edge Server edge-5: Aggregating model from Vehicle 48.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-48
# vehicle 49 from Edge Server edge-2: trained sucessfully : Training time=384.37318301200867, version=2
# Edge Server edge-2: Aggregating model from Vehicle 49.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-49
# vehicle 4 from Edge Server edge-2: trained sucessfully : Training time=396.2718186378479, version=2
# Edge Server edge-2: Aggregating model from Vehicle 4.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-4
# vehicle 59 from Edge Server edge-3: trained sucessfully : Training time=397.1984746456146, version=2
# Edge Server edge-3: Aggregating model from Vehicle 59.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-59
# vehicle 11 from Edge Server edge-0: trained sucessfully : Training time=404.10653471946716, version=2
# Edge Server edge-0: Aggregating model from Vehicle 11.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-11
# vehicle 32 from Edge Server edge-5: trained sucessfully : Training time=406.0156409740448, version=2
# Edge Server edge-5: Aggregating model from Vehicle 32.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-32
# vehicle 14 from Edge Server edge-9: trained sucessfully : Training time=412.3294553756714, version=2
# Edge Server edge-9: Aggregating model from Vehicle 14.
# vehicle 8 from Edge Server edge-8: trained sucessfully : Training time=412.65848445892334, version=2
# Edge Server edge-8: Aggregating model from Vehicle 8.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-14
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-8
# vehicle 41 from Edge Server edge-3: trained sucessfully : Training time=418.36763191223145, version=2
# Edge Server edge-3: Aggregating model from Vehicle 41.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-41
# vehicle 56 from Edge Server edge-8: trained sucessfully : Training time=421.8057198524475, version=2
# Edge Server edge-8: Aggregating model from Vehicle 56.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-56
# vehicle 31 from Edge Server edge-1: trained sucessfully : Training time=446.6911313533783, version=2
# Edge Server edge-1: Aggregating model from Vehicle 31.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-31
# vehicle 2 from Edge Server edge-7: trained sucessfully : Training time=454.5240821838379, version=2
# Edge Server edge-7: Aggregating model from Vehicle 2.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-2
# vehicle 46 from Edge Server edge-6: trained sucessfully : Training time=455.50829792022705, version=2
# Edge Server edge-6: Aggregating model from Vehicle 46.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-46
# vehicle 16 from Edge Server edge-0: trained sucessfully : Training time=456.6061728000641, version=2
# Edge Server edge-0: Aggregating model from Vehicle 16.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-16
# vehicle 42 from Edge Server edge-5: trained sucessfully : Training time=462.5311915874481, version=2
# Edge Server edge-5: Aggregating model from Vehicle 42.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-42
# vehicle 55 from Edge Server edge-0: trained sucessfully : Training time=463.22953844070435, version=2
# Edge Server edge-0: Aggregating model from Vehicle 55.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-55
# vehicle 33 from Edge Server edge-1: trained sucessfully : Training time=469.2681374549866, version=2
# Edge Server edge-1: Aggregating model from Vehicle 33.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-33
# vehicle 36 from Edge Server edge-1: trained sucessfully : Training time=474.8202519416809, version=2
# Edge Server edge-1: Aggregating model from Vehicle 36.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-36
# vehicle 6 from Edge Server edge-8: trained sucessfully : Training time=476.28197979927063, version=2
# Edge Server edge-8: Aggregating model from Vehicle 6.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-6
# vehicle 3 from Edge Server edge-2: trained sucessfully : Training time=480.12427854537964, version=2
# Edge Server edge-2: Aggregating model from Vehicle 3.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-3
# vehicle 10 from Edge Server edge-3: trained sucessfully : Training time=504.4690399169922, version=2
# Edge Server edge-3: Aggregating model from Vehicle 10.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-10
# vehicle 23 from Edge Server edge-0: trained sucessfully : Training time=508.3500483036041, version=2
# Edge Server edge-0: Aggregating model from Vehicle 23.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-23
# vehicle 1 from Edge Server edge-9: trained sucessfully : Training time=509.093781709671, version=2
# Edge Server edge-9: Aggregating model from Vehicle 1.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-1
# vehicle 7 from Edge Server edge-9: trained sucessfully : Training time=511.4669780731201, version=2
# Edge Server edge-9: Aggregating model from Vehicle 7.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-7
# vehicle 35 from Edge Server edge-5: trained sucessfully : Training time=514.3767421245575, version=2
# Edge Server edge-5: Aggregating model from Vehicle 35.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-35
# vehicle 37 from Edge Server edge-8: trained sucessfully : Training time=544.9344701766968, version=2
# Edge Server edge-8: Aggregating model from Vehicle 37.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-37
# vehicle 21 from Edge Server edge-2: trained sucessfully : Training time=548.4497623443604, version=2
# Edge Server edge-2: Aggregating model from Vehicle 21.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-21
# vehicle 25 from Edge Server edge-4: trained sucessfully : Training time=561.4478242397308, version=2
# Edge Server edge-4: Aggregating model from Vehicle 25.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-25
# vehicle 5 from Edge Server edge-8: trained sucessfully : Training time=564.8439385890961, version=2
# Edge Server edge-8: Aggregating model from Vehicle 5.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-5
# vehicle 47 from Edge Server edge-9: trained sucessfully : Training time=565.7654869556427, version=2
# Edge Server edge-9: Aggregating model from Vehicle 47.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-47
# vehicle 30 from Edge Server edge-1: trained sucessfully : Training time=570.6357319355011, version=2
# Edge Server edge-1: Aggregating model from Vehicle 30.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-30
# vehicle 50 from Edge Server edge-2: trained sucessfully : Training time=574.2177095413208, version=2
# Edge Server edge-2: Aggregating model from Vehicle 50.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-2. after training vehicle-50
# vehicle 19 from Edge Server edge-1: trained sucessfully : Training time=577.2913656234741, version=2
# Edge Server edge-1: Aggregating model from Vehicle 19.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-19
# vehicle 43 from Edge Server edge-8: trained sucessfully : Training time=590.9041268825531, version=2
# Edge Server edge-8: Aggregating model from Vehicle 43.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-8. after training vehicle-43
# vehicle 18 from Edge Server edge-4: trained sucessfully : Training time=596.0736343860626, version=2
# Edge Server edge-4: Aggregating model from Vehicle 18.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-18
# vehicle 20 from Edge Server edge-0: trained sucessfully : Training time=599.7692303657532, version=2
# Edge Server edge-0: Aggregating model from Vehicle 20.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-20
# Loss = 0.28398377652001455, Accuracy = 0.9216046838506494, Precision = 0.944761931806081, Recall = 0.9019145403408898, F1 score = 0.9228411541582009, Total Time for round 2= 599.96 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_2.pth
# ********************************************************************************************************************************************************************************************************
#
#   FL Global Training Round SAFL2 - Validation: 3
#
# vehicle 53 from Edge Server edge-6: trained sucessfully : Training time=37.03185248374939, version=3
# Edge Server edge-6: Aggregating model from Vehicle 53.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-6. after training vehicle-53
# vehicle 57 from Edge Server edge-7: trained sucessfully : Training time=77.55675220489502, version=3
# Edge Server edge-7: Aggregating model from Vehicle 57.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-7. after training vehicle-57
# vehicle 0 from Edge Server edge-3: trained sucessfully : Training time=84.96351790428162, version=3
# Edge Server edge-3: Aggregating model from Vehicle 0.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-0
# vehicle 15 from Edge Server edge-9: trained sucessfully : Training time=118.59084892272949, version=3
# Edge Server edge-9: Aggregating model from Vehicle 15.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-15
# vehicle 24 from Edge Server edge-3: trained sucessfully : Training time=145.02215909957886, version=3
# Edge Server edge-3: Aggregating model from Vehicle 24.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-3. after training vehicle-24
# vehicle 38 from Edge Server edge-0: trained sucessfully : Training time=148.5981204509735, version=3
# Edge Server edge-0: Aggregating model from Vehicle 38.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-38
# vehicle 54 from Edge Server edge-0: trained sucessfully : Training time=151.5466239452362, version=3
# Edge Server edge-0: Aggregating model from Vehicle 54.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-0. after training vehicle-54
# vehicle 9 from Edge Server edge-1: trained sucessfully : Training time=188.42735767364502, version=3
# Edge Server edge-1: Aggregating model from Vehicle 9.
# vehicle 40 from Edge Server edge-9: trained sucessfully : Training time=189.23834037780762, version=3
# Edge Server edge-9: Aggregating model from Vehicle 40.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-1. after training vehicle-9
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-9. after training vehicle-40
# vehicle 12 from Edge Server edge-5: trained sucessfully : Training time=215.0425202846527, version=3
# Edge Server edge-5: Aggregating model from Vehicle 12.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-5. after training vehicle-12
# vehicle 52 from Edge Server edge-4: trained sucessfully : Training time=228.4786639213562, version=3
# Edge Server edge-4: Aggregating model from Vehicle 52.
# [Cloud Server: Global model updated after aggregation from Edge Server-edge-4. after training vehicle-52
# vehicle 58 from Edge Server edge-0: trained sucessfully : Training time=230.89255952835083, version=3
# Edge Server edge-0: Aggregating model from Vehicle 58.
# ...
#
#
# Vehicle 8 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 9 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 55 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 58 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 16 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 36 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 43 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 54 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 20 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Loss = 0.2813881697225591, Accuracy = 0.9212383176747021, Precision = 0.9450183059040984, Recall = 0.9008911931144319, F1 score = 0.9224273124696413, Total Time for round 8= 0.14 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_8.pth
# ********************************************************************************************************************************************************************************************************
#
#   FL Global Training Round SAFL2 - Validation: 9
#
# Vehicle 49 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 50 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 3 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 57 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 21 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 28 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 37 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 4 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 2 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 34 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 46 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 39 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 5 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 44 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 53 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 13 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 27 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 33 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 59 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 25 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 52 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 41 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 12 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 29 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 19 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 22 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 32 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 26 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 35 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 48 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 42 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 23 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 10 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 24 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 6 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 56 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 9 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 18 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 0 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 8 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 38 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 36 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 14 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 51 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 15 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 43 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 45 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 30 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 31 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 47 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 16 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 11 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 17 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 54 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 55 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 40 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 58 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 20 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 1 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 7 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Loss = 0.2813881697225591, Accuracy = 0.9212383176747021, Precision = 0.9450183059040984, Recall = 0.9008911931144319, F1 score = 0.9224273124696413, Total Time for round 9= 0.13 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_9.pth
# ********************************************************************************************************************************************************************************************************
#
#   FL Global Training Round SAFL2 - Validation: 10
#
# Vehicle 50 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 49 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 4 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 21 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 26 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 57 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 3 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 14 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 38 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 44 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 48 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 28 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 2 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 54 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 27 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 23 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 39 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 47 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 15 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 16 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 33 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 17 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 25 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 7 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 11 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 37 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 1 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 13 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 46 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 18 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 53 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 40 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 29 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 22 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 19 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 59 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 31 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 52 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 10 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 36 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 0 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 41 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 24 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 51 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 58 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 20 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 5 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.Vehicle 35 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
#
# Vehicle 32 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 12 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 55 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 45 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 9 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 43 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 34 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 6 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 8 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 56 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 42 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Vehicle 30 has version 4, which is greater than the threshold of 3. Synchronizing model parameters.
# Loss = 0.2813881697225591, Accuracy = 0.9212383176747021, Precision = 0.9450183059040984, Recall = 0.9008911931144319, F1 score = 0.9224273124696413, Total Time for round 10= 0.13 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_10.pth
# ********************************************************************************************************************************************************************************************************
# Final model results: loss = 0.2813881697225591, accuracy = 0.9212383176747021, precision = 0.9450183059040984, recall = 0.9008911931144319, F1 = 0.9224273124696413
#  confusion matrix: [[128580   7734]
#  [ 14624 132931]]
# ********************************************************************************************************************************************************************************************************
#
# Total training time for all rounds: 2433.07 seconds
#
# Final model results: Loss = 0.2813881697225591, Accuracy = 0.9212383176747021, Precision = 0.9450183059040984, Recall = 0.9008911931144319, F1 = 0.9224273124696413
# Confusion Matrix:
# [[128580   7734]
#  [ 14624 132931]]
# Testing Time: 4.84 seconds
# Model saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/model_checkpoint/SAFL2/model_SAFL2_round_10.pth
# Training results saved to /content/drive/MyDrive/SAFL2_Exp2_09_02_25/results/SAFL2_results.csv
# Feature values for instance index 153709:
#    Feature     Value
# 0  DATA_0  1.619124
# 1  DATA_1  0.284244
# 2  DATA_2 -1.117115
# 3  DATA_3 -1.223501
# 4  DATA_4 -0.137681
# 5  DATA_5  0.123697
# 6  DATA_6 -0.868098
# 7  DATA_7  1.277163
# LIME explanation plot saved to /content/drive/MyDrive/SAFL2_Exp2_09_02_25/lime_resultslime_explanation_SAFL2.png
# Total time taken for Lime Explanation: 1.62 seconds
# SHAP summary plot saved as /content/drive/MyDrive/SAFL2_Exp2_09_02_25/shap_results/shap_summary_SAFL2.png
# Total time taken for Shap Explanation: 1040.17 seconds

# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
method_name="SAFL2"
#results_path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/results"
results_path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/results/SAFL2_results.csv"
fig_path = f"/content/drive/MyDrive/SAFL2_Exp2_09_02_25/results"
plot_path = f"{fig_path}_{method_name}.png"
results=pd.read_csv("/content/drive/MyDrive/SAFL2_Exp2_09_02_25/results/SAFL2_results.csv")

#results=pd.read_csv(f"{results_path}/{method_name}_results.csv")
df_plot = results[pd.to_numeric(results['Round'], errors='coerce').notnull()]
#df_plot['Round'] = pd.to_numeric(df_plot['Round'], errors='coerce')
df_plot = df_plot.dropna(subset=['Round']) # Remove rows where 'Round' is NaN after conversion
df_plot['Round'] = df_plot['Round'].astype(int)


# Plotting the training and test loss per round
plt.figure(figsize=(10, 6))
plt.plot(df_plot['Round'], df_plot['Train_Loss'], label="Training Loss", marker='o')
plt.plot(df_plot['Round'], df_plot['Test_loss'], label="Testing Loss", marker='o')
plt.xlabel("FL Training Round")
plt.ylabel("Loss")
plt.title("Training and Testing Loss per Federated Learning Round")
plt.xticks(df_plot['Round'].astype(int)) # Display only the round numbers on the x-axis
plt.legend()
plt.grid(True)


# Save the plot
plot_path = f"{fig_path}/{method_name}.png"
plt.savefig(plot_path, bbox_inches='tight')
plt.show()
