# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install shap -q
# !pip install hydra-core -q
# !pip install fedlab -q
# !pip install lime -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.5 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.0 MB/s eta 0:00:00
#   Building wheel for fedlab (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done

# %%
import random
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import copy
import statistics
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import yaml
import os
from fedlab.utils.dataset.partition import  BasicPartitioner
from torch.utils.data import Subset
import matplotlib.pyplot as plt
from collections import OrderedDict
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
import shap
import hydra
from hydra.core.hydra_config import HydraConfig
from omegaconf import DictConfig, OmegaConf
import random
import numpy as np
import torch
# Set seed for Python's random module
random.seed(42)
# Set seed for NumPy
np.random.seed(42)
# Set seed for PyTorch
torch.manual_seed(42)
import numpy as np
import torch
import torch.nn.functional as F
import random
from lime.lime_tabular import LimeTabularExplainer
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import os
import seaborn as sns
# If you are using CUDA, you may also want to set the seed for GPU operations
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)  # For all GPUs if you have multiple

# %% [markdown]
# num_rounds: 10 # number of FL rounds in the experiment
# num_clients: 60 # number of total clients
# num_edges: 10
#
# config_fit: # a config that each client will receive (this is sent by the server). This allows to dynamically configure the training on the client side as the simulation progresses
#   lr: 0.01 # learning rate to use by the clients
#   momentum: 0.9 # momentum used by SGD optimiser on the client side
#   local_epochs: 20 # number of training epochs each clients does in a fit() round
#   batch_size: 64 # batch size to use by clients during training

# %% [markdown]
# ### 1. Load and preprocess the dataset.

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_flag_distribution(df, class_labels=None):
    """
    Plots the distribution of the 'flag' column in the dataset.

    Parameters:
        df (pd.DataFrame): The dataframe containing the 'flag' column.
        class_labels (dict, optional): A dictionary to map flag values to meaningful class names.
                                       Example: {"R": "Normal", "T": "Attack"}.
    """
    sns.countplot(x="label", data=df, palette="viridis", hue="label", legend=False)
    plt.title("Flag Value Counts")
    if class_labels:
        plt.xticks(
            ticks=range(len(class_labels)),
            labels=[class_labels[label] for label in class_labels]
        )
    plt.show()

def preprocess_dataset():
    processed_file = "/content/drive/MyDrive/car_hacking_dataset/Dataset/Car_Hacking_preprocessed_dataset.csv"
    class_labels = {"R": "Normal", "T": "Attack"}

    # Load processed dataset if it exists
    if os.path.isfile(processed_file):
        df = pd.read_csv(processed_file)
        if "flag" in df.columns and "label" not in df.columns:
            df.rename(columns={"flag": "label"}, inplace=True)
        plot_flag_distribution(df, class_labels)
        return df

    # Raw data file paths
    raw_files = {
        "normal": "/content/drive/MyDrive/Normal_data.csv",
        "dos": "/content/drive/MyDrive/DoS_dataset.csv",
        "fuzzy": "/content/drive/MyDrive/Fuzzy_dataset.csv",
        "gear": "/content/drive/MyDrive/gear_dataset.csv",
        "rpm": "/content/drive/MyDrive/RPM_dataset.csv"
    }

    column_names = ["Timestamp", "ID", "DLC", "Byte1", "Byte2", "Byte3", "Byte4", "Byte5", "Byte6", "Byte7", "Byte8", "flag"]
    dataframes = []

    # Load and process raw files
    for key, path in raw_files.items():
        df = pd.read_csv(path, names=column_names, index_col=False) if key != "normal" else pd.read_csv(path, index_col=False)
        if key == "normal":
            df["flag"] = "R"  # Assign flag for normal data
        dataframes.append(df)

    # Combine all datasets
    df = pd.concat(dataframes, axis=0, ignore_index=True)
    print(f"Total data shape before removing missing data: {df.shape}")

    # Drop rows with missing data
    df.dropna(inplace=True)
    print(f"Total data shape after removing missing data: {df.shape}")

    # Convert Hexadecimal Byte columns to Decimal and drop original Byte columns
    byte_columns = [f"Byte{i}" for i in range(1, 9)]
    for i, byte_col in enumerate(byte_columns):
        df[f"DATA_{i}"] = df[byte_col].apply(lambda x: int(str(x), 16))
    df.drop(columns=byte_columns, inplace=True)

    # Drop unnecessary columns
    df.drop(columns=["Timestamp", "ID", "DLC"], inplace=True)

    # Remove duplicate rows
    df.drop_duplicates(inplace=True)
    print(f"Data shape after removing duplicate entries: {df.shape}")

    # Save the processed dataset
    os.makedirs(os.path.dirname(processed_file), exist_ok=True)
    df.to_csv(processed_file, index=False)

    # Visualize and rename flag column
    plot_flag_distribution(df, class_labels)
    if "flag" in df.columns and "label" not in df.columns:
        df.rename(columns={"flag": "label"}, inplace=True)

    return df

# %%
def prepare_training_testing_data(dataset, test_size=0.30, output_dir="/content/drive/MyDrive/car_hacking_dataset/Dataset"):
    """
    Prepares and pre-processes the dataset for training and testing.

    This function shuffles the dataset, encodes labels, scales features, and splits the data
    into training and testing sets. It also saves the processed training and testing data into CSV files.

    Args:
        dataset (pd.DataFrame): The input dataset containing features and labels.
        test_size (float, optional): Proportion of the dataset to be used for testing. Defaults to 0.30.
        output_dir (str, optional): Directory where processed files will be saved. Defaults to a specified path.

    Returns:
        tuple:
            X_train_scaled (numpy.ndarray): Scaled feature matrix for the training set.
            X_test_scaled (numpy.ndarray): Scaled feature matrix for the test set.
    """
    # Shuffle the dataset
    dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

    # Encode labels
    label_mapping = {"R": 0, "T": 1}
    dataset['label'] = dataset['label'].map(label_mapping)

    # Split into train and test sets
    train_df, test_df = train_test_split(dataset, test_size=test_size, stratify=dataset['label'], random_state=42)

    # Split features and labels
    X_train, y_train = train_df.drop(columns=['label']), train_df['label']
    X_test, y_test = test_df.drop(columns=['label']), test_df['label']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Prepare scaled datasets for saving
    train_df_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    train_df_scaled['label'] = y_train.values

    test_df_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
    test_df_scaled['label'] = y_test.values

    # Save processed datasets
    os.makedirs(output_dir, exist_ok=True)
    train_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_trainset.csv"), index=False)
    test_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_testset.csv"), index=False)

    return X_train_scaled, X_test_scaled

def get_car_hacking_dataset():
    """
    Loads and prepares the CiCiov dataset for training and testing in PyTorch format.

    This function reads the pre-processed train and test CSV files, converts the data into PyTorch tensors,
    and creates TensorDataset objects for both the training and testing data. It also returns the target labels
    separately for both the train and test sets.

    Args:
        None

    Returns:
        tuple:
            train_tensor (torch.utils.data.TensorDataset): Tensor dataset containing training features and labels.
            test_tensor (torch.utils.data.TensorDataset): Tensor dataset containing test features and labels.
            train_target (torch.Tensor): Tensor containing training labels.
            test_target (torch.Tensor): Tensor containing test labels.
    """
    train = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_trainset.csv')
    test = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_testset.csv')
    train_target = torch.tensor(train['label'].values.astype(np.float32))
    train = torch.tensor(train.drop('label', axis = 1).values.astype(np.float32))
    train_tensor = TensorDataset(train, train_target)

    test_target = torch.tensor(test['label'].values.astype(np.float32))
    test = torch.tensor(test.drop('label', axis = 1).values.astype(np.float32))
    test_tensor = TensorDataset(test, test_target)

    return train_tensor , test_tensor ,train_target,test_target

# %%
#  Preprocess the Dataset and ge
df = preprocess_dataset()

# Pre-process the dataset by splitting it into training and testing sets
# The parameter test_size=0.3 indicates that 30% of the data will be used for testing
x_train, x_test = prepare_training_testing_data(df,test_size=0.3)

# Convert the training data (x_train) into a PyTorch tensor of type float32
X_train_tensor = torch.tensor(x_train, dtype=torch.float32)

# Convert the testing data (x_test) into a PyTorch tensor of type float32
X_test_tensor = torch.tensor(x_test, dtype=torch.float32)

# Load the dataset for a specific application (CICIDS dataset)
# The function returns training and testing datasets, as well as their corresponding targets
trainset, testset, train_target, test_target = get_car_hacking_dataset()

# %%
x_train.shape, x_test.shape
# Out:
# ((662360, 8), (283869, 8))

# %%
print(" Label distribution in the Training data",np.unique(train_target, return_counts=True))
print(" Label distribution in the Test data",np.unique(test_target, return_counts=True))
# Out:
#  Label distribution in the Training data (array([0., 1.], dtype=float32), array([318065, 344295]))
#  Label distribution in the Test data (array([0., 1.], dtype=float32), array([136314, 147555]))

# %% [markdown]
# ### 2. Split the Training set into M parts with M-Number of Clients.
#
#  Here the test set will not be split. It will be used to test the Global Model.

# %%
import torch
from torch.utils.data import DataLoader, Subset

def get_all_labels(dataset):
    """
    Extract all labels from the given dataset.

    Args:
        dataset (Iterable): The dataset from which to extract labels.
                            It should yield pairs of (data, labels).

    Returns:
        torch.Tensor: A tensor containing all the labels stacked together.
    """
    all_labels = []

    # Iterate through the dataset to collect all labels
    for _, labels in dataset:
        all_labels.append(labels)

    # Stack all labels into a single tensor
    all_labels_tensor = torch.stack(all_labels)

    return all_labels_tensor

def split_dataset(train_set, test_set, num_clients, batch_size, partition, dir_alpha=None, major_classes_num=0):
    """
    Split the dataset into multiple clients for federated learning.

    Args:
        train_set (Dataset): The training dataset to be partitioned.
        test_set (Dataset): The testing dataset.
        num_clients (int): The number of clients to split the data among.
        batch_size (int): The batch size for the data loaders.
        partition (str): The type of partitioning ('iid' for independent and identically distributed).
        dir_alpha (float, optional): Dirichlet parameter for non-iid partitioning.
        major_classes_num (int, optional): Number of major classes for partitioning.

    Returns:
        list: A list of DataLoaders for the training sets of each client.
        DataLoader: A DataLoader for the test set.
    """

    # Initialize the partitioner with the labels from the training set
    partitioner = BasicPartitioner(
        get_all_labels(train_set),
        num_clients,
        partition=partition,
        dir_alpha=dir_alpha,
        major_classes_num=major_classes_num,
        seed=2023
    )

    trainloaders = []

    # Create a DataLoader for each client's training set
    for client in range(num_clients):
        idx = partitioner.client_dict[client]  # Get indices for the current client
        trainset_ = Subset(train_set, idx)  # Create a subset for the client

        # Create a DataLoader for the client's training set
        trainloaders.append(DataLoader(trainset_, batch_size=batch_size, shuffle=True))

    # Create a DataLoader for the test set (no shuffling)
    testloader = DataLoader(test_set, batch_size=batch_size)
    # Create a DataLoader for the Training data to get training loss
    raw_train_loader = DataLoader(train_set, batch_size=batch_size)
    return raw_train_loader ,trainloaders, testloader

# %%
import yaml

# Load the configuration from the YAML file
with open('/content/drive/MyDrive/base-scalability.yaml', 'r') as file:
    # Parse the YAML file into a Python dictionary
    cfg = yaml.safe_load(file)

# Split the dataset into training loaders for each client and a test loader
raw_train_loader,trainloaders, testloader = split_dataset(
    trainset,                             # The training dataset
    testset,                              # The testing dataset
    cfg['num_clients'],                   # Number of clients specified in the config
    cfg['config_fit']['batch_size'],      # Batch size specified in the config
    partition='noniid-labeldir',          # Type of partitioning (non-IID based on labels)
    dir_alpha=1                           # Dirichlet parameter for non-IID partitioning
)

# %% [markdown]
# ### 3. Initialize all Client Models with ANN Model.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import time


class ANNModel(nn.Module):
    def __init__(self, input_features=8):
        super(ANNModel, self).__init__()

        # Fully connected layers for a simple ANN
        self.fc1 = nn.Linear(input_features, 16)  # First hidden layer with 64 neurons
        self.fc2 = nn.Linear(16, 8)  # Second hidden layer with 32 neurons
        self.fc3 = nn.Linear(8, 1)  # Output layer for binary classification

        # Dropout layer to reduce overfitting
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # Forward pass through fully connected layers with ReLU and dropout
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x


def train(net, trainloader, optimizer, epochs):
    """
    Train a neural network model using a specified optimizer and dataset.
    """
    criterion = nn.BCEWithLogitsLoss()
    net.train()
    start_time = time.time()  # Start time for the training

    for _ in range(epochs):
        for features, labels in trainloader:
            optimizer.zero_grad()
            output = net(features)
            loss = criterion(output.squeeze(1), labels.float())
            loss.backward()
            optimizer.step()

        time.sleep(1)  # Simulate some delay

    end_time = time.time()  # End time for the training
    total_time = end_time - start_time
    return total_time


def evaluate_model(model, test_loader):
    """
    Evaluate a trained neural network model on a test dataset.
    """
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, labels in test_loader:
            outputs = model(data)
            outputs = outputs.squeeze(1)
            loss = F.binary_cross_entropy_with_logits(outputs, labels.float())

            total_loss += loss.item() * data.size(0)
            preds = torch.round(torch.sigmoid(outputs))
            total_correct += (preds == labels).sum().item()
            total_samples += data.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    conf_matrix = confusion_matrix(all_labels, all_preds)

    return avg_loss, accuracy, precision, recall, f1, conf_matrix

# %%
import collections
import statistics
from collections import OrderedDict

class Vehicle():
    """Define a Vehicle Client."""

    def __init__(self, trainloader, id) -> None:
        # the dataloaders that point to the data associated with this client
        self.trainloader = trainloader
        # a model that is randomly initialized at first
        self.model = ANNModel()
        # unique ID for the vehicle
        self.id = id
        print(f"[Vehicle Init] Initialized vehicle client with ID: {self.id}.")
    def __str__(self):
        return f"Vehicle-id={self.id}"

    # If you want a more formal representation, you can also use __repr__:
    def __repr__(self):
        return self.__str__()
    def set_parameters(self, parameters):
        """Receive parameters and apply them to the local model."""
        #print("[set_parameters] Setting parameters for the model...")
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.model.load_state_dict(state_dict, strict=True)
        #print("[set_parameters] Parameters set successfully.")

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""
        #print("[get_parameters] Extracting model parameters...")
        params = [val.cpu().numpy() for _, val in self.model.state_dict().items()]
        #print(f"[get_parameters] Parameters extracted: {len(params)} parameters.")
        return params

    def fit(self, config):
        """Train model received by the server (parameters) using the data
        that belongs to this client. Then, send it back to the server.
        """
        lr = config["lr"]
        momentum = config["momentum"]
        epochs = config["local_epochs"]

        #print(f"[fit] Starting training with ID={self.id}, lr={lr}, momentum={momentum}, epochs={epochs}...")
        optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=momentum, weight_decay=0.01)

        vehicle_time = train(self.model, self.trainloader, optim, epochs)
        #print(f"[fit] Training completed in {vehicle_time} seconds for ID={self.id}.")

        return self.model, len(self.trainloader), vehicle_time#, self.id  # Include ID in the return

def analyze_dataloaders(dataloaders, client_ids):
    """
    Analyze the data distribution of multiple DataLoader objects across different clients.

    This function calculates the label distribution, variance, and number of samples for each client
    from a list of DataLoader objects, which represent the data split for each client. It prints out
    details such as the set of unique labels, the number of samples, and label counts for each client.

    Args:
        dataloaders (list of torch.utils.data.DataLoader): A list of DataLoader objects, where each DataLoader corresponds to a client's data.
        client_ids (list of int or str): A list of client identifiers, which can be integers or strings, corresponding to each DataLoader.

    Returns:
        tuple:
            - label_distribution_per_client (list of list): A list of label distributions for each client. Each element contains the labels from one client's DataLoader.
            - variance_per_client (list of float): A list of variances in label distribution for each client.
            - num_samples_per_client (list of int): A list of the number of samples in each client's dataset.

    Prints:
        - Client ID and associated label information (unique labels, number of samples, label counts).
    """
    print("Analyzing dataloaders...")
    label_distribution_per_client = []
    variance_per_client = []
    num_samples_per_client = []

    for j, dataloader in enumerate(dataloaders):
        labels = []

        for _, batch_labels in dataloader:
            # Append the batch of labels to the list
            labels.extend(batch_labels.tolist())

        label_distribution_per_client.append(labels)
        variance = statistics.variance(labels) if len(labels) > 1 else 0
        variance_per_client.append(variance)
        num_samples = len(labels)
        num_samples_per_client.append(num_samples)

        # Count occurrences of each label
        label_counts = collections.Counter(labels)

        print(f"Client ID: {client_ids[j]}")
        print("Label Category in Vehicle", j, ':', set(labels))
        print("Number of Samples in Vehicle", j, ':', num_samples_per_client[j])
        print("Label Counts in Vehicle", j, ':', dict(label_counts))  # Display value counts for each label
        #print("Variance in Vehicle", j, ':', variance)
        print("*********")


def generate_clients(trainloaders, model):
    """
    Generate client instances from the provided training loaders.

    Args:
        trainloaders (list): A list of DataLoaders for each client's training data.
        model (torch.nn.Module): The model instance to be set for each client.

    Returns:
        list: A list of client instances created from the training loaders.
        list: A list of client IDs corresponding to each created client.
    """
    print(f"Generating clients from {len(trainloaders)} trainloaders...")
    clients = []       # Initialize a list to store client instances
    client_ids = []    # Initialize a list to store client IDs

    # Iterate through the training loaders to create client instances
    for i, trainloader in enumerate(trainloaders):
        cc = Vehicle(trainloader, id=i)  # Create a client instance with the trainloader and a unique ID
        cc.set_parameters(model)           # Set the model parameters for the client
        clients.append(cc)                 # Add the client instance to the list
        client_ids.append(cc.id)           # Store the client ID for reference

    print(f"[generate_clients] Total clients generated: {len(clients)}.\n")
    return clients, client_ids  # Return both the list of clients and their corresponding IDs

# Initialize global model and generate clients
init_global_model = ANNModel()
vehicles, client_ids = generate_clients(trainloaders, init_global_model.state_dict().values())

# Analyze dataloaders and include client IDs
analyze_dataloaders(trainloaders, client_ids)
# Out:
# Generating clients from 60 trainloaders...
# [Vehicle Init] Initialized vehicle client with ID: 0.
# [Vehicle Init] Initialized vehicle client with ID: 1.
# [Vehicle Init] Initialized vehicle client with ID: 2.
# [Vehicle Init] Initialized vehicle client with ID: 3.
# [Vehicle Init] Initialized vehicle client with ID: 4.
# [Vehicle Init] Initialized vehicle client with ID: 5.
# [Vehicle Init] Initialized vehicle client with ID: 6.
# [Vehicle Init] Initialized vehicle client with ID: 7.
# [Vehicle Init] Initialized vehicle client with ID: 8.
# [Vehicle Init] Initialized vehicle client with ID: 9.
# [Vehicle Init] Initialized vehicle client with ID: 10.
# [Vehicle Init] Initialized vehicle client with ID: 11.
# [Vehicle Init] Initialized vehicle client with ID: 12.
# [Vehicle Init] Initialized vehicle client with ID: 13.
# [Vehicle Init] Initialized vehicle client with ID: 14.
# [Vehicle Init] Initialized vehicle client with ID: 15.
# [Vehicle Init] Initialized vehicle client with ID: 16.
# [Vehicle Init] Initialized vehicle client with ID: 17.
# [Vehicle Init] Initialized vehicle client with ID: 18.
# [Vehicle Init] Initialized vehicle client with ID: 19.
# [Vehicle Init] Initialized vehicle client with ID: 20.
# [Vehicle Init] Initialized vehicle client with ID: 21.
# [Vehicle Init] Initialized vehicle client with ID: 22.
# [Vehicle Init] Initialized vehicle client with ID: 23.
# [Vehicle Init] Initialized vehicle client with ID: 24.
# [Vehicle Init] Initialized vehicle client with ID: 25.
# [Vehicle Init] Initialized vehicle client with ID: 26.
# [Vehicle Init] Initialized vehicle client with ID: 27.
# [Vehicle Init] Initialized vehicle client with ID: 28.
# [Vehicle Init] Initialized vehicle client with ID: 29.
# [Vehicle Init] Initialized vehicle client with ID: 30.
# [Vehicle Init] Initialized vehicle client with ID: 31.
# [Vehicle Init] Initialized vehicle client with ID: 32.
# [Vehicle Init] Initialized vehicle client with ID: 33.
# [Vehicle Init] Initialized vehicle client with ID: 34.
# [Vehicle Init] Initialized vehicle client with ID: 35.
# [Vehicle Init] Initialized vehicle client with ID: 36.
# [Vehicle Init] Initialized vehicle client with ID: 37.
# [Vehicle Init] Initialized vehicle client with ID: 38.
# [Vehicle Init] Initialized vehicle client with ID: 39.
# [Vehicle Init] Initialized vehicle client with ID: 40.
# [Vehicle Init] Initialized vehicle client with ID: 41.
# [Vehicle Init] Initialized vehicle client with ID: 42.
# [Vehicle Init] Initialized vehicle client with ID: 43.
# [Vehicle Init] Initialized vehicle client with ID: 44.
# [Vehicle Init] Initialized vehicle client with ID: 45.
# [Vehicle Init] Initialized vehicle client with ID: 46.
# [Vehicle Init] Initialized vehicle client with ID: 47.
# [Vehicle Init] Initialized vehicle client with ID: 48.
# [Vehicle Init] Initialized vehicle client with ID: 49.
# [Vehicle Init] Initialized vehicle client with ID: 50.
# [Vehicle Init] Initialized vehicle client with ID: 51.
# [Vehicle Init] Initialized vehicle client with ID: 52.
# [Vehicle Init] Initialized vehicle client with ID: 53.
# [Vehicle Init] Initialized vehicle client with ID: 54.
# [Vehicle Init] Initialized vehicle client with ID: 55.
# [Vehicle Init] Initialized vehicle client with ID: 56.
# [Vehicle Init] Initialized vehicle client with ID: 57.
# [Vehicle Init] Initialized vehicle client with ID: 58.
# [Vehicle Init] Initialized vehicle client with ID: 59.
# [generate_clients] Total clients generated: 60.
#
# Analyzing dataloaders...
# Client ID: 0
# Label Category in Vehicle 0 : {0.0, 1.0}
# Number of Samples in Vehicle 0 : 1204
# Label Counts in Vehicle 0 : {0.0: 572, 1.0: 632}
# *********
# Client ID: 1
# Label Category in Vehicle 1 : {0.0, 1.0}
# Number of Samples in Vehicle 1 : 14567
# Label Counts in Vehicle 1 : {1.0: 4115, 0.0: 10452}
# *********
# Client ID: 2
# Label Category in Vehicle 2 : {0.0}
# Number of Samples in Vehicle 2 : 11158
# Label Counts in Vehicle 2 : {0.0: 11158}
# *********
# Client ID: 3
# Label Category in Vehicle 3 : {0.0, 1.0}
# Number of Samples in Vehicle 3 : 12601
# Label Counts in Vehicle 3 : {1.0: 8523, 0.0: 4078}
# *********
# Client ID: 4
# Label Category in Vehicle 4 : {0.0, 1.0}
# Number of Samples in Vehicle 4 : 8783
# Label Counts in Vehicle 4 : {1.0: 5899, 0.0: 2884}
# *********
# Client ID: 5
# Label Category in Vehicle 5 : {0.0}
# Number of Samples in Vehicle 5 : 20376
# Label Counts in Vehicle 5 : {0.0: 20376}
# *********
# Client ID: 6
# Label Category in Vehicle 6 : {0.0, 1.0}
# Number of Samples in Vehicle 6 : 12299
# Label Counts in Vehicle 6 : {1.0: 7088, 0.0: 5211}
# *********
# Client ID: 7
# Label Category in Vehicle 7 : {0.0}
# Number of Samples in Vehicle 7 : 14659
# Label Counts in Vehicle 7 : {0.0: 14659}
# *********
# Client ID: 8
# Label Category in Vehicle 8 : {0.0, 1.0}
# Number of Samples in Vehicle 8 : 9399
# Label Counts in Vehicle 8 : {0.0: 4320, 1.0: 5079}
# *********
# Client ID: 9
# Label Category in Vehicle 9 : {0.0, 1.0}
# Number of Samples in Vehicle 9 : 3292
# Label Counts in Vehicle 9 : {0.0: 2255, 1.0: 1037}
# *********
# Client ID: 10
# Label Category in Vehicle 10 : {0.0}
# Number of Samples in Vehicle 10 : 14235
# Label Counts in Vehicle 10 : {0.0: 14235}
# *********
# Client ID: 11
# Label Category in Vehicle 11 : {0.0, 1.0}
# Number of Samples in Vehicle 11 : 9069
# Label Counts in Vehicle 11 : {0.0: 6608, 1.0: 2461}
# *********
# Client ID: 12
# Label Category in Vehicle 12 : {0.0, 1.0}
# Number of Samples in Vehicle 12 : 3842
# Label Counts in Vehicle 12 : {0.0: 2481, 1.0: 1361}
# *********
# Client ID: 13
# Label Category in Vehicle 13 : {0.0, 1.0}
# Number of Samples in Vehicle 13 : 5800
# Label Counts in Vehicle 13 : {0.0: 4358, 1.0: 1442}
# *********
# Client ID: 14
# Label Category in Vehicle 14 : {0.0, 1.0}
# Number of Samples in Vehicle 14 : 9334
# Label Counts in Vehicle 14 : {0.0: 6334, 1.0: 3000}
# *********
# Client ID: 15
# Label Category in Vehicle 15 : {0.0, 1.0}
# Number of Samples in Vehicle 15 : 1857
# Label Counts in Vehicle 15 : {0.0: 1722, 1.0: 135}
# *********
# Client ID: 16
# Label Category in Vehicle 16 : {0.0}
# Number of Samples in Vehicle 16 : 11260
# Label Counts in Vehicle 16 : {0.0: 11260}
# *********
# Client ID: 17
# Label Category in Vehicle 17 : {0.0, 1.0}
# Number of Samples in Vehicle 17 : 7548
# Label Counts in Vehicle 17 : {0.0: 6919, 1.0: 629}
# *********
# Client ID: 18
# Label Category in Vehicle 18 : {0.0, 1.0}
# Number of Samples in Vehicle 18 : 38873
# Label Counts in Vehicle 18 : {1.0: 31706, 0.0: 7167}
# *********
# Client ID: 19
# Label Category in Vehicle 19 : {0.0, 1.0}
# Number of Samples in Vehicle 19 : 24045
# Label Counts in Vehicle 19 : {1.0: 21203, 0.0: 2842}
# *********
# Client ID: 20
# Label Category in Vehicle 20 : {0.0, 1.0}
# Number of Samples in Vehicle 20 : 45844
# Label Counts in Vehicle 20 : {1.0: 44424, 0.0: 1420}
# *********
# Client ID: 21
# Label Category in Vehicle 21 : {0.0, 1.0}
# Number of Samples in Vehicle 21 : 18207
# Label Counts in Vehicle 21 : {1.0: 13875, 0.0: 4332}
# *********
# Client ID: 22
# Label Category in Vehicle 22 : {0.0, 1.0}
# Number of Samples in Vehicle 22 : 4757
# Label Counts in Vehicle 22 : {0.0: 4151, 1.0: 606}
# *********
# Client ID: 23
# Label Category in Vehicle 23 : {0.0, 1.0}
# Number of Samples in Vehicle 23 : 14453
# Label Counts in Vehicle 23 : {0.0: 8302, 1.0: 6151}
# *********
# Client ID: 24
# Label Category in Vehicle 24 : {0.0, 1.0}
# Number of Samples in Vehicle 24 : 2405
# Label Counts in Vehicle 24 : {1.0: 1507, 0.0: 898}
# *********
# Client ID: 25
# Label Category in Vehicle 25 : {0.0}
# Number of Samples in Vehicle 25 : 19960
# Label Counts in Vehicle 25 : {0.0: 19960}
# *********
# Client ID: 26
# Label Category in Vehicle 26 : {0.0, 1.0}
# Number of Samples in Vehicle 26 : 4406
# Label Counts in Vehicle 26 : {0.0: 3875, 1.0: 531}
# *********
# Client ID: 27
# Label Category in Vehicle 27 : {0.0, 1.0}
# Number of Samples in Vehicle 27 : 4432
# Label Counts in Vehicle 27 : {0.0: 3920, 1.0: 512}
# *********
# Client ID: 28
# Label Category in Vehicle 28 : {0.0, 1.0}
# Number of Samples in Vehicle 28 : 5116
# Label Counts in Vehicle 28 : {1.0: 4593, 0.0: 523}
# *********
# Client ID: 29
# Label Category in Vehicle 29 : {0.0, 1.0}
# Number of Samples in Vehicle 29 : 7131
# Label Counts in Vehicle 29 : {1.0: 4010, 0.0: 3121}
# *********
# Client ID: 30
# Label Category in Vehicle 30 : {0.0, 1.0}
# Number of Samples in Vehicle 30 : 21614
# Label Counts in Vehicle 30 : {0.0: 8116, 1.0: 13498}
# *********
# Client ID: 31
# Label Category in Vehicle 31 : {0.0, 1.0}
# Number of Samples in Vehicle 31 : 10858
# Label Counts in Vehicle 31 : {0.0: 3894, 1.0: 6964}
# *********
# Client ID: 32
# Label Category in Vehicle 32 : {0.0, 1.0}
# Number of Samples in Vehicle 32 : 9160
# Label Counts in Vehicle 32 : {1.0: 4726, 0.0: 4434}
# *********
# Client ID: 33
# Label Category in Vehicle 33 : {0.0, 1.0}
# Number of Samples in Vehicle 33 : 11899
# Label Counts in Vehicle 33 : {1.0: 4187, 0.0: 7712}
# *********
# Client ID: 34
# Label Category in Vehicle 34 : {0.0, 1.0}
# Number of Samples in Vehicle 34 : 5223
# Label Counts in Vehicle 34 : {0.0: 4731, 1.0: 492}
# *********
# Client ID: 35
# Label Category in Vehicle 35 : {0.0, 1.0}
# Number of Samples in Vehicle 35 : 15004
# Label Counts in Vehicle 35 : {1.0: 13313, 0.0: 1691}
# *********
# Client ID: 36
# Label Category in Vehicle 36 : {0.0}
# Number of Samples in Vehicle 36 : 12233
# Label Counts in Vehicle 36 : {0.0: 12233}
# *********
# Client ID: 37
# Label Category in Vehicle 37 : {0.0, 1.0}
# Number of Samples in Vehicle 37 : 17685
# Label Counts in Vehicle 37 : {1.0: 12824, 0.0: 4861}
# *********
# Client ID: 38
# Label Category in Vehicle 38 : {0.0, 1.0}
# Number of Samples in Vehicle 38 : 2443
# Label Counts in Vehicle 38 : {1.0: 2228, 0.0: 215}
# *********
# Client ID: 39
# Label Category in Vehicle 39 : {0.0, 1.0}
# Number of Samples in Vehicle 39 : 5517
# Label Counts in Vehicle 39 : {0.0: 1126, 1.0: 4391}
# *********
# Client ID: 40
# Label Category in Vehicle 40 : {0.0, 1.0}
# Number of Samples in Vehicle 40 : 3295
# Label Counts in Vehicle 40 : {1.0: 1532, 0.0: 1763}
# *********
# Client ID: 41
# Label Category in Vehicle 41 : {0.0, 1.0}
# Number of Samples in Vehicle 41 : 9595
# Label Counts in Vehicle 41 : {0.0: 4487, 1.0: 5108}
# *********
# Client ID: 42
# Label Category in Vehicle 42 : {0.0, 1.0}
# Number of Samples in Vehicle 42 : 11504
# Label Counts in Vehicle 42 : {0.0: 9549, 1.0: 1955}
# *********
# Client ID: 43
# Label Category in Vehicle 43 : {0.0, 1.0}
# Number of Samples in Vehicle 43 : 33411
# Label Counts in Vehicle 43 : {1.0: 24148, 0.0: 9263}
# *********
# Client ID: 44
# Label Category in Vehicle 44 : {0.0, 1.0}
# Number of Samples in Vehicle 44 : 5195
# Label Counts in Vehicle 44 : {0.0: 1388, 1.0: 3807}
# *********
# Client ID: 45
# Label Category in Vehicle 45 : {0.0, 1.0}
# Number of Samples in Vehicle 45 : 5601
# Label Counts in Vehicle 45 : {0.0: 860, 1.0: 4741}
# *********
# Client ID: 46
# Label Category in Vehicle 46 : {0.0, 1.0}
# Number of Samples in Vehicle 46 : 11161
# Label Counts in Vehicle 46 : {1.0: 9985, 0.0: 1176}
# *********
# Client ID: 47
# Label Category in Vehicle 47 : {0.0, 1.0}
# Number of Samples in Vehicle 47 : 20484
# Label Counts in Vehicle 47 : {1.0: 13010, 0.0: 7474}
# *********
# Client ID: 48
# Label Category in Vehicle 48 : {0.0, 1.0}
# Number of Samples in Vehicle 48 : 8046
# Label Counts in Vehicle 48 : {0.0: 3534, 1.0: 4512}
# *********
# Client ID: 49
# Label Category in Vehicle 49 : {0.0, 1.0}
# Number of Samples in Vehicle 49 : 8429
# Label Counts in Vehicle 49 : {1.0: 8397, 0.0: 32}
# *********
# Client ID: 50
# Label Category in Vehicle 50 : {0.0, 1.0}
# Number of Samples in Vehicle 50 : 22766
# Label Counts in Vehicle 50 : {0.0: 4236, 1.0: 18530}
# *********
# Client ID: 51
# Label Category in Vehicle 51 : {0.0, 1.0}
# Number of Samples in Vehicle 51 : 7829
# Label Counts in Vehicle 51 : {0.0: 6421, 1.0: 1408}
# *********
# Client ID: 52
# Label Category in Vehicle 52 : {0.0, 1.0}
# Number of Samples in Vehicle 52 : 4201
# Label Counts in Vehicle 52 : {0.0: 2784, 1.0: 1417}
# *********
# Client ID: 53
# Label Category in Vehicle 53 : {0.0, 1.0}
# Number of Samples in Vehicle 53 : 296
# Label Counts in Vehicle 53 : {0.0: 78, 1.0: 218}
# *********
# Client ID: 54
# Label Category in Vehicle 54 : {0.0, 1.0}
# Number of Samples in Vehicle 54 : 2505
# Label Counts in Vehicle 54 : {1.0: 1862, 0.0: 643}
# *********
# Client ID: 55
# Label Category in Vehicle 55 : {0.0, 1.0}
# Number of Samples in Vehicle 55 : 11544
# Label Counts in Vehicle 55 : {0.0: 9883, 1.0: 1661}
# *********
# Client ID: 56
# Label Category in Vehicle 56 : {0.0, 1.0}
# Number of Samples in Vehicle 56 : 9787
# Label Counts in Vehicle 56 : {0.0: 8087, 1.0: 1700}
# *********
# Client ID: 57
# Label Category in Vehicle 57 : {0.0, 1.0}
# Number of Samples in Vehicle 57 : 1070
# Label Counts in Vehicle 57 : {0.0: 1048, 1.0: 22}
# *********
# Client ID: 58
# Label Category in Vehicle 58 : {0.0, 1.0}
# Number of Samples in Vehicle 58 : 4275
# Label Counts in Vehicle 58 : {0.0: 2487, 1.0: 1788}
# *********
# Client ID: 59
# Label Category in Vehicle 59 : {0.0, 1.0}
# Number of Samples in Vehicle 59 : 8818
# Label Counts in Vehicle 59 : {1.0: 5352, 0.0: 3466}
# *********

# %% [markdown]
# ### Assign client models to edge servers and initiate the Edge server with ANN Model parameters
#
# - Before training (initialization):
#   - The global model's initial parameters are distributed to edge servers using `set_parameters`.
# - After local training:
#   - `aggregate_local_models` should be called to aggregate the trained models from all vehicles and update the edge server’s model.

# %%
import random
import copy

def divide_list_randomly(lst, M):
    """
    Divide a list into M random sublists.

    Args:
        lst (list): The list to be divided.
        M (int): The number of sublists to create.

    Returns:
        list: A list of M sublists created from the original list.

    Raises:
        ValueError: If M is greater than the number of elements in the list.
    """
    # Print the size of the list and the number of sublists to be created (commented out for cleaner output)
    # print(f"[divide_list_randomly] Dividing list of size {len(lst)} into {M} random sublists...")
    N = len(lst)

    if M > N:
        raise ValueError("M cannot be greater than the number of elements in the list")

    # Generate M-1 unique random indices to split the list
    indices = sorted(random.sample(range(1, N), M - 1))

    # Include the start and end indices for complete slicing
    indices = [0] + indices + [N]

    # Create sublists based on the generated indices
    sublists = [lst[indices[i]:indices[i + 1]] for i in range(len(indices) - 1)]
    print(f"Spread {N} clients across {len(sublists)} edges, with each edge receiving a subset of clients.")
    return sublists

def weighted_aggregation(w, agg_weights):
    """
    Perform weighted aggregation of model weights.

    Args:
        w (list): A list of models (state_dicts) to be aggregated.
        agg_weights (list): A list of weights corresponding to each model.

    Returns:
        dict: The aggregated weights as a state_dict.

    This function computes a weighted average of the model weights based on the provided aggregation weights.
    """
    # Print start of the aggregation process (commented out for cleaner output)
    # print("[weighted_aggregation] Starting weighted aggregation...")
    w_avg = copy.deepcopy(w[0].state_dict())    # Initialize the average weights with the first model's weights
    total_agg_weights = sum(agg_weights)        # Calculate the total of aggregation weights

    # Compute the initial weighted contribution of the first model
    for key in w_avg.keys():
        w_avg[key] *= (agg_weights[0] / total_agg_weights)

    # Accumulate weighted contributions from the other models
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i].state_dict()[key] * (agg_weights[i] / total_agg_weights)

    print("[weighted_aggregation] Weighted aggregation completed.")
    return w_avg

# %%
class EdgeServer:
    def __init__(self, vehicles, config, edge_id):  # Removed cache_size
        self.edge_id = edge_id
        self.vehicles = vehicles
        self.local_model_storage = []
        self.agg_weight = []
        self.model = ANNModel()
        self.config = config

    def start_training_vehicles(self):
        local_model_storage = []
        agg_weight = []
        edge_time = 0

        def train_vehicle(vehicle):
            vehicle.set_parameters(self.model.state_dict().values())
            w_vehicle, data_size_vehicle, vehicle_time = vehicle.fit(self.config)
            print(f"[{self.edge_id}] Vehicle {vehicle.id} trained with time: {vehicle_time:.2f} seconds")
            return w_vehicle, data_size_vehicle, vehicle_time, vehicle.id

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = [executor.submit(train_vehicle, vehicle) for vehicle in self.vehicles]

            # Wait for ALL vehicles to complete (no cache limit)
            for future in concurrent.futures.as_completed(futures):
                w_vehicle, data_size_vehicle, vehicle_time, _ = future.result()
                local_model_storage.append(w_vehicle)
                agg_weight.append(data_size_vehicle)
                edge_time = max(edge_time, vehicle_time)

        self.local_model_storage = local_model_storage
        self.agg_weight = agg_weight
        print(f"[{self.edge_id}] All {len(self.vehicles)} vehicles trained.")
        return edge_time, self.local_model_storage, self.agg_weight

    def aggregate_local_models(self):
        # Aggregate ALL local models
        parameters = weighted_aggregation(self.local_model_storage, self.agg_weight)
        self.set_parameters(parameters.values())
        print(f"[{self.edge_id}] Aggregated ALL {len(self.local_model_storage)} models.")


    def set_parameters(self, parameters):
        """Receive parameters and apply them to the local model."""
        #print(f"[{self.edge_id}] Setting parameters for the model...")
        params_dict = zip(self.model.state_dict().keys(), parameters)

        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})

        self.model.load_state_dict(state_dict, strict=True)
        print(f"[{self.edge_id}] Parameters set.")

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""
        #print(f"[{self.edge_id}] Extracting model parameters...")
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def update_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.set_parameters(self.get_parameters())

# %%
import random

def divide_list_randomly(lst, M):
    """
    Divide a list into M random sublists with each sublist having at least one element.

    Args:
        lst (list): The list to be divided.
        M (int): The number of sublists to create.

    Returns:
        list: A list of M sublists created from the original list.

    Raises:
        ValueError: If M is greater than the number of elements in the list.
    """
    N = len(lst)

    if M > N:
        raise ValueError("M cannot be greater than the number of elements in the list")

    # Shuffle the original list to randomize the indices
    shuffled_list = lst[:]
    random.shuffle(shuffled_list)

    # Allocate 1 element to each sublist to ensure the condition
    sublist_sizes = [1] * M
    remaining_elements = N - M

    # Distribute remaining elements randomly across the sublists
    for _ in range(remaining_elements):
        sublist_sizes[random.randint(0, M - 1)] += 1

    # Divide the shuffled list into M random sublists based on generated sizes
    sublists = []
    start = 0
    for size in sublist_sizes:
        sublists.append(shuffled_list[start:start + size])
        start += size

    print(f"Spread {N} clients across {M} edges, with each edge receiving a random subset of clients.")
    return sublists

def spawn_edge_servers(vehicles, num_edges, config, parameters):
    """
    Spawns a specified number of edge servers, each assigned a subset of vehicles.

    Args:
        vehicles (list): List of vehicle instances to be managed by edge servers.
        num_edges (int): Number of edge servers to spawn.
        config (dict): Configuration parameters for the edge servers.
        parameters (dict): Parameters to set for the edge servers' models.

    Returns:
        tuple: A tuple containing:
            - edge_servers (list): List of spawned EdgeServer instances.
            - edge_server_vehicle_map (dict): Mapping of edge server IDs to their respective vehicle IDs.
    """
    # print(f"[spawn_edge_servers] Spawning {num_edges} edge servers...")

    # Create a dictionary to hold the mapping from edge servers to vehicles
    edge_server_vehicle_map = {}

    edge_servers = []  # List to store edge server instances
    # Divide the vehicles randomly among the edge servers
    vehicles_per_edge = divide_list_randomly(vehicles, num_edges)

    for i in range(num_edges):
        # Create an EdgeServer instance for each edge server
        edge = EdgeServer(vehicles_per_edge[i], config, f"edge-{i}")

        edge.set_parameters(parameters)  # Set the model parameters for the edge server
        edge_servers.append(edge)  # Add the edge server to the list

        # Get IDs of vehicles assigned to the current edge server
        vehicle_ids = [vehicle.id for vehicle in vehicles_per_edge[i]]
        # Map the edge server ID to its corresponding vehicle IDs
        edge_server_vehicle_map[f"edge-{i}"] = vehicle_ids

    # print(f"[spawn_edge_servers] Spawned {len(edge_servers)} edge servers.")
    print(f"[spawn_edge_servers] Vehicle mapping to edge servers: {edge_server_vehicle_map}")

    return edge_servers, edge_server_vehicle_map  # Return the list of edge servers and their vehicle mappings

# %%
## Define the edge servers and the cloud server
# Spawn edge servers and map vehicle IDs
edge_servers, edge_server_vehicle_map = spawn_edge_servers(vehicles, cfg['num_edges'], cfg['config_fit'], init_global_model.state_dict().values())
# Out:
# Spread 60 clients across 10 edges, with each edge receiving a random subset of clients.
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [spawn_edge_servers] Vehicle mapping to edge servers: {'edge-0': [38, 23, 54, 11], 'edge-1': [16, 20, 55, 58, 33, 19], 'edge-2': [9, 36, 31, 45, 30, 49], 'edge-3': [3, 21, 50, 4, 29, 10, 59, 22, 41, 24, 0], 'edge-4': [44, 25, 52, 18, 28, 39, 26], 'edge-5': [48, 12, 35, 42, 32, 53, 13, 46], 'edge-6': [57, 2, 27, 37, 5], 'edge-7': [34, 51, 43, 6, 56], 'edge-8': [8, 14, 15], 'edge-9': [17, 47, 1, 7, 40]}

# %% [markdown]
# ### Initiate Cloud Server Model and set up the Global Model parameters with ANN Model

# %%
class CloudServer:
    """
    Modified Cloud Server for SFL1 with cache-based aggregation.
    """
    def __init__(self, edge_servers):
        self.edge_servers = edge_servers
        self.model = ANNModel()
        #self.cache = []  # Stores sub-global models from edges
        print(f"[CloudServer] Initialized.")

    def update_global_model(self):
        # Aggregate ALL sub-global models
        sub_global_models = [edge.model for edge in self.edge_servers]
        agg_weights = [sum(edge.agg_weight) for edge in self.edge_servers]  # Weight by total data

        aggregated_params = weighted_aggregation(sub_global_models, agg_weights).values()
        self.set_parameters(aggregated_params)
        print(f"[Cloud] Aggregated ALL {len(sub_global_models)} edge models.")

  #  def receive_sub_global_model(self, edge_params):
  #      """Receive sub-global model from an edge server and update cache."""
  #      if len(self.cache) < self.cloud_cache_size:
  #          self.cache.append(edge_params)
  #          print(f"[CloudServer] Received sub-global model. Cache size: {len(self.cache)}")
  #      else:
  #          print("[CloudServer] Cache full. Discarding sub-global model.")

    def set_parameters(self, parameters):
        """
        Receives parameters and applies them to the local model.

        Args:
            parameters (iterable): The parameters to set in the model.
        """
        # Create a state dict from the provided parameters and load into the model
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.model.load_state_dict(state_dict, strict=True)  # Load parameters into the model
        print("[set_parameters] Parameters set to the model.")

    def get_parameters(self):
        """
        Extracts the model parameters and returns them as a list of numpy arrays.

        Returns:
            list: A list of model parameters as numpy arrays.
        """
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]  # Return parameters as numpy arrays

    def update_edge_servers(self):
        """
        Updates all edge servers with the global model parameters.

        This method sends the current global model parameters to each edge server
        to ensure they have the latest updates.
        """
        print("[update_edge_servers] Updating edge servers with global parameters...")
        for edge_server in self.edge_servers:
            edge_server.set_parameters(self.get_parameters())  # Update edge server with global parameters
        print("[update_edge_servers] Edge servers updated.")

# %%
cloud_server = CloudServer(edge_servers)
# Out:
# [CloudServer] Initialized.

# %% [markdown]
# ### Run the Ensuring Completion Algorithm

# %%
import matplotlib.pyplot as plt
import shap
def shap_method(model, method_name, x_train, x_test):
    """
    Generates SHAP (SHapley Additive exPlanations) summary plot for a given model and saves the results.

    This function computes SHAP values for a given trained model and test data using the DeepExplainer,
    creates a summary plot for feature importance, and saves the plot to a specified directory.

    Args:
        model (torch.nn.Module): The trained PyTorch model to be explained.
        method_name (str): The name of the method, used for naming and organizing output files.
        x_train (torch.Tensor): The training data tensor, used by the SHAP explainer to compute expected outputs.
        x_test (torch.Tensor): The test data tensor, used to compute SHAP values and generate the summary plot.

    Returns:
        None: The function saves the SHAP summary plot to the specified directory and prints the path to the saved plot.

    Side Effects:
        - Saves a SHAP summary plot as a PNG image in the specified directory.
        - Displays the SHAP plot inline (if running in an environment that supports plotting).
    """
    # Create the directory for saving SHAP results
    path = f"/content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/shap_results"
    os.makedirs(path, exist_ok=True)

    model.eval()
    explainer = shap.DeepExplainer(model, x_train)

    # Calculate SHAP values
    shap_values = explainer.shap_values(x_test, check_additivity=False)

    # Reshape SHAP values if needed
    shap_values_reshaped = shap_values.squeeze()

    feature_names=['DATA_0','DATA_1','DATA_2','DATA_3','DATA_4','DATA_5','DATA_6','DATA_7']
    # Summary plot
    shap.summary_plot(shap_values_reshaped, x_test.numpy(), show=False,feature_names=feature_names)

    # Save the summary plot in the specified path
    plt.savefig(os.path.join(path, f'shap_summary_{method_name}.png'), bbox_inches='tight')

    # Show the summary plot
    plt.show()  # This will display the plot in the output
    plt.close()  # Close the plot to free memory
    print(f'SHAP summary plot saved as {os.path.join(path, f"shap_summary_{method_name}.png")}')


# Function to save the model with a specified name format
def save_model(model, round_num, method_name, file_path="model_checkpoint"):
    path=f"/content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/{method_name}"
    os.makedirs(path, exist_ok=True)
    model_name = f"{path}/model_{method_name}_round_{round_num}.pth"
    torch.save(model.state_dict(), model_name)
    print(f"Model saved as {model_name}")

# %%
def launch_training_edge_server(edge):
    """Launches training for an edge server with Ensuring Completion."""
    print(f"[SFL1] Launching training for edge {edge.edge_id}.")
    etime, lms, agw = edge.start_training_vehicles()
    return (edge.edge_id, edge.vehicles, etime, lms, agw)


def ensuring_completion(edge_servers, cloud_server, round_num):
    """
    Manages the completion of training across all edge servers, updating the global model
    and distributing it back to the edge servers.

    Args:
        edge_servers (list): List of edge servers participating in the training process.
        cloud_server (CloudServer): The central cloud server managing the global model.
        round_num (int): The current round of training.

    Returns:
        list: A list of results containing edge server IDs, associated vehicles, training time,
              local model storage, and aggregation weights for each edge server.
    """
    print(f"\nStarting the training process for round {round_num} on edge servers...\n")

    edge_results = []  # To store results from each edge server's training process

    # Launching training on all edge servers in parallel using ProcessPoolExecutor
    with concurrent.futures.ProcessPoolExecutor() as executor:
        print("Launching training on edge servers...")
        results = list(executor.map(launch_training_edge_server, edge_servers))

    print("Training completed on edge servers. Collecting results...")

    # Collecting the training results from each edge server
    for result in results:
        edge_id, vehicles, edge_time, lms, agw = result
        edge_results.append({
            "edge_id": edge_id,
            "vehicles": vehicles,
            "training_time": edge_time,
            "local_model_storage": lms,
            "agg_weight": agw
        })

    # Updating the local models and aggregation weights for each edge server
    for result in edge_results:
        edge_id = result['edge_id']
        edge = next(edge for edge in edge_servers if edge.edge_id == edge_id)

        print(f"\nUpdating edge server {edge_id} with local model storage and aggregation weights...")
        edge.local_model_storage = result['local_model_storage']  # Set local models
        edge.agg_weight = result['agg_weight']  # Set aggregation weights

        # Aggregate the local models on each edge server
        print(f"Aggregating local models for edge server {edge_id}...")
        edge.aggregate_local_models()

        #print(f"Edge server {edge_id} has vehicles: {result['vehicles']}, training time: {result['training_time']} seconds")

    # Update the global model on the cloud server
    print("\nUpdating global model on the cloud server...")
    cloud_server.update_global_model()

    # Distribute the updated global model back to the edge servers
    cloud_server.update_edge_servers()

    # Update the vehicles associated with each edge server with the global model
    for edge in edge_servers:
        print(f"Updating vehicles for edge server {edge.edge_id}...")
        edge.update_vehicles()

    # Print a summary for the round
    print(f"\nRound {round_num} summary:")
    for result in edge_results:
        print(f"Edge {result['edge_id']} associated vehicles: {result['vehicles']}")

    return edge_results

# %%
# Function to generate LIME explanation
def generate_lime_explanation(x_train_tensor, x_test_tensor, model, method_name, random_instance=True, instance_index=None):
    """
    Generate LIME explanations for a model and save the plot.

    Parameters:
    - x_train_tensor: Training data as a PyTorch tensor
    - x_test_tensor: Test data as a PyTorch tensor
    - model: The PyTorch model to explain
    - method_name: The name of the LIME method for labeling
    - random_instance: Whether to select a random instance from the test set
    - instance_index: Specific index of the instance to explain (optional)
    """

    # Create the directory for saving LIME results
    save_path = f"/content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/lime_results"
    os.makedirs(save_path, exist_ok=True)

    # Convert tensors to NumPy arrays
    x_train_np = x_train_tensor.numpy()
    x_test_np = x_test_tensor.numpy()

    # Get feature names (assuming 8 features)
    num_features = x_train_np.shape[1]
    #features = [f"Feature {i+1}" for i in range(num_features)]
    features=["DATA_0",	"DATA_1",	"DATA_2",	"DATA_3",	"DATA_4",	"DATA_5",	"DATA_6",	"DATA_7"]
    # Ensure the model is in evaluation mode
    model.eval()

    # Randomly select an instance from the test dataset, or use a specific index if provided
    if random_instance:
        instance_index = random.randint(0, len(x_test_np) - 1)
    instance_index=153709
    selected_instance = x_test_np[instance_index]

    # Create a LIME explainer for tabular data
    explainer = LimeTabularExplainer(x_train_np, feature_names=features, class_names=['Normal', 'Attack'],
                                     discretize_continuous=True)

    # Modified cnn_predict function to return probabilities for binary classification
    def cnn_predict(input_data):
        """
        Modified cnn_predict function to return probabilities for binary classification.

        Args:
        input_data (list of NumPy arrays): Input data to make predictions on.

        Returns:
        probabilities (NumPy array): Predicted probabilities for the positive class.
        """

        # Convert the input_data (list of NumPy arrays) to a single NumPy array before creating the tensor
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)

        # Ensure the model is in evaluation mode
        model.eval()

        with torch.no_grad():
            output = model(input_tensor)

            # Check for NaN or infinity values in the output
            if torch.isnan(output).any() or torch.isinf(output).any():
                raise ValueError("Model output contains NaN or infinity values.")

            # Apply sigmoid to get probabilities
            probabilities = torch.sigmoid(output).numpy()

        # Convert to 2-class probabilities (positive class and negative class)
        probabilities = np.hstack([1 - probabilities, probabilities])

        # Check for constant predictions
        if np.all(probabilities == probabilities[0]):
            print("Warning: Model returned constant predictions.")

        return probabilities

    # Generate LIME explanation for the selected instance with more samples (increased to 10000)
    explanation = explainer.explain_instance(selected_instance, cnn_predict, num_features=num_features, num_samples=10000)

    # Save the plot
    plot_path = f"{save_path}lime_explanation_{method_name}.png"
    explanation.as_pyplot_figure()
    #plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})-{method_name}-Global Model")
    plt.savefig(plot_path, bbox_inches='tight')
    plt.show()  # This will display the plot in the output
    plt.close()
    print(f"LIME explanation plot saved to {plot_path}")

    return explanation, selected_instance, instance_index

# Function to calculate local fidelity (R² score)
def evaluate_local_fidelity(explanation, model, selected_instance):
    # Get LIME's surrogate predictions
    lime_surrogate_predictions = explanation.local_pred

    # Get CNN model's predictions for the selected instance
    def cnn_predict(input_data):
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)
        with torch.no_grad():
            output = torch.sigmoid(model(input_tensor)).numpy()
        return output

    cnn_predictions = cnn_predict([selected_instance])[0]

    # Check for constant predictions
    if np.all(cnn_predictions == cnn_predictions[0]):
        print("Warning: Model returned constant predictions. R² score cannot be calculated.")
        return np.nan

    # Calculate R² score to measure local fidelity
    local_fidelity = r2_score(cnn_predictions, lime_surrogate_predictions)

    return local_fidelity

# Function to plot feature importance
def plot_feature_importance(explanation, instance_index):
    # Plot the feature importance from LIME
    explanation.as_pyplot_figure()
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.show()

def plot_confusion_matrix(cm, title='Confusion Matrix', class_labels=['Normal', 'Attack'], figsize=(8, 6)):
    """
    Plots a confusion matrix using seaborn heatmap.

    Args:
    cm (numpy.ndarray): Confusion matrix (2x2) array.
    title (str): Title of the plot.
    class_labels (list): Custom labels for the classes.
    figsize (tuple): Size of the figure.

    Returns:
    None
    """
    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16}, linewidths=0.5)

    # Add labels, title, and axes
    plt.xlabel('Target (Actual Class)', fontsize=12)
    plt.ylabel('Output (Predicted Class)', fontsize=12)
    plt.title(title, fontsize=14)

    # Custom tick labels for the classes
    plt.xticks([0.5, 1.5], class_labels, rotation=0)
    plt.yticks([0.5, 1.5], class_labels, rotation=0)

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
def run_fl_training(cfg, cloud_server, edge_servers,train_loader, testloader, X_train_tensor, X_test_tensor, method_name,  save_path="model_checkpoint"):
    """
    Run the Federated Learning (FL) training loop with multiple rounds and evaluate the global model performance.

    Args:
        cfg (dict): Configuration settings for the FL training, including the number of rounds.
        cloud_server (CloudServer): The cloud server that coordinates model aggregation and updates with edge servers.
        edge_servers (list): List of EdgeServer objects responsible for training local models using vehicle data.
        testloader (DataLoader): DataLoader object for the test dataset, used to evaluate the global model.
        X_train_tensor (torch.Tensor): Tensor containing a sample of the training data for SHAP analysis.
        X_test_tensor (torch.Tensor): Tensor containing a sample of the test data for SHAP analysis.
        method_name (str): The name of the method used for saving models and results.
        save_path (str, optional): Directory path where the models will be saved. Defaults to "model_checkpoint".

    Returns:
        None: This function does not return any value. It saves models and results at each round of FL, performs evaluation, and stores SHAP analysis.

    The training process includes:
        - Running multiple rounds of training across edge servers.
        - Aggregating the results at the cloud server.
        - Evaluating the global model after each round.
        - Logging the time taken for each round and total training time.
        - Saving the model checkpoints after each round.
        - Saving round results to a CSV file for further analysis.
        - Running SHAP analysis on the final global model to assess feature importance.

    The function outputs the following at each round:
        - Loss, Accuracy, Precision, Recall, F1 Score for the global model.
        - Total round time and overall training time.
        - A final SHAP analysis of the trained global model.
    """
    fl_time = []
    round_results = []
    train_losses = []  # Track training loss for each round
    test_losses = []   # Track testing loss for each round
    results_path = f"/content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/results"
    os.makedirs(results_path, exist_ok=True)

    start_time = time.time()
    total_time = 0

    for round_num in range(cfg['num_rounds']):
        print(f'\n  FL Global Training Round SFL1: {round_num + 1} \n')

        round_start_time = time.time()  # Start time for this round

        # Ensuring completion and collecting results
        edge_results = ensuring_completion(edge_servers, cloud_server, round_num + 1)

        # Calculate the total time for this round
        total_round_time = time.time() - round_start_time  # Calculate round time
        fl_time.append(total_round_time)  # Store round time
        total_time += total_round_time ## Total time

        # Evaluating model performance
        loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
        print(f'Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 = {f1}, Total Time for  {round_num + 1}= {total_round_time:.2f} seconds')

        train_loss, _, _, _, _, _ = evaluate_model(cloud_server.model,train_loader)
        train_losses.append(train_loss)
        test_losses.append(loss)
        # Saving the model after each round
        save_model(cloud_server.model, round_num + 1, method_name, file_path=save_path)

        # Collecting round results
        round_results.append({
            "Round": round_num + 1,
            "Loss": loss,
            "Accuracy": accuracy,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Total Round Time": total_round_time,  # Store the time taken for this round
            "Edge Results": edge_results,  # Includes vehicles and times for each edge server
            "Train_Loss":train_loss,
            "Test_loss":loss
        })
    # Logging total training time
    end_time = time.time()
    total_time_taken = end_time - start_time
    #print(f"Total training time for all rounds by end and start time by SFL1: {total_time:.2f} seconds")
    print(f"Total training time for all rounds: {total_time:.2f} seconds")
    # Final model evaluation
    # Measure testing time
    test_start_time = time.time()
    loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
    test_end_time = time.time()

    testing_time = test_end_time - test_start_time

    print(f'Final model results: Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 = {f1}')
    print(f'Confusion Matrix:\n{conf_matrix}')
    print(f'Testing Time: {testing_time:.2f} seconds')
    # Appending the final round results
    round_results.append({
        "Round": "Final",
        "Loss": loss,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "FL Time": fl_time,  # Include all round times
        "Confusion Matrix": conf_matrix,
    })

    # Saving the final model
    save_model(cloud_server.model, cfg['num_rounds'], method_name, file_path=save_path)

    # Append total time to the round results
    round_results.append({
        "Round": "Total Time",
        "FL Time": total_time,
        "Round Times": fl_time,  # Optional: store each round time
        "Testing Time": testing_time
})

    # Save results to CSV
    df_results = pd.DataFrame(round_results)
    df_results.to_csv(os.path.join(results_path, f"{method_name}_results.csv"), index=False)
    print(f"Training results saved to {results_path}/{method_name}_results.csv")
    plot_confusion_matrix(conf_matrix)
    ## Generate Lime explanation
    lime_start_time = time.time()
    explanation, selected_instance, instance_index = generate_lime_explanation(X_train_tensor, X_test_tensor, cloud_server.model, method_name)
    lime_end_time = time.time()

    lime_time = lime_end_time - lime_start_time
    print(f"Total time taken for Lime Explanation: {lime_time:.2f} seconds")

    # Running SHAP analysis
    shap_start_time = time.time()
    shap_method(cloud_server.model, method_name, X_train_tensor[:100], X_test_tensor)
    shap_end_time = time.time()
    shap_time = shap_end_time - shap_start_time
    print(f"Total time taken for Shap Explanation: {shap_time:.2f} seconds")

    return df_results

# %%
results=run_fl_training(cfg, cloud_server, edge_servers,raw_train_loader, testloader, X_train_tensor, X_test_tensor, method_name="SFL1", save_path="model_checkpoint")
# Out:
#   FL Global Training Round SFL1: 1
#
#
# Starting the training process for round 1 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.
# [SFL1] Launching training for edge edge-7.
# [SFL1] Launching training for edge edge-5.[SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-3.
#
# [edge-5] Vehicle 53 trained with time: 20.83 seconds
# [edge-6] Vehicle 57 trained with time: 23.03 seconds
# [edge-0] Vehicle 38 trained with time: 25.93 seconds
# [edge-0] Vehicle 54 trained with time: 26.03 seconds
# [edge-3] Vehicle 0 trained with time: 27.91 seconds
# [edge-6] Vehicle 27 trained with time: 31.16 seconds
# [edge-2] Vehicle 9 trained with time: 31.57 seconds
# [edge-3] Vehicle 24 trained with time: 35.14 seconds
# [edge-0] Vehicle 11 trained with time: 35.22 seconds
# [edge-7] Vehicle 34 trained with time: 35.38 seconds
# [edge-5] Vehicle 12 trained with time: 35.69 seconds
# [edge-1] Vehicle 58 trained with time: 36.13 seconds
# [edge-4] Vehicle 52 trained with time: 36.81 seconds
# [edge-4] Vehicle 26 trained with time: 37.08 seconds
# [edge-2] Vehicle 45 trained with time: 37.53 seconds
# [edge-4] Vehicle 44 trained with time: 37.97 seconds
# [edge-4] Vehicle 28 trained with time: 39.70 seconds
# [edge-0] Vehicle 23 trained with time: 40.57 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-4] Vehicle 39 trained with time: 41.01 seconds
# [edge-7] Vehicle 51 trained with time: 41.48 seconds
# [edge-5] Vehicle 13 trained with time: 41.56 seconds
# [edge-6] Vehicle 2 trained with time: 42.71 seconds
# [edge-2] Vehicle 49 trained with time: 42.76 seconds
# [edge-7] Vehicle 56 trained with time: 44.59 seconds
# [edge-5] Vehicle 48 trained with time: 46.55 seconds
# [edge-2] Vehicle 31 trained with time: 48.61 seconds
# [edge-3] Vehicle 22 trained with time: 48.95 seconds
# [edge-7] Vehicle 6 trained with time: 49.72 seconds
# [edge-5] Vehicle 32 trained with time: 50.12 seconds
# [edge-2] Vehicle 36 trained with time: 51.77 seconds
# [edge-6] Vehicle 37 trained with time: 52.97 seconds
# [edge-5] Vehicle 46 trained with time: 54.88 seconds
# [edge-6] Vehicle 5 trained with time: 55.17 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 42 trained with time: 55.51 seconds
# [edge-5] Vehicle 35 trained with time: 56.06 seconds
# [edge-5] All 8 vehicles trained.
# [edge-1] Vehicle 16 trained with time: 56.51 seconds
# [edge-1] Vehicle 55 trained with time: 58.51 seconds
# [edge-1] Vehicle 33 trained with time: 60.50 seconds
# [edge-2] Vehicle 30 trained with time: 60.81 seconds
# [edge-2] All 6 vehicles trained.
# [edge-4] Vehicle 25 trained with time: 62.44 seconds
# [edge-8] Vehicle 15 trained with time: 22.38 seconds
# [edge-3] Vehicle 29 trained with time: 63.15 seconds
# [edge-7] Vehicle 43 trained with time: 70.72 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 59 trained with time: 70.88 seconds
# [edge-3] Vehicle 4 trained with time: 71.60 seconds
# [edge-8] Vehicle 14 trained with time: 32.75 seconds
# [edge-8] Vehicle 8 trained with time: 32.88 seconds
# [edge-8] All 3 vehicles trained.
# [edge-3] Vehicle 41 trained with time: 74.34 seconds
# [edge-1] Vehicle 19 trained with time: 76.62 seconds
# [edge-4] Vehicle 18 trained with time: 79.21 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 80.29 seconds
# [edge-9] Vehicle 40 trained with time: 26.72 seconds
# [edge-3] Vehicle 10 trained with time: 82.74 seconds
# [edge-9] Vehicle 17 trained with time: 32.50 seconds
# [edge-3] Vehicle 21 trained with time: 89.01 seconds
# [edge-1] Vehicle 20 trained with time: 93.40 seconds
# [edge-1] All 6 vehicles trained.
# [edge-9] Vehicle 1 trained with time: 38.37 seconds
# [edge-3] Vehicle 50 trained with time: 93.85 seconds
# [edge-3] All 11 vehicles trained.
# [edge-9] Vehicle 7 trained with time: 38.81 seconds
# [edge-9] Vehicle 47 trained with time: 41.31 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 1 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.466157330374176, Accuracy = 0.9144006566409153, Precision = 0.9517850597463529, Recall = 0.8798956321371691, F1 = 0.9144295951965912, Total Time for  1= 103.18 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_1.pth
#
#   FL Global Training Round SFL1: 2
#
#
# Starting the training process for round 2 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.[SFL1] Launching training for edge edge-7.
#
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.78 seconds
# [edge-6] Vehicle 57 trained with time: 22.42 seconds
# [edge-0] Vehicle 54 trained with time: 25.94 seconds[edge-0] Vehicle 38 trained with time: 25.94 seconds
#
# [edge-3] Vehicle 0 trained with time: 27.21 seconds
# [edge-6] Vehicle 27 trained with time: 30.07 seconds
# [edge-2] Vehicle 9 trained with time: 29.97 seconds
# [edge-0] Vehicle 11 trained with time: 33.50 seconds
# [edge-7] Vehicle 34 trained with time: 33.75 seconds
# [edge-1] Vehicle 58 trained with time: 34.00 seconds
# [edge-5] Vehicle 12 trained with time: 34.25 seconds
# [edge-3] Vehicle 24 trained with time: 34.61 seconds
# [edge-4] Vehicle 52 trained with time: 35.24 seconds
# [edge-4] Vehicle 26 trained with time: 35.83 seconds[edge-2] Vehicle 45 trained with time: 35.77 seconds
#
# [edge-7] Vehicle 51 trained with time: 38.65 seconds
# [edge-0] Vehicle 23 trained with time: 39.02 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-4] Vehicle 44 trained with time: 39.41 seconds
# [edge-4] Vehicle 28 trained with time: 40.22 seconds
# [edge-5] Vehicle 13 trained with time: 40.59 seconds
# [edge-4] Vehicle 39 trained with time: 40.69 seconds
# [edge-6] Vehicle 2 trained with time: 42.07 seconds
# [edge-2] Vehicle 49 trained with time: 42.78 seconds
# [edge-7] Vehicle 56 trained with time: 43.36 seconds
# [edge-5] Vehicle 48 trained with time: 45.28 seconds
# [edge-7] Vehicle 6 trained with time: 47.53 seconds
# [edge-2] Vehicle 31 trained with time: 47.59 seconds
# [edge-2] Vehicle 36 trained with time: 48.09 seconds
# [edge-3] Vehicle 22 trained with time: 48.74 seconds
# [edge-5] Vehicle 32 trained with time: 49.18 seconds
# [edge-6] Vehicle 37 trained with time: 51.55 seconds
# [edge-5] Vehicle 46 trained with time: 51.95 seconds
# [edge-5] Vehicle 42 trained with time: 53.38 seconds
# [edge-6] Vehicle 5 trained with time: 53.53 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 35 trained with time: 58.19 seconds
# [edge-5] All 8 vehicles trained.
# [edge-2] Vehicle 30 trained with time: 58.84 seconds
# [edge-2] All 6 vehicles trained.
# [edge-1] Vehicle 16 trained with time: 59.94 seconds
# [edge-4] Vehicle 25 trained with time: 60.69 seconds
# [edge-1] Vehicle 33 trained with time: 61.49 seconds
# [edge-8] Vehicle 15 trained with time: 22.42 seconds
# [edge-1] Vehicle 55 trained with time: 61.53 seconds
# [edge-3] Vehicle 29 trained with time: 61.71 seconds
# [edge-3] Vehicle 4 trained with time: 67.21 seconds
# [edge-7] Vehicle 43 trained with time: 67.32 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 59 trained with time: 68.92 seconds
# [edge-3] Vehicle 41 trained with time: 71.22 seconds
# [edge-8] Vehicle 8 trained with time: 32.80 seconds
# [edge-8] Vehicle 14 trained with time: 32.84 seconds
# [edge-8] All 3 vehicles trained.
# [edge-1] Vehicle 19 trained with time: 74.53 seconds
# [edge-4] Vehicle 18 trained with time: 76.44 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 77.93 seconds
# [edge-3] Vehicle 10 trained with time: 80.60 seconds
# [edge-9] Vehicle 40 trained with time: 27.83 seconds
# [edge-9] Vehicle 17 trained with time: 33.03 seconds
# [edge-3] Vehicle 21 trained with time: 86.76 seconds
# [edge-3] Vehicle 50 trained with time: 90.87 seconds
# [edge-3] All 11 vehicles trained.
# [edge-1] Vehicle 20 trained with time: 91.93 seconds
# [edge-1] All 6 vehicles trained.
# [edge-9] Vehicle 1 trained with time: 41.58 seconds
# [edge-9] Vehicle 7 trained with time: 41.86 seconds
# [edge-9] Vehicle 47 trained with time: 42.62 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 2 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.27340680164490905, Accuracy = 0.9204738805575812, Precision = 0.9476104521230875, Recall = 0.8965741587882484, F1 = 0.9213861117205211, Total Time for  2= 98.14 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_2.pth
#
#   FL Global Training Round SFL1: 3
#
#
# Starting the training process for round 3 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.[SFL1] Launching training for edge edge-7.
#
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.73 seconds
# [edge-6] Vehicle 57 trained with time: 22.62 seconds
# [edge-0] Vehicle 38 trained with time: 25.68 seconds
# [edge-0] Vehicle 54 trained with time: 25.71 seconds
# [edge-3] Vehicle 0 trained with time: 27.12 seconds
# [edge-6] Vehicle 27 trained with time: 29.92 seconds
# [edge-2] Vehicle 9 trained with time: 30.30 seconds
# [edge-0] Vehicle 11 trained with time: 33.78 seconds
# [edge-5] Vehicle 12 trained with time: 33.79 seconds
# [edge-7] Vehicle 34 trained with time: 33.97 seconds
# [edge-3] Vehicle 24 trained with time: 34.47 seconds
# [edge-1] Vehicle 58 trained with time: 34.74 seconds
# [edge-4] Vehicle 52 trained with time: 34.79 seconds
# [edge-4] Vehicle 26 trained with time: 35.65 seconds
# [edge-2] Vehicle 45 trained with time: 36.25 seconds
# [edge-4] Vehicle 28 trained with time: 37.81 seconds
# [edge-4] Vehicle 44 trained with time: 39.05 seconds
# [edge-0] Vehicle 23 trained with time: 39.26 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-4] Vehicle 39 trained with time: 39.48 seconds
# [edge-7] Vehicle 51 trained with time: 39.55 seconds
# [edge-5] Vehicle 13 trained with time: 40.31 seconds
# [edge-7] Vehicle 56 trained with time: 42.25 seconds
# [edge-6] Vehicle 2 trained with time: 42.32 seconds
# [edge-2] Vehicle 49 trained with time: 43.03 seconds
# [edge-5] Vehicle 48 trained with time: 44.99 seconds
# [edge-2] Vehicle 31 trained with time: 47.20 seconds
# [edge-7] Vehicle 6 trained with time: 47.86 seconds
# [edge-3] Vehicle 22 trained with time: 47.77 seconds
# [edge-5] Vehicle 32 trained with time: 48.12 seconds
# [edge-2] Vehicle 36 trained with time: 49.28 seconds
# [edge-6] Vehicle 37 trained with time: 51.28 seconds
# [edge-5] Vehicle 46 trained with time: 53.04 seconds
# [edge-5] Vehicle 42 trained with time: 53.38 seconds
# [edge-6] Vehicle 5 trained with time: 53.55 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 35 trained with time: 56.57 seconds
# [edge-5] All 8 vehicles trained.
# [edge-2] Vehicle 30 trained with time: 57.29 seconds
# [edge-2] All 6 vehicles trained.
# [edge-1] Vehicle 16 trained with time: 58.06 seconds
# [edge-4] Vehicle 25 trained with time: 59.06 seconds
# [edge-1] Vehicle 55 trained with time: 59.33 seconds
# [edge-1] Vehicle 33 trained with time: 60.19 seconds
# [edge-3] Vehicle 29 trained with time: 60.15 seconds
# [edge-8] Vehicle 15 trained with time: 22.82 seconds
# [edge-7] Vehicle 43 trained with time: 67.14 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 4 trained with time: 69.54 seconds
# [edge-3] Vehicle 59 trained with time: 70.18 seconds
# [edge-8] Vehicle 14 trained with time: 32.40 seconds
# [edge-8] Vehicle 8 trained with time: 32.50 seconds
# [edge-8] All 3 vehicles trained.
# [edge-3] Vehicle 41 trained with time: 72.09 seconds
# [edge-1] Vehicle 19 trained with time: 74.15 seconds
# [edge-4] Vehicle 18 trained with time: 76.10 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 77.02 seconds
# [edge-3] Vehicle 10 trained with time: 80.49 seconds
# [edge-9] Vehicle 40 trained with time: 27.59 seconds
# [edge-3] Vehicle 21 trained with time: 84.39 seconds
# [edge-9] Vehicle 17 trained with time: 33.02 seconds
# [edge-1] Vehicle 20 trained with time: 88.58 seconds
# [edge-1] All 6 vehicles trained.
# [edge-3] Vehicle 50 trained with time: 89.21 seconds
# [edge-3] All 11 vehicles trained.
# [edge-9] Vehicle 7 trained with time: 40.70 seconds
# [edge-9] Vehicle 1 trained with time: 41.45 seconds
# [edge-9] Vehicle 47 trained with time: 44.92 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 3 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.2565906616749037, Accuracy = 0.9178459077954972, Precision = 0.9530317837711685, Recall = 0.8855952017891634, F1 = 0.9180767839139492, Total Time for  3= 100.66 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_3.pth
#
#   FL Global Training Round SFL1: 4
#
#
# Starting the training process for round 4 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.
# [SFL1] Launching training for edge edge-7.
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.68 seconds
# [edge-6] Vehicle 57 trained with time: 22.55 seconds
# [edge-0] Vehicle 38 trained with time: 25.89 seconds
# [edge-0] Vehicle 54 trained with time: 25.91 seconds
# [edge-3] Vehicle 0 trained with time: 27.25 seconds
# [edge-2] Vehicle 9 trained with time: 29.97 seconds
# [edge-6] Vehicle 27 trained with time: 30.79 seconds
# [edge-0] Vehicle 11 trained with time: 32.70 seconds
# [edge-7] Vehicle 34 trained with time: 33.33 seconds
# [edge-5] Vehicle 12 trained with time: 34.01 seconds
# [edge-3] Vehicle 24 trained with time: 34.18 seconds
# [edge-4] Vehicle 52 trained with time: 34.95 seconds
# [edge-1] Vehicle 58 trained with time: 35.39 seconds
# [edge-4] Vehicle 26 trained with time: 35.58 seconds
# [edge-4] Vehicle 44 trained with time: 36.24 seconds
# [edge-2] Vehicle 45 trained with time: 36.60 seconds
# [edge-4] Vehicle 28 trained with time: 37.80 seconds
# [edge-7] Vehicle 51 trained with time: 38.20 seconds
# [edge-0] Vehicle 23 trained with time: 38.42 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-4] Vehicle 39 trained with time: 38.46 seconds
# [edge-5] Vehicle 13 trained with time: 40.00 seconds
# [edge-6] Vehicle 2 trained with time: 40.17 seconds
# [edge-2] Vehicle 49 trained with time: 41.83 seconds
# [edge-7] Vehicle 56 trained with time: 43.50 seconds
# [edge-5] Vehicle 48 trained with time: 45.94 seconds
# [edge-2] Vehicle 31 trained with time: 46.25 seconds
# [edge-3] Vehicle 22 trained with time: 47.43 seconds
# [edge-7] Vehicle 6 trained with time: 47.60 seconds
# [edge-2] Vehicle 36 trained with time: 48.99 seconds
# [edge-5] Vehicle 32 trained with time: 48.80 seconds
# [edge-6] Vehicle 37 trained with time: 50.02 seconds
# [edge-6] Vehicle 5 trained with time: 51.86 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 46 trained with time: 52.95 seconds
# [edge-5] Vehicle 42 trained with time: 53.32 seconds
# [edge-1] Vehicle 16 trained with time: 57.70 seconds
# [edge-1] Vehicle 55 trained with time: 58.00 seconds
# [edge-2] Vehicle 30 trained with time: 58.24 seconds
# [edge-2] All 6 vehicles trained.
# [edge-5] Vehicle 35 trained with time: 58.38 seconds
# [edge-5] All 8 vehicles trained.
# [edge-1] Vehicle 33 trained with time: 59.76 seconds
# [edge-4] Vehicle 25 trained with time: 59.99 seconds
# [edge-3] Vehicle 29 trained with time: 60.74 seconds
# [edge-8] Vehicle 15 trained with time: 22.56 seconds
# [edge-7] Vehicle 43 trained with time: 67.03 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 4 trained with time: 69.71 seconds
# [edge-3] Vehicle 59 trained with time: 69.76 seconds
# [edge-3] Vehicle 41 trained with time: 70.52 seconds
# [edge-8] Vehicle 14 trained with time: 32.51 seconds
# [edge-8] Vehicle 8 trained with time: 32.52 seconds
# [edge-8] All 3 vehicles trained.
# [edge-1] Vehicle 19 trained with time: 73.99 seconds
# [edge-4] Vehicle 18 trained with time: 75.85 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 78.33 seconds
# [edge-9] Vehicle 40 trained with time: 26.98 seconds
# [edge-3] Vehicle 10 trained with time: 80.85 seconds
# [edge-9] Vehicle 17 trained with time: 32.57 seconds
# [edge-3] Vehicle 21 trained with time: 86.30 seconds
# [edge-1] Vehicle 20 trained with time: 88.95 seconds
# [edge-1] All 6 vehicles trained.
# [edge-3] Vehicle 50 trained with time: 90.57 seconds
# [edge-3] All 11 vehicles trained.
# [edge-9] Vehicle 1 trained with time: 39.20 seconds
# [edge-9] Vehicle 7 trained with time: 40.05 seconds
# [edge-9] Vehicle 47 trained with time: 44.60 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 4 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.25538042650763787, Accuracy = 0.9180044316216283, Precision = 0.9532653016565398, Recall = 0.885676527396564, F1 = 0.9182288299935358, Total Time for  4= 98.63 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_4.pth
#
#   FL Global Training Round SFL1: 5
#
#
# Starting the training process for round 5 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.[SFL1] Launching training for edge edge-7.
#
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.66 seconds
# [edge-6] Vehicle 57 trained with time: 22.56 seconds
# [edge-0] Vehicle 54 trained with time: 25.70 seconds
# [edge-0] Vehicle 38 trained with time: 25.73 seconds
# [edge-3] Vehicle 0 trained with time: 27.28 seconds
# [edge-6] Vehicle 27 trained with time: 29.97 seconds
# [edge-2] Vehicle 9 trained with time: 30.04 seconds
# [edge-0] Vehicle 11 trained with time: 33.71 seconds
# [edge-7] Vehicle 34 trained with time: 33.75 seconds
# [edge-4] Vehicle 52 trained with time: 33.94 seconds
# [edge-5] Vehicle 12 trained with time: 34.21 seconds
# [edge-3] Vehicle 24 trained with time: 34.81 seconds
# [edge-1] Vehicle 58 trained with time: 35.13 seconds
# [edge-4] Vehicle 26 trained with time: 35.34 seconds
# [edge-2] Vehicle 45 trained with time: 36.10 seconds
# [edge-4] Vehicle 44 trained with time: 36.18 seconds
# [edge-4] Vehicle 28 trained with time: 37.59 seconds
# [edge-4] Vehicle 39 trained with time: 38.52 seconds
# [edge-0] Vehicle 23 trained with time: 39.19 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-7] Vehicle 51 trained with time: 39.66 seconds
# [edge-5] Vehicle 13 trained with time: 39.93 seconds
# [edge-6] Vehicle 2 trained with time: 41.60 seconds
# [edge-2] Vehicle 49 trained with time: 42.45 seconds
# [edge-7] Vehicle 56 trained with time: 43.18 seconds
# [edge-5] Vehicle 48 trained with time: 45.05 seconds
# [edge-7] Vehicle 6 trained with time: 46.15 seconds
# [edge-2] Vehicle 31 trained with time: 46.48 seconds
# [edge-5] Vehicle 32 trained with time: 47.98 seconds
# [edge-3] Vehicle 22 trained with time: 48.31 seconds
# [edge-2] Vehicle 36 trained with time: 48.91 seconds
# [edge-6] Vehicle 37 trained with time: 50.92 seconds
# [edge-5] Vehicle 46 trained with time: 51.98 seconds
# [edge-6] Vehicle 5 trained with time: 53.38 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 42 trained with time: 53.53 seconds
# [edge-1] Vehicle 16 trained with time: 55.13 seconds
# [edge-5] Vehicle 35 trained with time: 55.55 seconds
# [edge-5] All 8 vehicles trained.
# [edge-1] Vehicle 55 trained with time: 56.53 seconds
# [edge-1] Vehicle 33 trained with time: 57.84 seconds
# [edge-2] Vehicle 30 trained with time: 58.70 seconds
# [edge-2] All 6 vehicles trained.
# [edge-4] Vehicle 25 trained with time: 58.94 seconds
# [edge-3] Vehicle 29 trained with time: 60.76 seconds
# [edge-8] Vehicle 15 trained with time: 22.51 seconds
# [edge-7] Vehicle 43 trained with time: 67.10 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 4 trained with time: 67.20 seconds
# [edge-3] Vehicle 59 trained with time: 69.11 seconds
# [edge-8] Vehicle 14 trained with time: 32.46 seconds
# [edge-8] Vehicle 8 trained with time: 32.51 seconds
# [edge-8] All 3 vehicles trained.
# [edge-3] Vehicle 41 trained with time: 71.92 seconds
# [edge-1] Vehicle 19 trained with time: 74.02 seconds
# [edge-3] Vehicle 3 trained with time: 75.56 seconds
# [edge-4] Vehicle 18 trained with time: 76.65 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 10 trained with time: 80.50 seconds
# [edge-9] Vehicle 40 trained with time: 28.55 seconds
# [edge-3] Vehicle 21 trained with time: 86.09 seconds
# [edge-9] Vehicle 17 trained with time: 34.69 seconds
# [edge-1] Vehicle 20 trained with time: 90.98 seconds
# [edge-3] Vehicle 50 trained with time: 90.99 seconds[edge-1] All 6 vehicles trained.
#
# [edge-3] All 11 vehicles trained.
# [edge-9] Vehicle 1 trained with time: 44.32 seconds
# [edge-9] Vehicle 7 trained with time: 44.69 seconds
# [edge-9] Vehicle 47 trained with time: 46.40 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 5 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.25478368015926806, Accuracy = 0.9177014749761333, Precision = 0.9539914752995708, Recall = 0.8843211006065534, F1 = 0.9178360660350151, Total Time for  5= 101.74 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_5.pth
#
#   FL Global Training Round SFL1: 6
#
#
# Starting the training process for round 6 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.[SFL1] Launching training for edge edge-7.
#
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.63 seconds
# [edge-6] Vehicle 57 trained with time: 22.60 seconds
# [edge-0] Vehicle 38 trained with time: 25.74 seconds
# [edge-0] Vehicle 54 trained with time: 25.75 seconds
# [edge-3] Vehicle 0 trained with time: 27.25 seconds
# [edge-2] Vehicle 9 trained with time: 29.41 seconds
# [edge-6] Vehicle 27 trained with time: 30.07 seconds
# [edge-7] Vehicle 34 trained with time: 33.46 seconds
# [edge-5] Vehicle 12 trained with time: 33.91 seconds
# [edge-0] Vehicle 11 trained with time: 34.14 seconds
# [edge-3] Vehicle 24 trained with time: 34.53 seconds
# [edge-4] Vehicle 52 trained with time: 34.99 seconds
# [edge-1] Vehicle 58 trained with time: 35.45 seconds
# [edge-4] Vehicle 26 trained with time: 35.70 seconds
# [edge-2] Vehicle 45 trained with time: 35.67 seconds
# [edge-4] Vehicle 44 trained with time: 37.57 seconds
# [edge-4] Vehicle 28 trained with time: 38.27 seconds
# [edge-7] Vehicle 51 trained with time: 38.73 seconds
# [edge-0] Vehicle 23 trained with time: 38.85 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-5] Vehicle 13 trained with time: 39.55 seconds
# [edge-4] Vehicle 39 trained with time: 39.79 seconds
# [edge-7] Vehicle 56 trained with time: 41.74 seconds
# [edge-2] Vehicle 49 trained with time: 42.00 seconds
# [edge-6] Vehicle 2 trained with time: 42.22 seconds
# [edge-5] Vehicle 48 trained with time: 44.19 seconds
# [edge-2] Vehicle 31 trained with time: 46.02 seconds
# [edge-7] Vehicle 6 trained with time: 46.87 seconds
# [edge-2] Vehicle 36 trained with time: 47.15 seconds
# [edge-3] Vehicle 22 trained with time: 47.55 seconds
# [edge-5] Vehicle 32 trained with time: 48.15 seconds
# [edge-6] Vehicle 37 trained with time: 51.39 seconds
# [edge-5] Vehicle 46 trained with time: 52.87 seconds
# [edge-6] Vehicle 5 trained with time: 53.80 seconds
# ...
# [edge-8] All 3 vehicles trained.
# [edge-1] Vehicle 19 trained with time: 71.20 seconds
# [edge-4] Vehicle 18 trained with time: 74.34 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 75.66 seconds
# [edge-9] Vehicle 40 trained with time: 27.88 seconds
# [edge-3] Vehicle 10 trained with time: 78.67 seconds
# [edge-3] Vehicle 21 trained with time: 81.98 seconds
# [edge-9] Vehicle 17 trained with time: 33.41 seconds
# [edge-3] Vehicle 50 trained with time: 86.33 seconds
# [edge-3] All 11 vehicles trained.
# [edge-1] Vehicle 20 trained with time: 88.71 seconds
# [edge-1] All 6 vehicles trained.
# [edge-9] Vehicle 1 trained with time: 42.34 seconds
# [edge-9] Vehicle 7 trained with time: 42.54 seconds
# [edge-9] Vehicle 47 trained with time: 42.87 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 9 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.2546451853143994, Accuracy = 0.9184659120932542, Precision = 0.9534949842528869, Recall = 0.8863745721934194, F1 = 0.918710465961654, Total Time for  9= 95.11 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_9.pth
#
#   FL Global Training Round SFL1: 10
#
#
# Starting the training process for round 10 on edge servers...
#
# Launching training on edge servers...
# [SFL1] Launching training for edge edge-0.
# [SFL1] Launching training for edge edge-1.
# [SFL1] Launching training for edge edge-2.
# [SFL1] Launching training for edge edge-6.
# [SFL1] Launching training for edge edge-7.
# [SFL1] Launching training for edge edge-4.
# [SFL1] Launching training for edge edge-5.
# [SFL1] Launching training for edge edge-3.
# [edge-5] Vehicle 53 trained with time: 20.64 seconds
# [edge-6] Vehicle 57 trained with time: 22.43 seconds
# [edge-0] Vehicle 38 trained with time: 25.84 seconds[edge-0] Vehicle 54 trained with time: 25.84 seconds
#
# [edge-3] Vehicle 0 trained with time: 27.13 seconds
# [edge-2] Vehicle 9 trained with time: 29.64 seconds
# [edge-6] Vehicle 27 trained with time: 30.72 seconds
# [edge-0] Vehicle 11 trained with time: 32.46 seconds
# [edge-4] Vehicle 52 trained with time: 33.83 seconds
# [edge-5] Vehicle 12 trained with time: 34.03 seconds
# [edge-7] Vehicle 34 trained with time: 34.12 seconds
# [edge-1] Vehicle 58 trained with time: 34.30 seconds
# [edge-3] Vehicle 24 trained with time: 34.43 seconds
# [edge-2] Vehicle 45 trained with time: 34.89 seconds
# [edge-4] Vehicle 26 trained with time: 35.17 seconds
# [edge-4] Vehicle 28 trained with time: 36.92 seconds
# [edge-4] Vehicle 44 trained with time: 38.43 seconds
# [edge-7] Vehicle 51 trained with time: 38.57 seconds
# [edge-0] Vehicle 23 trained with time: 38.77 seconds
# [edge-0] All 4 vehicles trained.
# [SFL1] Launching training for edge edge-8.
# [edge-5] Vehicle 13 trained with time: 38.85 seconds
# [edge-4] Vehicle 39 trained with time: 40.07 seconds
# [edge-6] Vehicle 2 trained with time: 41.32 seconds
# [edge-2] Vehicle 49 trained with time: 41.85 seconds
# [edge-7] Vehicle 56 trained with time: 43.20 seconds
# [edge-5] Vehicle 48 trained with time: 43.87 seconds
# [edge-5] Vehicle 32 trained with time: 46.28 seconds
# [edge-2] Vehicle 31 trained with time: 46.42 seconds
# [edge-3] Vehicle 22 trained with time: 47.51 seconds
# [edge-7] Vehicle 6 trained with time: 47.78 seconds
# [edge-2] Vehicle 36 trained with time: 48.09 seconds
# [edge-5] Vehicle 46 trained with time: 49.30 seconds
# [edge-5] Vehicle 42 trained with time: 49.93 seconds
# [edge-6] Vehicle 37 trained with time: 51.10 seconds
# [edge-6] Vehicle 5 trained with time: 53.31 seconds
# [edge-6] All 5 vehicles trained.
# [SFL1] Launching training for edge edge-9.
# [edge-5] Vehicle 35 trained with time: 56.24 seconds
# [edge-5] All 8 vehicles trained.
# [edge-2] Vehicle 30 trained with time: 56.61 seconds
# [edge-2] All 6 vehicles trained.
# [edge-1] Vehicle 55 trained with time: 57.07 seconds
# [edge-1] Vehicle 16 trained with time: 57.14 seconds
# [edge-1] Vehicle 33 trained with time: 57.67 seconds
# [edge-4] Vehicle 25 trained with time: 58.35 seconds
# [edge-3] Vehicle 29 trained with time: 59.94 seconds
# [edge-8] Vehicle 15 trained with time: 22.66 seconds
# [edge-7] Vehicle 43 trained with time: 67.05 seconds
# [edge-7] All 5 vehicles trained.
# [edge-3] Vehicle 4 trained with time: 68.81 seconds
# [edge-3] Vehicle 59 trained with time: 68.87 seconds
# [edge-3] Vehicle 41 trained with time: 69.71 seconds
# [edge-8] Vehicle 8 trained with time: 31.65 seconds
# [edge-8] Vehicle 14 trained with time: 31.81 seconds
# [edge-8] All 3 vehicles trained.
# [edge-1] Vehicle 19 trained with time: 72.80 seconds
# [edge-4] Vehicle 18 trained with time: 75.03 seconds
# [edge-4] All 7 vehicles trained.
# [edge-3] Vehicle 3 trained with time: 75.57 seconds
# [edge-3] Vehicle 10 trained with time: 79.03 seconds
# [edge-9] Vehicle 40 trained with time: 27.28 seconds
# [edge-3] Vehicle 21 trained with time: 83.88 seconds
# [edge-9] Vehicle 17 trained with time: 32.96 seconds
# [edge-3] Vehicle 50 trained with time: 88.18 seconds
# [edge-3] All 11 vehicles trained.
# [edge-1] Vehicle 20 trained with time: 88.88 seconds
# [edge-1] All 6 vehicles trained.
# [edge-9] Vehicle 7 trained with time: 40.27 seconds
# [edge-9] Vehicle 1 trained with time: 40.51 seconds
# [edge-9] Vehicle 47 trained with time: 41.27 seconds
# [edge-9] All 5 vehicles trained.
# Training completed on edge servers. Collecting results...
#
# Updating edge server edge-0 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-0...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated ALL 4 models.
#
# Updating edge server edge-1 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-1...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated ALL 6 models.
#
# Updating edge server edge-2 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-2...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated ALL 6 models.
#
# Updating edge server edge-3 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-3...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated ALL 11 models.
#
# Updating edge server edge-4 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-4...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated ALL 7 models.
#
# Updating edge server edge-5 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-5...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated ALL 8 models.
#
# Updating edge server edge-6 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-6...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated ALL 5 models.
#
# Updating edge server edge-7 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-7...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated ALL 5 models.
#
# Updating edge server edge-8 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-8...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated ALL 3 models.
#
# Updating edge server edge-9 with local model storage and aggregation weights...
# Aggregating local models for edge server edge-9...
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated ALL 5 models.
#
# Updating global model on the cloud server...
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated ALL 10 edge models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
# Updating vehicles for edge server edge-0...
# Updating vehicles for edge server edge-1...
# Updating vehicles for edge server edge-2...
# Updating vehicles for edge server edge-3...
# Updating vehicles for edge server edge-4...
# Updating vehicles for edge server edge-5...
# Updating vehicles for edge server edge-6...
# Updating vehicles for edge server edge-7...
# Updating vehicles for edge server edge-8...
# Updating vehicles for edge server edge-9...
#
# Round 10 summary:
# Edge edge-0 associated vehicles: [Vehicle-id=38, Vehicle-id=23, Vehicle-id=54, Vehicle-id=11]
# Edge edge-1 associated vehicles: [Vehicle-id=16, Vehicle-id=20, Vehicle-id=55, Vehicle-id=58, Vehicle-id=33, Vehicle-id=19]
# Edge edge-2 associated vehicles: [Vehicle-id=9, Vehicle-id=36, Vehicle-id=31, Vehicle-id=45, Vehicle-id=30, Vehicle-id=49]
# Edge edge-3 associated vehicles: [Vehicle-id=3, Vehicle-id=21, Vehicle-id=50, Vehicle-id=4, Vehicle-id=29, Vehicle-id=10, Vehicle-id=59, Vehicle-id=22, Vehicle-id=41, Vehicle-id=24, Vehicle-id=0]
# Edge edge-4 associated vehicles: [Vehicle-id=44, Vehicle-id=25, Vehicle-id=52, Vehicle-id=18, Vehicle-id=28, Vehicle-id=39, Vehicle-id=26]
# Edge edge-5 associated vehicles: [Vehicle-id=48, Vehicle-id=12, Vehicle-id=35, Vehicle-id=42, Vehicle-id=32, Vehicle-id=53, Vehicle-id=13, Vehicle-id=46]
# Edge edge-6 associated vehicles: [Vehicle-id=57, Vehicle-id=2, Vehicle-id=27, Vehicle-id=37, Vehicle-id=5]
# Edge edge-7 associated vehicles: [Vehicle-id=34, Vehicle-id=51, Vehicle-id=43, Vehicle-id=6, Vehicle-id=56]
# Edge edge-8 associated vehicles: [Vehicle-id=8, Vehicle-id=14, Vehicle-id=15]
# Edge edge-9 associated vehicles: [Vehicle-id=17, Vehicle-id=47, Vehicle-id=1, Vehicle-id=7, Vehicle-id=40]
# Loss = 0.25424546097650763, Accuracy = 0.9186103449126182, Precision = 0.9547617133544299, Recall = 0.8853715563688116, F1 = 0.9187583073709676, Total Time for  10= 96.58 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_10.pth
# Total training time for all rounds: 994.66 seconds
# Final model results: Loss = 0.25424546097650763, Accuracy = 0.9186103449126182, Precision = 0.9547617133544299, Recall = 0.8853715563688116, F1 = 0.9187583073709676
# Confusion Matrix:
# [[130124   6190]
#  [ 16914 130641]]
# Testing Time: 4.45 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/model_checkpoint/SFL1/model_SFL1_round_10.pth
# Training results saved to /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/results/SFL1_results.csv
# LIME explanation plot saved to /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/lime_resultslime_explanation_SFL1.png
# Total time taken for Lime Explanation: 1.55 seconds
# SHAP summary plot saved as /content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/shap_results/shap_summary_SFL1.png
# Total time taken for Shap Explanation: 959.28 seconds

# %%
method_name="SFL1"
results_path = f"/content/drive/MyDrive/car_hacking_results/SFL1-debugging_exp2-14-02-2025/results"
plot_path = f"{results_path}_{method_name}.png"

df_plot = results[pd.to_numeric(results['Round'], errors='coerce').notnull()]
# Plotting the training and test loss per round
plt.figure(figsize=(10, 6))
plt.plot(df_plot['Round'], df_plot['Train_Loss'], label="Training Loss", marker='o')
plt.plot(df_plot['Round'], df_plot['Test_loss'], label="Testing Loss", marker='o')
plt.xlabel("FL Training Round")
plt.ylabel("Loss")
plt.title("Training and Testing Loss per Federated Learning Round")
plt.xticks(df_plot['Round'].astype(int))  # Display only the round numbers on the x-axis
plt.legend()
plt.grid(True)

# Save the plot
plot_path = f"{results_path}/{method_name}.png"
plt.savefig(plot_path, bbox_inches='tight')
plt.show()
