# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install shap -q
# !pip install hydra-core -q
# !pip install fedlab -q
# !pip install lime -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
#   Building wheel for fedlab (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 15.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done

# %%
import random
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import copy
import statistics
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import yaml
import os
from fedlab.utils.dataset.partition import  BasicPartitioner
from torch.utils.data import Subset
import matplotlib.pyplot as plt
from collections import OrderedDict
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
import shap
import hydra
from hydra.core.hydra_config import HydraConfig
from omegaconf import DictConfig, OmegaConf
import random
import numpy as np
import torch
# Set seed for Python's random module
random.seed(42)
# Set seed for NumPy
np.random.seed(42)
# Set seed for PyTorch
torch.manual_seed(42)
import numpy as np
import torch
import torch.nn.functional as F
import random
from lime.lime_tabular import LimeTabularExplainer
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import os
import seaborn as sns
# If you are using CUDA, you may also want to set the seed for GPU operations
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)  # For all GPUs if you have multiple

# %% [markdown]
# num_rounds: 10.
# num_clients: 60.
# num_edges: 10.
#
# config_fit: # a config that each client will receive (this is sent by the server). This allows to dynamically configure the training on the client side as the simulation progresses
#   lr: 0.01 # learning rate to use by the clients
#   momentum: 0.9 # momentum used by SGD optimiser on the client side
#   local_epochs: 20 # number of training epochs each clients does in a fit() round
#   batch_size: 64 # batch size to use by clients during training

# %% [markdown]
# ### 1. Load and preprocess the dataset. Get Training and test dataset

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_flag_distribution(df, class_labels=None):
    """
    Plots the distribution of the 'flag' column in the dataset.

    Parameters:
        df (pd.DataFrame): The dataframe containing the 'flag' column.
        class_labels (dict, optional): A dictionary to map flag values to meaningful class names.
                                       Example: {"R": "Normal", "T": "Attack"}.
    """
    sns.countplot(x="label", data=df, palette="viridis", hue="label", legend=False)
    plt.title("Flag Value Counts")
    if class_labels:
        plt.xticks(
            ticks=range(len(class_labels)),
            labels=[class_labels[label] for label in class_labels]
        )
    plt.show()

def preprocess_dataset():
    processed_file = "/content/drive/MyDrive/car_hacking_dataset/Dataset/Car_Hacking_preprocessed_dataset.csv"
    class_labels = {"R": "Normal", "T": "Attack"}

    # Load processed dataset if it exists
    if os.path.isfile(processed_file):
        df = pd.read_csv(processed_file)
        if "flag" in df.columns and "label" not in df.columns:
            df.rename(columns={"flag": "label"}, inplace=True)
        plot_flag_distribution(df, class_labels)
        return df

    # Raw data file paths
    raw_files = {
        "normal": "/content/drive/MyDrive/Normal_data.csv",
        "dos": "/content/drive/MyDrive/DoS_dataset.csv",
        "fuzzy": "/content/drive/MyDrive/Fuzzy_dataset.csv",
        "gear": "/content/drive/MyDrive/gear_dataset.csv",
        "rpm": "/content/drive/MyDrive/RPM_dataset.csv"
    }

    column_names = ["Timestamp", "ID", "DLC", "Byte1", "Byte2", "Byte3", "Byte4", "Byte5", "Byte6", "Byte7", "Byte8", "flag"]
    dataframes = []

    # Load and process raw files
    for key, path in raw_files.items():
        df = pd.read_csv(path, names=column_names, index_col=False) if key != "normal" else pd.read_csv(path, index_col=False)
        if key == "normal":
            df["flag"] = "R"  # Assign flag for normal data
        dataframes.append(df)

    # Combine all datasets
    df = pd.concat(dataframes, axis=0, ignore_index=True)
    print(f"Total data shape before removing missing data: {df.shape}")

    # Drop rows with missing data
    df.dropna(inplace=True)
    print(f"Total data shape after removing missing data: {df.shape}")

    # Convert Hexadecimal Byte columns to Decimal and drop original Byte columns
    byte_columns = [f"Byte{i}" for i in range(1, 9)]
    for i, byte_col in enumerate(byte_columns):
        df[f"DATA_{i}"] = df[byte_col].apply(lambda x: int(str(x), 16))
    df.drop(columns=byte_columns, inplace=True)

    # Drop unnecessary columns
    df.drop(columns=["Timestamp", "ID", "DLC"], inplace=True)

    # Remove duplicate rows
    df.drop_duplicates(inplace=True)
    print(f"Data shape after removing duplicate entries: {df.shape}")

    # Save the processed dataset
    os.makedirs(os.path.dirname(processed_file), exist_ok=True)
    df.to_csv(processed_file, index=False)

    # Visualize and rename flag column
    plot_flag_distribution(df, class_labels)
    if "flag" in df.columns and "label" not in df.columns:
        df.rename(columns={"flag": "label"}, inplace=True)

    return df

# %%
def prepare_training_testing_data(dataset, test_size=0.30, output_dir="/content/drive/MyDrive/car_hacking_dataset/Dataset"):
    """
    Prepares and pre-processes the dataset for training and testing.

    This function shuffles the dataset, encodes labels, scales features, and splits the data
    into training and testing sets. It also saves the processed training and testing data into CSV files.

    Args:
        dataset (pd.DataFrame): The input dataset containing features and labels.
        test_size (float, optional): Proportion of the dataset to be used for testing. Defaults to 0.30.
        output_dir (str, optional): Directory where processed files will be saved. Defaults to a specified path.

    Returns:
        tuple:
            X_train_scaled (numpy.ndarray): Scaled feature matrix for the training set.
            X_test_scaled (numpy.ndarray): Scaled feature matrix for the test set.
    """
    # Shuffle the dataset
    dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

    # Encode labels
    label_mapping = {"R": 0, "T": 1}
    dataset['label'] = dataset['label'].map(label_mapping)

    # Split into train and test sets
    train_df, test_df = train_test_split(dataset, test_size=test_size, stratify=dataset['label'], random_state=42)

    # Split features and labels
    X_train, y_train = train_df.drop(columns=['label']), train_df['label']
    X_test, y_test = test_df.drop(columns=['label']), test_df['label']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Prepare scaled datasets for saving
    train_df_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    train_df_scaled['label'] = y_train.values

    test_df_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
    test_df_scaled['label'] = y_test.values

    # Save processed datasets
    os.makedirs(output_dir, exist_ok=True)
    train_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_trainset.csv"), index=False)
    test_df_scaled.to_csv(os.path.join(output_dir, "car_hacking_testset.csv"), index=False)

    return X_train_scaled, X_test_scaled

def get_car_hacking_dataset():
    """
    Loads and prepares the CiCiov dataset for training and testing in PyTorch format.

    This function reads the pre-processed train and test CSV files, converts the data into PyTorch tensors,
    and creates TensorDataset objects for both the training and testing data. It also returns the target labels
    separately for both the train and test sets.

    Args:
        None

    Returns:
        tuple:
            train_tensor (torch.utils.data.TensorDataset): Tensor dataset containing training features and labels.
            test_tensor (torch.utils.data.TensorDataset): Tensor dataset containing test features and labels.
            train_target (torch.Tensor): Tensor containing training labels.
            test_target (torch.Tensor): Tensor containing test labels.
    """
    train = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_trainset.csv')
    test = pd.read_csv('/content/drive/MyDrive/car_hacking_dataset/Dataset/car_hacking_testset.csv')
    train_target = torch.tensor(train['label'].values.astype(np.float32))
    train = torch.tensor(train.drop('label', axis = 1).values.astype(np.float32))
    train_tensor = TensorDataset(train, train_target)

    test_target = torch.tensor(test['label'].values.astype(np.float32))
    test = torch.tensor(test.drop('label', axis = 1).values.astype(np.float32))
    test_tensor = TensorDataset(test, test_target)

    return train_tensor , test_tensor ,train_target,test_target

# %%
#  Preprocess the Dataset and ge
df = preprocess_dataset()

# Pre-process the dataset by splitting it into training and testing sets
# The parameter test_size=0.3 indicates that 30% of the data will be used for testing
x_train, x_test = prepare_training_testing_data(df,test_size=0.3)

# Convert the training data (x_train) into a PyTorch tensor of type float32
X_train_tensor = torch.tensor(x_train, dtype=torch.float32)

# Convert the testing data (x_test) into a PyTorch tensor of type float32
X_test_tensor = torch.tensor(x_test, dtype=torch.float32)

# Load the dataset for a specific application (CICIDS dataset)
# The function returns training and testing datasets, as well as their corresponding targets
trainset, testset, train_target, test_target = get_car_hacking_dataset()

# %%
x_train.shape, x_test.shape
# Out:
# ((662360, 8), (283869, 8))

# %%
print(" Label distribution in the Training data",np.unique(train_target, return_counts=True))
print(" Label distribution in the Test data",np.unique(test_target, return_counts=True))
# Out:
#  Label distribution in the Training data (array([0., 1.], dtype=float32), array([318065, 344295]))
#  Label distribution in the Test data (array([0., 1.], dtype=float32), array([136314, 147555]))

# %% [markdown]
# ### 2. Split the Training set into M parts with M-Number of Clients. Here the test set will not be split. It will be used to test the Global Model.

# %%
import torch
from torch.utils.data import DataLoader, Subset

def get_all_labels(dataset):
    """
    Extract all labels from the given dataset.

    Args:
        dataset (Iterable): The dataset from which to extract labels.
                            It should yield pairs of (data, labels).

    Returns:
        torch.Tensor: A tensor containing all the labels stacked together.
    """
    all_labels = []

    # Iterate through the dataset to collect all labels
    for _, labels in dataset:
        all_labels.append(labels)

    # Stack all labels into a single tensor
    all_labels_tensor = torch.stack(all_labels)

    return all_labels_tensor

def split_dataset(train_set, test_set, num_clients, batch_size, partition, dir_alpha=None, major_classes_num=0):
    """
    Split the dataset into multiple clients for federated learning.

    Args:
        train_set (Dataset): The training dataset to be partitioned.
        test_set (Dataset): The testing dataset.
        num_clients (int): The number of clients to split the data among.
        batch_size (int): The batch size for the data loaders.
        partition (str): The type of partitioning ('iid' for independent and identically distributed).
        dir_alpha (float, optional): Dirichlet parameter for non-iid partitioning.
        major_classes_num (int, optional): Number of major classes for partitioning.

    Returns:
        list: A list of DataLoaders for the training sets of each client.
        DataLoader: A DataLoader for the test set.
    """

    # Initialize the partitioner with the labels from the training set
    partitioner = BasicPartitioner(
        get_all_labels(train_set),
        num_clients,
        partition=partition,
        dir_alpha=dir_alpha,
        major_classes_num=major_classes_num,
        seed=2023
    )

    trainloaders = []

    # Create a DataLoader for each client's training set
    for client in range(num_clients):
        idx = partitioner.client_dict[client]  # Get indices for the current client
        trainset_ = Subset(train_set, idx)  # Create a subset for the client

        # Create a DataLoader for the client's training set
        trainloaders.append(DataLoader(trainset_, batch_size=batch_size, shuffle=True))

    # Create a DataLoader for the test set (no shuffling)
    testloader = DataLoader(test_set, batch_size=batch_size)
    # Create a DataLoader for the Training data to get training loss
    raw_train_loader = DataLoader(train_set, batch_size=batch_size)
    return raw_train_loader ,trainloaders, testloader

# %%
import yaml

# Load the configuration from the YAML file
with open('/content/drive/MyDrive/base-scalability.yaml', 'r') as file:
    # Parse the YAML file into a Python dictionary
    cfg = yaml.safe_load(file)

# Split the dataset into training loaders for each client and a test loader
raw_train_loader,trainloaders, testloader = split_dataset(
    trainset,                             # The training dataset
    testset,                              # The testing dataset
    cfg['num_clients'],                   # Number of clients specified in the config
    cfg['config_fit']['batch_size'],      # Batch size specified in the config
    partition='noniid-labeldir',          # Type of partitioning (non-IID based on labels)
    dir_alpha=1                           # Dirichlet parameter for non-IID partitioning
)

# %% [markdown]
# ### 3. Initialize all Client Models with CNN Model and analyze the train loaders for each client local data

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import time


class ANNModel(nn.Module):
    def __init__(self, input_features=8):
        super(ANNModel, self).__init__()

        # Fully connected layers for a simple ANN
        self.fc1 = nn.Linear(input_features, 16)  # First hidden layer with 64 neurons
        self.fc2 = nn.Linear(16, 8)  # Second hidden layer with 32 neurons
        self.fc3 = nn.Linear(8, 1)  # Output layer for binary classification

        # Dropout layer to reduce overfitting
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # Forward pass through fully connected layers with ReLU and dropout
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x


def train(net, trainloader, optimizer, epochs):
    """
    Train a neural network model using a specified optimizer and dataset.
    """
    criterion = nn.BCEWithLogitsLoss()
    net.train()
    start_time = time.time()  # Start time for the training

    for _ in range(epochs):
        for features, labels in trainloader:
            optimizer.zero_grad()
            output = net(features)
            loss = criterion(output.squeeze(1), labels.float())
            loss.backward()
            optimizer.step()

        time.sleep(1)  # Simulate some delay

    end_time = time.time()  # End time for the training
    total_time = end_time - start_time
    return total_time


def evaluate_model(model, test_loader):
    """
    Evaluate a trained neural network model on a test dataset.
    """
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, labels in test_loader:
            outputs = model(data)
            outputs = outputs.squeeze(1)
            loss = F.binary_cross_entropy_with_logits(outputs, labels.float())

            total_loss += loss.item() * data.size(0)
            preds = torch.round(torch.sigmoid(outputs))
            total_correct += (preds == labels).sum().item()
            total_samples += data.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    conf_matrix = confusion_matrix(all_labels, all_preds)

    return avg_loss, accuracy, precision, recall, f1, conf_matrix

# %%
import collections
import statistics
from collections import OrderedDict

class Vehicle():
    """Define a Vehicle Client."""

    def __init__(self, trainloader, id) -> None:
        # the dataloaders that point to the data associated with this client
        self.trainloader = trainloader
        # a model that is randomly initialized at first
        self.model = ANNModel()
        # unique ID for the vehicle
        self.id = id
        print(f"[Vehicle Init] Initialized vehicle client with ID: {self.id}.")
    def __str__(self):
        return f"Vehicle-id={self.id}"

    # If you want a more formal representation, you can also use __repr__:
    def __repr__(self):
        return self.__str__()
    def set_parameters(self, parameters):
        """Receive parameters and apply them to the local model."""
        #print("[set_parameters] Setting parameters for the model...")
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.model.load_state_dict(state_dict, strict=True)
        #print("[set_parameters] Parameters set successfully.")

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""
        #print("[get_parameters] Extracting model parameters...")
        params = [val.cpu().numpy() for _, val in self.model.state_dict().items()]
        #print(f"[get_parameters] Parameters extracted: {len(params)} parameters.")
        return params

    def fit(self, config):
        """Train model received by the server (parameters) using the data
        that belongs to this client. Then, send it back to the server.
        """
        lr = config["lr"]
        momentum = config["momentum"]
        epochs = config["local_epochs"]

        #print(f"[fit] Starting training with ID={self.id}, lr={lr}, momentum={momentum}, epochs={epochs}...")
        optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=momentum, weight_decay=0.01)

        vehicle_time = train(self.model, self.trainloader, optim, epochs)
        #print(f"[fit] Training completed in {vehicle_time} seconds for ID={self.id}.")

        return self.model, len(self.trainloader), vehicle_time#, self.id  # Include ID in the return

def analyze_dataloaders(dataloaders, client_ids):
    """
    Analyze the data distribution of multiple DataLoader objects across different clients.

    This function calculates the label distribution, variance, and number of samples for each client
    from a list of DataLoader objects, which represent the data split for each client. It prints out
    details such as the set of unique labels, the number of samples, and label counts for each client.

    Args:
        dataloaders (list of torch.utils.data.DataLoader): A list of DataLoader objects, where each DataLoader corresponds to a client's data.
        client_ids (list of int or str): A list of client identifiers, which can be integers or strings, corresponding to each DataLoader.

    Returns:
        tuple:
            - label_distribution_per_client (list of list): A list of label distributions for each client. Each element contains the labels from one client's DataLoader.
            - variance_per_client (list of float): A list of variances in label distribution for each client.
            - num_samples_per_client (list of int): A list of the number of samples in each client's dataset.

    Prints:
        - Client ID and associated label information (unique labels, number of samples, label counts).
    """
    print("Analyzing dataloaders...")
    label_distribution_per_client = []
    variance_per_client = []
    num_samples_per_client = []

    for j, dataloader in enumerate(dataloaders):
        labels = []

        for _, batch_labels in dataloader:
            # Append the batch of labels to the list
            labels.extend(batch_labels.tolist())

        label_distribution_per_client.append(labels)
        variance = statistics.variance(labels) if len(labels) > 1 else 0
        variance_per_client.append(variance)
        num_samples = len(labels)
        num_samples_per_client.append(num_samples)

        # Count occurrences of each label
        label_counts = collections.Counter(labels)

        print(f"Client ID: {client_ids[j]}")
        print("Label Category in Vehicle", j, ':', set(labels))
        print("Number of Samples in Vehicle", j, ':', num_samples_per_client[j])
        print("Label Counts in Vehicle", j, ':', dict(label_counts))  # Display value counts for each label
        #print("Variance in Vehicle", j, ':', variance)
        print("*********")


def generate_clients(trainloaders, model):
    """
    Generate client instances from the provided training loaders.

    Args:
        trainloaders (list): A list of DataLoaders for each client's training data.
        model (torch.nn.Module): The model instance to be set for each client.

    Returns:
        list: A list of client instances created from the training loaders.
        list: A list of client IDs corresponding to each created client.
    """
    print(f"Generating clients from {len(trainloaders)} trainloaders...")
    clients = []       # Initialize a list to store client instances
    client_ids = []    # Initialize a list to store client IDs

    # Iterate through the training loaders to create client instances
    for i, trainloader in enumerate(trainloaders):
        cc = Vehicle(trainloader, id=i)  # Create a client instance with the trainloader and a unique ID
        cc.set_parameters(model)           # Set the model parameters for the client
        clients.append(cc)                 # Add the client instance to the list
        client_ids.append(cc.id)           # Store the client ID for reference

    print(f"[generate_clients] Total clients generated: {len(clients)}.\n")
    return clients, client_ids  # Return both the list of clients and their corresponding IDs

# Initialize global model and generate clients
init_global_model = ANNModel()
vehicles, client_ids = generate_clients(trainloaders, init_global_model.state_dict().values())

# Analyze dataloaders and include client IDs
analyze_dataloaders(trainloaders, client_ids)
# Out:
# Generating clients from 60 trainloaders...
# [Vehicle Init] Initialized vehicle client with ID: 0.
# [Vehicle Init] Initialized vehicle client with ID: 1.
# [Vehicle Init] Initialized vehicle client with ID: 2.
# [Vehicle Init] Initialized vehicle client with ID: 3.
# [Vehicle Init] Initialized vehicle client with ID: 4.
# [Vehicle Init] Initialized vehicle client with ID: 5.
# [Vehicle Init] Initialized vehicle client with ID: 6.
# [Vehicle Init] Initialized vehicle client with ID: 7.
# [Vehicle Init] Initialized vehicle client with ID: 8.
# [Vehicle Init] Initialized vehicle client with ID: 9.
# [Vehicle Init] Initialized vehicle client with ID: 10.
# [Vehicle Init] Initialized vehicle client with ID: 11.
# [Vehicle Init] Initialized vehicle client with ID: 12.
# [Vehicle Init] Initialized vehicle client with ID: 13.
# [Vehicle Init] Initialized vehicle client with ID: 14.
# [Vehicle Init] Initialized vehicle client with ID: 15.
# [Vehicle Init] Initialized vehicle client with ID: 16.
# [Vehicle Init] Initialized vehicle client with ID: 17.
# [Vehicle Init] Initialized vehicle client with ID: 18.
# [Vehicle Init] Initialized vehicle client with ID: 19.
# [Vehicle Init] Initialized vehicle client with ID: 20.
# [Vehicle Init] Initialized vehicle client with ID: 21.
# [Vehicle Init] Initialized vehicle client with ID: 22.
# [Vehicle Init] Initialized vehicle client with ID: 23.
# [Vehicle Init] Initialized vehicle client with ID: 24.
# [Vehicle Init] Initialized vehicle client with ID: 25.
# [Vehicle Init] Initialized vehicle client with ID: 26.
# [Vehicle Init] Initialized vehicle client with ID: 27.
# [Vehicle Init] Initialized vehicle client with ID: 28.
# [Vehicle Init] Initialized vehicle client with ID: 29.
# [Vehicle Init] Initialized vehicle client with ID: 30.
# [Vehicle Init] Initialized vehicle client with ID: 31.
# [Vehicle Init] Initialized vehicle client with ID: 32.
# [Vehicle Init] Initialized vehicle client with ID: 33.
# [Vehicle Init] Initialized vehicle client with ID: 34.
# [Vehicle Init] Initialized vehicle client with ID: 35.
# [Vehicle Init] Initialized vehicle client with ID: 36.
# [Vehicle Init] Initialized vehicle client with ID: 37.
# [Vehicle Init] Initialized vehicle client with ID: 38.
# [Vehicle Init] Initialized vehicle client with ID: 39.
# [Vehicle Init] Initialized vehicle client with ID: 40.
# [Vehicle Init] Initialized vehicle client with ID: 41.
# [Vehicle Init] Initialized vehicle client with ID: 42.
# [Vehicle Init] Initialized vehicle client with ID: 43.
# [Vehicle Init] Initialized vehicle client with ID: 44.
# [Vehicle Init] Initialized vehicle client with ID: 45.
# [Vehicle Init] Initialized vehicle client with ID: 46.
# [Vehicle Init] Initialized vehicle client with ID: 47.
# [Vehicle Init] Initialized vehicle client with ID: 48.
# [Vehicle Init] Initialized vehicle client with ID: 49.
# [Vehicle Init] Initialized vehicle client with ID: 50.
# [Vehicle Init] Initialized vehicle client with ID: 51.
# [Vehicle Init] Initialized vehicle client with ID: 52.
# [Vehicle Init] Initialized vehicle client with ID: 53.
# [Vehicle Init] Initialized vehicle client with ID: 54.
# [Vehicle Init] Initialized vehicle client with ID: 55.
# [Vehicle Init] Initialized vehicle client with ID: 56.
# [Vehicle Init] Initialized vehicle client with ID: 57.
# [Vehicle Init] Initialized vehicle client with ID: 58.
# [Vehicle Init] Initialized vehicle client with ID: 59.
# [generate_clients] Total clients generated: 60.
#
# Analyzing dataloaders...
# Client ID: 0
# Label Category in Vehicle 0 : {0.0, 1.0}
# Number of Samples in Vehicle 0 : 1204
# Label Counts in Vehicle 0 : {0.0: 572, 1.0: 632}
# *********
# Client ID: 1
# Label Category in Vehicle 1 : {0.0, 1.0}
# Number of Samples in Vehicle 1 : 14567
# Label Counts in Vehicle 1 : {1.0: 4115, 0.0: 10452}
# *********
# Client ID: 2
# Label Category in Vehicle 2 : {0.0}
# Number of Samples in Vehicle 2 : 11158
# Label Counts in Vehicle 2 : {0.0: 11158}
# *********
# Client ID: 3
# Label Category in Vehicle 3 : {0.0, 1.0}
# Number of Samples in Vehicle 3 : 12601
# Label Counts in Vehicle 3 : {1.0: 8523, 0.0: 4078}
# *********
# Client ID: 4
# Label Category in Vehicle 4 : {0.0, 1.0}
# Number of Samples in Vehicle 4 : 8783
# Label Counts in Vehicle 4 : {1.0: 5899, 0.0: 2884}
# *********
# Client ID: 5
# Label Category in Vehicle 5 : {0.0}
# Number of Samples in Vehicle 5 : 20376
# Label Counts in Vehicle 5 : {0.0: 20376}
# *********
# Client ID: 6
# Label Category in Vehicle 6 : {0.0, 1.0}
# Number of Samples in Vehicle 6 : 12299
# Label Counts in Vehicle 6 : {1.0: 7088, 0.0: 5211}
# *********
# Client ID: 7
# Label Category in Vehicle 7 : {0.0}
# Number of Samples in Vehicle 7 : 14659
# Label Counts in Vehicle 7 : {0.0: 14659}
# *********
# Client ID: 8
# Label Category in Vehicle 8 : {0.0, 1.0}
# Number of Samples in Vehicle 8 : 9399
# Label Counts in Vehicle 8 : {0.0: 4320, 1.0: 5079}
# *********
# Client ID: 9
# Label Category in Vehicle 9 : {0.0, 1.0}
# Number of Samples in Vehicle 9 : 3292
# Label Counts in Vehicle 9 : {0.0: 2255, 1.0: 1037}
# *********
# Client ID: 10
# Label Category in Vehicle 10 : {0.0}
# Number of Samples in Vehicle 10 : 14235
# Label Counts in Vehicle 10 : {0.0: 14235}
# *********
# Client ID: 11
# Label Category in Vehicle 11 : {0.0, 1.0}
# Number of Samples in Vehicle 11 : 9069
# Label Counts in Vehicle 11 : {0.0: 6608, 1.0: 2461}
# *********
# Client ID: 12
# Label Category in Vehicle 12 : {0.0, 1.0}
# Number of Samples in Vehicle 12 : 3842
# Label Counts in Vehicle 12 : {0.0: 2481, 1.0: 1361}
# *********
# Client ID: 13
# Label Category in Vehicle 13 : {0.0, 1.0}
# Number of Samples in Vehicle 13 : 5800
# Label Counts in Vehicle 13 : {0.0: 4358, 1.0: 1442}
# *********
# Client ID: 14
# Label Category in Vehicle 14 : {0.0, 1.0}
# Number of Samples in Vehicle 14 : 9334
# Label Counts in Vehicle 14 : {0.0: 6334, 1.0: 3000}
# *********
# Client ID: 15
# Label Category in Vehicle 15 : {0.0, 1.0}
# Number of Samples in Vehicle 15 : 1857
# Label Counts in Vehicle 15 : {0.0: 1722, 1.0: 135}
# *********
# Client ID: 16
# Label Category in Vehicle 16 : {0.0}
# Number of Samples in Vehicle 16 : 11260
# Label Counts in Vehicle 16 : {0.0: 11260}
# *********
# Client ID: 17
# Label Category in Vehicle 17 : {0.0, 1.0}
# Number of Samples in Vehicle 17 : 7548
# Label Counts in Vehicle 17 : {0.0: 6919, 1.0: 629}
# *********
# Client ID: 18
# Label Category in Vehicle 18 : {0.0, 1.0}
# Number of Samples in Vehicle 18 : 38873
# Label Counts in Vehicle 18 : {1.0: 31706, 0.0: 7167}
# *********
# Client ID: 19
# Label Category in Vehicle 19 : {0.0, 1.0}
# Number of Samples in Vehicle 19 : 24045
# Label Counts in Vehicle 19 : {1.0: 21203, 0.0: 2842}
# *********
# Client ID: 20
# Label Category in Vehicle 20 : {0.0, 1.0}
# Number of Samples in Vehicle 20 : 45844
# Label Counts in Vehicle 20 : {1.0: 44424, 0.0: 1420}
# *********
# Client ID: 21
# Label Category in Vehicle 21 : {0.0, 1.0}
# Number of Samples in Vehicle 21 : 18207
# Label Counts in Vehicle 21 : {1.0: 13875, 0.0: 4332}
# *********
# Client ID: 22
# Label Category in Vehicle 22 : {0.0, 1.0}
# Number of Samples in Vehicle 22 : 4757
# Label Counts in Vehicle 22 : {0.0: 4151, 1.0: 606}
# *********
# Client ID: 23
# Label Category in Vehicle 23 : {0.0, 1.0}
# Number of Samples in Vehicle 23 : 14453
# Label Counts in Vehicle 23 : {0.0: 8302, 1.0: 6151}
# *********
# Client ID: 24
# Label Category in Vehicle 24 : {0.0, 1.0}
# Number of Samples in Vehicle 24 : 2405
# Label Counts in Vehicle 24 : {1.0: 1507, 0.0: 898}
# *********
# Client ID: 25
# Label Category in Vehicle 25 : {0.0}
# Number of Samples in Vehicle 25 : 19960
# Label Counts in Vehicle 25 : {0.0: 19960}
# *********
# Client ID: 26
# Label Category in Vehicle 26 : {0.0, 1.0}
# Number of Samples in Vehicle 26 : 4406
# Label Counts in Vehicle 26 : {0.0: 3875, 1.0: 531}
# *********
# Client ID: 27
# Label Category in Vehicle 27 : {0.0, 1.0}
# Number of Samples in Vehicle 27 : 4432
# Label Counts in Vehicle 27 : {0.0: 3920, 1.0: 512}
# *********
# Client ID: 28
# Label Category in Vehicle 28 : {0.0, 1.0}
# Number of Samples in Vehicle 28 : 5116
# Label Counts in Vehicle 28 : {1.0: 4593, 0.0: 523}
# *********
# Client ID: 29
# Label Category in Vehicle 29 : {0.0, 1.0}
# Number of Samples in Vehicle 29 : 7131
# Label Counts in Vehicle 29 : {1.0: 4010, 0.0: 3121}
# *********
# Client ID: 30
# Label Category in Vehicle 30 : {0.0, 1.0}
# Number of Samples in Vehicle 30 : 21614
# Label Counts in Vehicle 30 : {0.0: 8116, 1.0: 13498}
# *********
# Client ID: 31
# Label Category in Vehicle 31 : {0.0, 1.0}
# Number of Samples in Vehicle 31 : 10858
# Label Counts in Vehicle 31 : {0.0: 3894, 1.0: 6964}
# *********
# Client ID: 32
# Label Category in Vehicle 32 : {0.0, 1.0}
# Number of Samples in Vehicle 32 : 9160
# Label Counts in Vehicle 32 : {1.0: 4726, 0.0: 4434}
# *********
# Client ID: 33
# Label Category in Vehicle 33 : {0.0, 1.0}
# Number of Samples in Vehicle 33 : 11899
# Label Counts in Vehicle 33 : {1.0: 4187, 0.0: 7712}
# *********
# Client ID: 34
# Label Category in Vehicle 34 : {0.0, 1.0}
# Number of Samples in Vehicle 34 : 5223
# Label Counts in Vehicle 34 : {0.0: 4731, 1.0: 492}
# *********
# Client ID: 35
# Label Category in Vehicle 35 : {0.0, 1.0}
# Number of Samples in Vehicle 35 : 15004
# Label Counts in Vehicle 35 : {1.0: 13313, 0.0: 1691}
# *********
# Client ID: 36
# Label Category in Vehicle 36 : {0.0}
# Number of Samples in Vehicle 36 : 12233
# Label Counts in Vehicle 36 : {0.0: 12233}
# *********
# Client ID: 37
# Label Category in Vehicle 37 : {0.0, 1.0}
# Number of Samples in Vehicle 37 : 17685
# Label Counts in Vehicle 37 : {1.0: 12824, 0.0: 4861}
# *********
# Client ID: 38
# Label Category in Vehicle 38 : {0.0, 1.0}
# Number of Samples in Vehicle 38 : 2443
# Label Counts in Vehicle 38 : {1.0: 2228, 0.0: 215}
# *********
# Client ID: 39
# Label Category in Vehicle 39 : {0.0, 1.0}
# Number of Samples in Vehicle 39 : 5517
# Label Counts in Vehicle 39 : {0.0: 1126, 1.0: 4391}
# *********
# Client ID: 40
# Label Category in Vehicle 40 : {0.0, 1.0}
# Number of Samples in Vehicle 40 : 3295
# Label Counts in Vehicle 40 : {1.0: 1532, 0.0: 1763}
# *********
# Client ID: 41
# Label Category in Vehicle 41 : {0.0, 1.0}
# Number of Samples in Vehicle 41 : 9595
# Label Counts in Vehicle 41 : {0.0: 4487, 1.0: 5108}
# *********
# Client ID: 42
# Label Category in Vehicle 42 : {0.0, 1.0}
# Number of Samples in Vehicle 42 : 11504
# Label Counts in Vehicle 42 : {0.0: 9549, 1.0: 1955}
# *********
# Client ID: 43
# Label Category in Vehicle 43 : {0.0, 1.0}
# Number of Samples in Vehicle 43 : 33411
# Label Counts in Vehicle 43 : {1.0: 24148, 0.0: 9263}
# *********
# Client ID: 44
# Label Category in Vehicle 44 : {0.0, 1.0}
# Number of Samples in Vehicle 44 : 5195
# Label Counts in Vehicle 44 : {0.0: 1388, 1.0: 3807}
# *********
# Client ID: 45
# Label Category in Vehicle 45 : {0.0, 1.0}
# Number of Samples in Vehicle 45 : 5601
# Label Counts in Vehicle 45 : {0.0: 860, 1.0: 4741}
# *********
# Client ID: 46
# Label Category in Vehicle 46 : {0.0, 1.0}
# Number of Samples in Vehicle 46 : 11161
# Label Counts in Vehicle 46 : {1.0: 9985, 0.0: 1176}
# *********
# Client ID: 47
# Label Category in Vehicle 47 : {0.0, 1.0}
# Number of Samples in Vehicle 47 : 20484
# Label Counts in Vehicle 47 : {1.0: 13010, 0.0: 7474}
# *********
# Client ID: 48
# Label Category in Vehicle 48 : {0.0, 1.0}
# Number of Samples in Vehicle 48 : 8046
# Label Counts in Vehicle 48 : {0.0: 3534, 1.0: 4512}
# *********
# Client ID: 49
# Label Category in Vehicle 49 : {0.0, 1.0}
# Number of Samples in Vehicle 49 : 8429
# Label Counts in Vehicle 49 : {1.0: 8397, 0.0: 32}
# *********
# Client ID: 50
# Label Category in Vehicle 50 : {0.0, 1.0}
# Number of Samples in Vehicle 50 : 22766
# Label Counts in Vehicle 50 : {0.0: 4236, 1.0: 18530}
# *********
# Client ID: 51
# Label Category in Vehicle 51 : {0.0, 1.0}
# Number of Samples in Vehicle 51 : 7829
# Label Counts in Vehicle 51 : {0.0: 6421, 1.0: 1408}
# *********
# Client ID: 52
# Label Category in Vehicle 52 : {0.0, 1.0}
# Number of Samples in Vehicle 52 : 4201
# Label Counts in Vehicle 52 : {0.0: 2784, 1.0: 1417}
# *********
# Client ID: 53
# Label Category in Vehicle 53 : {0.0, 1.0}
# Number of Samples in Vehicle 53 : 296
# Label Counts in Vehicle 53 : {0.0: 78, 1.0: 218}
# *********
# Client ID: 54
# Label Category in Vehicle 54 : {0.0, 1.0}
# Number of Samples in Vehicle 54 : 2505
# Label Counts in Vehicle 54 : {1.0: 1862, 0.0: 643}
# *********
# Client ID: 55
# Label Category in Vehicle 55 : {0.0, 1.0}
# Number of Samples in Vehicle 55 : 11544
# Label Counts in Vehicle 55 : {0.0: 9883, 1.0: 1661}
# *********
# Client ID: 56
# Label Category in Vehicle 56 : {0.0, 1.0}
# Number of Samples in Vehicle 56 : 9787
# Label Counts in Vehicle 56 : {0.0: 8087, 1.0: 1700}
# *********
# Client ID: 57
# Label Category in Vehicle 57 : {0.0, 1.0}
# Number of Samples in Vehicle 57 : 1070
# Label Counts in Vehicle 57 : {0.0: 1048, 1.0: 22}
# *********
# Client ID: 58
# Label Category in Vehicle 58 : {0.0, 1.0}
# Number of Samples in Vehicle 58 : 4275
# Label Counts in Vehicle 58 : {0.0: 2487, 1.0: 1788}
# *********
# Client ID: 59
# Label Category in Vehicle 59 : {0.0, 1.0}
# Number of Samples in Vehicle 59 : 8818
# Label Counts in Vehicle 59 : {1.0: 5352, 0.0: 3466}
# *********

# %% [markdown]
# ### Assign client models to edge servers and initiate the Edge server with CNN Model parameters
#
# #### Before training (initialization):
# - The global model's initial parameters are distributed to edge servers using `set_parameters`.
# #### After local training:
# - `aggregate_local_models` should be called to aggregate the trained models from all vehicles and update the edge server’s model.

# %%
import random
import copy

def divide_list_randomly(lst, M):
    """
    Divide a list into M random sublists.

    Args:
        lst (list): The list to be divided.
        M (int): The number of sublists to create.

    Returns:
        list: A list of M sublists created from the original list.

    Raises:
        ValueError: If M is greater than the number of elements in the list.
    """
    # Print the size of the list and the number of sublists to be created (commented out for cleaner output)
    # print(f"[divide_list_randomly] Dividing list of size {len(lst)} into {M} random sublists...")
    N = len(lst)

    if M > N:
        raise ValueError("M cannot be greater than the number of elements in the list")

    # Generate M-1 unique random indices to split the list
    indices = sorted(random.sample(range(1, N), M - 1))

    # Include the start and end indices for complete slicing
    indices = [0] + indices + [N]

    # Create sublists based on the generated indices
    sublists = [lst[indices[i]:indices[i + 1]] for i in range(len(indices) - 1)]
    print(f"Spread {N} clients across {len(sublists)} edges, with each edge receiving a subset of clients.")
    return sublists

def weighted_aggregation(w, agg_weights):
    """
    Perform weighted aggregation of model weights.

    Args:
        w (list): A list of models (state_dicts) to be aggregated.
        agg_weights (list): A list of weights corresponding to each model.

    Returns:
        dict: The aggregated weights as a state_dict.

    This function computes a weighted average of the model weights based on the provided aggregation weights.
    """
    # Print start of the aggregation process (commented out for cleaner output)
    # print("[weighted_aggregation] Starting weighted aggregation...")
    w_avg = copy.deepcopy(w[0].state_dict())    # Initialize the average weights with the first model's weights
    total_agg_weights = sum(agg_weights)        # Calculate the total of aggregation weights

    # Compute the initial weighted contribution of the first model
    for key in w_avg.keys():
        w_avg[key] *= (agg_weights[0] / total_agg_weights)

    # Accumulate weighted contributions from the other models
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i].state_dict()[key] * (agg_weights[i] / total_agg_weights)

    print("[weighted_aggregation] Weighted aggregation completed.")
    return w_avg

# %%
class EdgeServer:
    def __init__(self, vehicles, config, edge_id, cache_size):
        self.edge_id = edge_id
        self.vehicles = vehicles
        self.local_model_storage = []
        self.agg_weight = []
        self.model = ANNModel()
        self.config = config
        self.cache_size = cache_size  # Edge server's cache size
        self.total_data_size = 0  # Total data size of cached clients

    def start_training_vehicles(self):
        local_model_storage = []
        agg_weight = []
        edge_time = 0
        submitted_futures = []

        def train_vehicle(vehicle):
            vehicle.set_parameters(self.model.state_dict().values())
            w_vehicle, data_size_vehicle, vehicle_time = vehicle.fit(self.config)
            print(f"[{self.edge_id}] Vehicle {vehicle.id} trained with time: {vehicle_time}")
            return w_vehicle, data_size_vehicle, vehicle_time, vehicle.id

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = [executor.submit(train_vehicle, vehicle) for vehicle in self.vehicles]

            # Process completed futures until cache is full
            for future in concurrent.futures.as_completed(futures):
                if len(local_model_storage) >= self.cache_size:
                    # Cancel remaining futures
                    for f in futures:
                        f.cancel()
                    break
                try:
                    w_vehicle, data_size_vehicle, vehicle_time, _ = future.result()
                    local_model_storage.append(w_vehicle)
                    agg_weight.append(data_size_vehicle)
                    edge_time = max(edge_time, vehicle_time)
                except concurrent.futures.CancelledError:
                    continue

        # Truncate to cache_size if more were added
        self.local_model_storage = local_model_storage[:self.cache_size]
        self.agg_weight = agg_weight[:self.cache_size]
        print(f"[{self.edge_id}] Training completed with {len(self.local_model_storage)} models.")
        return edge_time, self.local_model_storage, self.agg_weight

    def aggregate_local_models(self):
        # Aggregate only cached models
        cached_models = self.local_model_storage[:self.cache_size]
        cached_agg_weights = self.agg_weight[:self.cache_size]
        self.total_data_size = sum(cached_agg_weights)  # Track total data for cloud aggregation

        parameters = weighted_aggregation(cached_models, cached_agg_weights)
        self.set_parameters(parameters.values())
        print(f"[{self.edge_id}] Aggregated {len(cached_models)} local models.")
        #return self.get_parameters()


    def set_parameters(self, parameters):
        """Receive parameters and apply them to the local model."""
        #print(f"[{self.edge_id}] Setting parameters for the model...")
        params_dict = zip(self.model.state_dict().keys(), parameters)

        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})

        self.model.load_state_dict(state_dict, strict=True)
        print(f"[{self.edge_id}] Parameters set.")

    def get_parameters(self):
        """Extract model parameters and return them as a list of numpy arrays."""
        #print(f"[{self.edge_id}] Extracting model parameters...")
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

#    def aggregate_local_models(self):
#        # Gather the IDs of clients whose models are being aggregated
#        client_ids = [vehicle.id for vehicle in self.vehicles]
#
#        print(f"[{self.edge_id}] Aggregating local models from clients: {client_ids}...")
#
#        parameters = weighted_aggregation(self.local_model_storage, self.agg_weight)
#        self.set_parameters(parameters.values())
#
#        print(f"[{self.edge_id}] Local models aggregated for clients: {client_ids}.")

    def update_vehicles(self):
        for vehicle in self.vehicles:
            vehicle.set_parameters(self.get_parameters())

# %%
def spawn_edge_servers(vehicles, num_edges, config, parameters):
    """
    Spawns a specified number of edge servers, each assigned a subset of vehicles.

    Args:
        vehicles (list): List of vehicle instances to be managed by edge servers.
        num_edges (int): Number of edge servers to spawn.
        config (dict): Configuration parameters for the edge servers.
        parameters (dict): Parameters to set for the edge servers' models.

    Returns:
        tuple: A tuple containing:
            - edge_servers (list): List of spawned EdgeServer instances.
            - edge_server_vehicle_map (dict): Mapping of edge server IDs to their respective vehicle IDs.
    """
    # print(f"[spawn_edge_servers] Spawning {num_edges} edge servers...")

    # Create a dictionary to hold the mapping from edge servers to vehicles
    edge_server_vehicle_map = {}

    edge_servers = []  # List to store edge server instances
    # Divide the vehicles randomly among the edge servers
    vehicles_per_edge = divide_list_randomly(vehicles, num_edges)

    for i in range(num_edges):
        # Create an EdgeServer instance for each edge server
        edge = EdgeServer(vehicles_per_edge[i], config, f"edge-{i}")
        edge.set_parameters(parameters)  # Set the model parameters for the edge server
        edge_servers.append(edge)  # Add the edge server to the list

        # Get IDs of vehicles assigned to the current edge server
        vehicle_ids = [vehicle.id for vehicle in vehicles_per_edge[i]]
        # Map the edge server ID to its corresponding vehicle IDs
        edge_server_vehicle_map[f"edge-{i}"] = vehicle_ids

    # print(f"[spawn_edge_servers] Spawned {len(edge_servers)} edge servers.")
    print(f"[spawn_edge_servers] Vehicle mapping to edge servers: {edge_server_vehicle_map}")

    return edge_servers, edge_server_vehicle_map  # Return the list of edge servers and their vehicle mappings

# %%
import random

def divide_list_randomly(lst, M):
    """
    Divide a list into M random sublists with each sublist having at least one element.

    Args:
        lst (list): The list to be divided.
        M (int): The number of sublists to create.

    Returns:
        list: A list of M sublists created from the original list.

    Raises:
        ValueError: If M is greater than the number of elements in the list.
    """
    N = len(lst)

    if M > N:
        raise ValueError("M cannot be greater than the number of elements in the list")

    # Shuffle the original list to randomize the indices
    shuffled_list = lst[:]
    random.shuffle(shuffled_list)

    # Allocate 1 element to each sublist to ensure the condition
    sublist_sizes = [1] * M
    remaining_elements = N - M

    # Distribute remaining elements randomly across the sublists
    for _ in range(remaining_elements):
        sublist_sizes[random.randint(0, M - 1)] += 1

    # Divide the shuffled list into M random sublists based on generated sizes
    sublists = []
    start = 0
    for size in sublist_sizes:
        sublists.append(shuffled_list[start:start + size])
        start += size

    print(f"Spread {N} clients across {M} edges, with each edge receiving a random subset of clients.")
    return sublists

def spawn_edge_servers(vehicles, num_edges, config, parameters,edge_cache_size=4):
    """
    Spawns a specified number of edge servers, each assigned a subset of vehicles.

    Args:
        vehicles (list): List of vehicle instances to be managed by edge servers.
        num_edges (int): Number of edge servers to spawn.
        config (dict): Configuration parameters for the edge servers.
        parameters (dict): Parameters to set for the edge servers' models.

    Returns:
        tuple: A tuple containing:
            - edge_servers (list): List of spawned EdgeServer instances.
            - edge_server_vehicle_map (dict): Mapping of edge server IDs to their respective vehicle IDs.
    """
    # print(f"[spawn_edge_servers] Spawning {num_edges} edge servers...")

    # Create a dictionary to hold the mapping from edge servers to vehicles
    edge_server_vehicle_map = {}

    edge_servers = []  # List to store edge server instances
    # Divide the vehicles randomly among the edge servers
    vehicles_per_edge = divide_list_randomly(vehicles, num_edges)

    for i in range(num_edges):
        # Create an EdgeServer instance for each edge server
        edge = EdgeServer(vehicles_per_edge[i], config, f"edge-{i}", edge_cache_size)

        edge.set_parameters(parameters)  # Set the model parameters for the edge server
        edge_servers.append(edge)  # Add the edge server to the list

        # Get IDs of vehicles assigned to the current edge server
        vehicle_ids = [vehicle.id for vehicle in vehicles_per_edge[i]]
        # Map the edge server ID to its corresponding vehicle IDs
        edge_server_vehicle_map[f"edge-{i}"] = vehicle_ids

    # print(f"[spawn_edge_servers] Spawned {len(edge_servers)} edge servers.")
    print(f"[spawn_edge_servers] Vehicle mapping to edge servers: {edge_server_vehicle_map}")

    return edge_servers, edge_server_vehicle_map  # Return the list of edge servers and their vehicle mappings

# %%
## Define the edge servers and the cloud server
# Spawn edge servers and map vehicle IDs
edge_servers, edge_server_vehicle_map = spawn_edge_servers(vehicles, cfg['num_edges'], cfg['config_fit'], init_global_model.state_dict().values(),edge_cache_size=4)
# Out:
# Spread 60 clients across 10 edges, with each edge receiving a random subset of clients.
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [spawn_edge_servers] Vehicle mapping to edge servers: {'edge-0': [38, 23, 54, 11], 'edge-1': [16, 20, 55, 58, 33, 19], 'edge-2': [9, 36, 31, 45, 30, 49], 'edge-3': [3, 21, 50, 4, 29, 10, 59, 22, 41, 24, 0], 'edge-4': [44, 25, 52, 18, 28, 39, 26], 'edge-5': [48, 12, 35, 42, 32, 53, 13, 46], 'edge-6': [57, 2, 27, 37, 5], 'edge-7': [34, 51, 43, 6, 56], 'edge-8': [8, 14, 15], 'edge-9': [17, 47, 1, 7, 40]}

# %% [markdown]
# ### Initiate Cloud Server Model and set up the Global Model parameters with CNN Model

# %%
class CloudServer:
    """
    Modified Cloud Server for SFL2 with cache-based aggregation.
    """
    def __init__(self, edge_servers, cloud_cache_size=4):
        self.edge_servers = edge_servers
        self.cache_size = cloud_cache_size  # Cloud server's cache capacity
        self.model = ANNModel()
        self.cache = []  # Stores sub-global models from edges
        print(f"[CloudServer] Initialized with cache size {cloud_cache_size}.")

#   def update_global_model(self):
#       """Aggregate sub-global models only when the cloud cache is full."""
#       if len(self.cache) < self.cloud_cache_size:
#           print("[CloudServer] Cache not full. Skipping global aggregation.")
#           return
#
#       # Perform aggregation
#       aggregated_params = weighted_aggregation(
#           [edge.model for edge in self.cache],
#           [1]*len(self.cache)  # Equal weights
#       ).values()
#       self.set_parameters(aggregated_params)
#       self.cache.clear()  # Reset cache after aggregation
#       print("[CloudServer] Global model updated.")
    def update_global_model(self):
        sub_global_models = []
        agg_weights = []

        # Collect sub-global models until cloud's cache is full
        for edge in self.edge_servers:
            if len(sub_global_models) >= self.cache_size:
                break
            sub_global_models.append(edge.model)
            agg_weights.append(edge.total_data_size)  # Weight by edge's total data

        # Aggregate using cached sub-global models
        aggregated_params = weighted_aggregation(sub_global_models, agg_weights).values()
        self.set_parameters(aggregated_params)
        print(f"[Cloud] Aggregated {len(sub_global_models)} sub-global models.")

    def receive_sub_global_model(self, edge_params):
        """Receive sub-global model from an edge server and update cache."""
        if len(self.cache) < self.cloud_cache_size:
            self.cache.append(edge_params)
            print(f"[CloudServer] Received sub-global model. Cache size: {len(self.cache)}")
        else:
            print("[CloudServer] Cache full. Discarding sub-global model.")

    def set_parameters(self, parameters):
        """
        Receives parameters and applies them to the local model.

        Args:
            parameters (iterable): The parameters to set in the model.
        """
        # Create a state dict from the provided parameters and load into the model
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.model.load_state_dict(state_dict, strict=True)  # Load parameters into the model
        print("[set_parameters] Parameters set to the model.")

    def get_parameters(self):
        """
        Extracts the model parameters and returns them as a list of numpy arrays.

        Returns:
            list: A list of model parameters as numpy arrays.
        """
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]  # Return parameters as numpy arrays

    def update_edge_servers(self):
        """
        Updates all edge servers with the global model parameters.

        This method sends the current global model parameters to each edge server
        to ensure they have the latest updates.
        """
        print("[update_edge_servers] Updating edge servers with global parameters...")
        for edge_server in self.edge_servers:
            edge_server.set_parameters(self.get_parameters())  # Update edge server with global parameters
        print("[update_edge_servers] Edge servers updated.")

# %%
    cloud_server = CloudServer(edge_servers, cloud_cache_size=4)
# Out:
# [CloudServer] Initialized with cache size 4.

# %% [markdown]
# ### Run the Ensuring Completion Algorithm

# %%
import matplotlib.pyplot as plt
import shap
def shap_method(model, method_name, x_train, x_test):
    """
    Generates SHAP (SHapley Additive exPlanations) summary plot for a given model and saves the results.

    This function computes SHAP values for a given trained model and test data using the DeepExplainer,
    creates a summary plot for feature importance, and saves the plot to a specified directory.

    Args:
        model (torch.nn.Module): The trained PyTorch model to be explained.
        method_name (str): The name of the method, used for naming and organizing output files.
        x_train (torch.Tensor): The training data tensor, used by the SHAP explainer to compute expected outputs.
        x_test (torch.Tensor): The test data tensor, used to compute SHAP values and generate the summary plot.

    Returns:
        None: The function saves the SHAP summary plot to the specified directory and prints the path to the saved plot.

    Side Effects:
        - Saves a SHAP summary plot as a PNG image in the specified directory.
        - Displays the SHAP plot inline (if running in an environment that supports plotting).
    """
    # Create the directory for saving SHAP results
    path = f"/content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/shap_results"
    os.makedirs(path, exist_ok=True)

    model.eval()
    explainer = shap.DeepExplainer(model, x_train)

    # Calculate SHAP values
    shap_values = explainer.shap_values(x_test, check_additivity=False)

    # Reshape SHAP values if needed
    shap_values_reshaped = shap_values.squeeze()

    feature_names=['DATA_0','DATA_1','DATA_2','DATA_3','DATA_4','DATA_5','DATA_6','DATA_7']
    # Summary plot
    shap.summary_plot(shap_values_reshaped, x_test.numpy(), show=False,feature_names=feature_names)

    # Save the summary plot in the specified path
    plt.savefig(os.path.join(path, f'shap_summary_{method_name}.png'), bbox_inches='tight')

    # Show the summary plot
    plt.show()  # This will display the plot in the output
    plt.close()  # Close the plot to free memory
    print(f'SHAP summary plot saved as {os.path.join(path, f"shap_summary_{method_name}.png")}')


# Function to save the model with a specified name format
def save_model(model, round_num, method_name, file_path="model_checkpoint"):
    path=f"/content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/{method_name}"
    os.makedirs(path, exist_ok=True)
    model_name = f"{path}/model_{method_name}_round_{round_num}.pth"
    torch.save(model.state_dict(), model_name)
    print(f"Model saved as {model_name}")

# %%
''' def launch_training_edge_server(edge):
    """
    Launches training for an edge server with CACHE-BASED TERMINATION.
    """
    print(f"[SFL2] Launching training for edge {edge.edge_id} with cache size {edge.cache_size}...")
    start_time=time.time()
    etime, lms, agw = edge.start_training_vehicles()  # This now uses cache-based termination
    time_taken=time.time()-start_time
    #print(f"[SFL2] Edge {edge.edge_id} trained {len(lms)}/{len(edge.vehicles)} vehicles (cache full). Time: {etime}")
    #print(f"[SFL2] Edge {edge.edge_id} trained {len(lms)}/{len(edge.vehicles)} vehicles (cache full). Time taken  by edge server: {time_taken}")
    return (edge.edge_id, edge.vehicles, etime, lms, agw)

def cache_based_mechanism(edge_servers, cloud_server, round_num):
    """
    Manages training with CACHE-BASED termination at both edge and cloud levels.
    """
    print(f"\n[SFL2] Starting CACHE-BASED training for round {round_num}...\n")

    # Step 1: Train edge servers (cache-based termination)
    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = list(executor.map(launch_training_edge_server, edge_servers))

    edge_results = []
    for result in results:
        edge_id, vehicles, edge_time, lms, agw = result
        edge = next(edge for edge in edge_servers if edge.edge_id == edge_id)

        # Update edge server with cached models (not all vehicles)
        edge.local_model_storage = lms
        edge.agg_weight = agw
        edge.aggregate_local_models()  # Aggregates only cached models
        edge_results.append(result)

    # Step 2: Cloud aggregates SUB-GLOBAL models until its cache is full
    print("\n[SFL2] Updating cloud server with cached sub-global models...")
    cloud_server.update_global_model()  # Cloud uses its own cache logic

    # Step 3: Distribute global model back (only to edges that participated)
    cloud_server.update_edge_servers()

    # Step 4: Update vehicles (only those that were cached)
    for edge in edge_servers:
        edge.update_vehicles()

    print(f"\n[SFL2] Round {round_num} summary:")
    for result in edge_results:
        edge_id = result['edge_id']
        print(f"Edge {edge_id} trained {len(result['local_model_storage'])}/{len(result['vehicles'])} vehicles.")

    return edge_results
 '''
# Out:
# ' def launch_training_edge_server(edge):\n    """\n    Launches training for an edge server with CACHE-BASED TERMINATION.\n    """\n    print(f"[SFL2] Launching training for edge {edge.edge_id} with cache size {edge.cache_size}...")\n    start_time=time.time()\n    etime, lms, agw = edge.start_training_vehicles()  # This now uses cache-based termination\n    time_taken=time.time()-start_time\n    #print(f"[SFL2] Edge {edge.edge_id} trained {len(lms)}/{len(edge.vehicles)} vehicles (cache full). Time: {etime}")\n    #print(f"[SFL2] Edge {edge.edge_id} trained {len(lms)}/{len(edge.vehicles)} vehicles (cache full). Time taken  by edge server: {time_taken}")\n    return (edge.edge_id, edge.vehicles, etime, lms, agw)\n\ndef cache_based_mechanism(edge_servers, cloud_server, round_num):\n    """\n    Manages training with CACHE-BASED termination at both edge and cloud levels.\n    """\n    print(f"\n[SFL2] Starting CACHE-BASED training for round {round_num}...\n")\n\n    # Step 1: Train edge servers (cache-based termination)\n    with concurrent.futures.ProcessPoolExecutor() as executor:\n        results = list(executor.map(launch_training_edge_server, edge_servers))\n\n    edge_results = []\n    for result in results:\n        edge_id, vehicles, edge_time, lms, agw = result\n        edge = next(edge for edge in edge_servers if edge.edge_id == edge_id)\n\n        # Update edge server with cached models (not all vehicles)\n        edge.local_model_storage = lms\n        edge.agg_weight = agw\n        edge.aggregate_local_models()  # Aggregates only cached models\n        edge_results.append(result)\n\n    # Step 2: Cloud aggregates SUB-GLOBAL models until its cache is full\n    print("\n[SFL2] Updating cloud server with cached sub-global models...")\n    cloud_server.update_global_model()  # Cloud uses its own cache logic\n\n    # Step 3: Distribute global model back (only to edges that participated)\n    cloud_server.update_edge_servers()\n\n    # Step 4: Update vehicles (only those that were cached)\n    for edge in edge_servers:\n        edge.update_vehicles()\n\n    print(f"\n[SFL2] Round {round_num} summary:")\n    for result in edge_results:\n        edge_id = result[\'edge_id\']\n        print(f"Edge {edge_id} trained {len(result[\'local_model_storage\'])}/{len(result[\'vehicles\'])} vehicles.")\n\n    return edge_results\n '

# %%
def launch_training_edge_server(edge):
    """Launches training for an edge server with CACHE-BASED TERMINATION."""
    print(f"[SFL2] Launching training for edge {edge.edge_id} with cache size {edge.cache_size}...")
    start_time = time.time()
    etime, lms, agw = edge.start_training_vehicles()
    time_taken = time.time() - start_time

    # Return a dictionary instead of a tuple
    return {
        "edge_id": edge.edge_id,
        "vehicles": edge.vehicles,
        "training_time": etime,
        "local_model_storage": lms,
        "agg_weight": agw
    }

def cache_based_mechanism(edge_servers, cloud_server, round_num):
    print(f"\nStarting the training process for round {round_num} on edge servers...\n")
    edge_results = []

    # Launch training on edge servers
    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = list(executor.map(launch_training_edge_server, edge_servers))

    # Collect results into edge_results
    for result in results:
        edge_results.append(result)

    # Update edge servers with results
    for result in edge_results:
        edge_id = result["edge_id"]  # Now works because result is a dictionary
        edge = next(edge for edge in edge_servers if edge.edge_id == edge_id)
        edge.local_model_storage = result["local_model_storage"]
        edge.agg_weight = result["agg_weight"]
        edge.aggregate_local_models()

    # Update cloud and vehicles (same as before)
    cloud_server.update_global_model()
    cloud_server.update_edge_servers()
    for edge in edge_servers:
        edge.update_vehicles()

    print(f"\n[SFL2] Round {round_num} summary:")
    for result in edge_results:
        print(f"Edge {result['edge_id']} trained {len(result['local_model_storage'])}/{len(result['vehicles'])} vehicles.")

    return edge_results

# %%
# Function to generate LIME explanation
def generate_lime_explanation(x_train_tensor, x_test_tensor, model, method_name, random_instance=True, instance_index=None):
    """
    Generate LIME explanations for a model and save the plot.

    Parameters:
    - x_train_tensor: Training data as a PyTorch tensor
    - x_test_tensor: Test data as a PyTorch tensor
    - model: The PyTorch model to explain
    - method_name: The name of the LIME method for labeling
    - random_instance: Whether to select a random instance from the test set
    - instance_index: Specific index of the instance to explain (optional)
    """

    # Create the directory for saving LIME results
    save_path = f"/content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/lime_results"
    os.makedirs(save_path, exist_ok=True)

    # Convert tensors to NumPy arrays
    x_train_np = x_train_tensor.numpy()
    x_test_np = x_test_tensor.numpy()

    # Get feature names (assuming 8 features)
    num_features = x_train_np.shape[1]
    #features = [f"Feature {i+1}" for i in range(num_features)]
    features=["DATA_0",	"DATA_1",	"DATA_2",	"DATA_3",	"DATA_4",	"DATA_5",	"DATA_6",	"DATA_7"]
    # Ensure the model is in evaluation mode
    model.eval()

    # Randomly select an instance from the test dataset, or use a specific index if provided
    if random_instance:
        instance_index = random.randint(0, len(x_test_np) - 1)
    instance_index=153709
    selected_instance = x_test_np[instance_index]

    # Create a LIME explainer for tabular data
    explainer = LimeTabularExplainer(x_train_np, feature_names=features, class_names=['Normal', 'Attack'],
                                     discretize_continuous=True)

    # Modified cnn_predict function to return probabilities for binary classification
    def cnn_predict(input_data):
        """
        Modified cnn_predict function to return probabilities for binary classification.

        Args:
        input_data (list of NumPy arrays): Input data to make predictions on.

        Returns:
        probabilities (NumPy array): Predicted probabilities for the positive class.
        """

        # Convert the input_data (list of NumPy arrays) to a single NumPy array before creating the tensor
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)

        # Ensure the model is in evaluation mode
        model.eval()

        with torch.no_grad():
            output = model(input_tensor)

            # Check for NaN or infinity values in the output
            if torch.isnan(output).any() or torch.isinf(output).any():
                raise ValueError("Model output contains NaN or infinity values.")

            # Apply sigmoid to get probabilities
            probabilities = torch.sigmoid(output).numpy()

        # Convert to 2-class probabilities (positive class and negative class)
        probabilities = np.hstack([1 - probabilities, probabilities])

        # Check for constant predictions
        if np.all(probabilities == probabilities[0]):
            print("Warning: Model returned constant predictions.")

        return probabilities

    # Generate LIME explanation for the selected instance with more samples (increased to 10000)
    explanation = explainer.explain_instance(selected_instance, cnn_predict, num_features=num_features, num_samples=10000)

    # Save the plot
    plot_path = f"{save_path}lime_explanation_{method_name}.png"
    explanation.as_pyplot_figure()
    #plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})-{method_name}-Global Model")
    plt.savefig(plot_path, bbox_inches='tight')
    plt.show()  # This will display the plot in the output
    plt.close()
    print(f"LIME explanation plot saved to {plot_path}")

    return explanation, selected_instance, instance_index

# Function to calculate local fidelity (R² score)
def evaluate_local_fidelity(explanation, model, selected_instance):
    # Get LIME's surrogate predictions
    lime_surrogate_predictions = explanation.local_pred

    # Get CNN model's predictions for the selected instance
    def cnn_predict(input_data):
        input_tensor = torch.tensor(np.array(input_data), dtype=torch.float32)
        with torch.no_grad():
            output = torch.sigmoid(model(input_tensor)).numpy()
        return output

    cnn_predictions = cnn_predict([selected_instance])[0]

    # Check for constant predictions
    if np.all(cnn_predictions == cnn_predictions[0]):
        print("Warning: Model returned constant predictions. R² score cannot be calculated.")
        return np.nan

    # Calculate R² score to measure local fidelity
    local_fidelity = r2_score(cnn_predictions, lime_surrogate_predictions)

    return local_fidelity

# Function to plot feature importance
def plot_feature_importance(explanation, instance_index):
    # Plot the feature importance from LIME
    explanation.as_pyplot_figure()
    plt.title(f"LIME Explanation for Instance (Index: {instance_index})")
    plt.show()

def plot_confusion_matrix(cm, title='Confusion Matrix', class_labels=['Normal', 'Attack'], figsize=(8, 6)):
    """
    Plots a confusion matrix using seaborn heatmap.

    Args:
    cm (numpy.ndarray): Confusion matrix (2x2) array.
    title (str): Title of the plot.
    class_labels (list): Custom labels for the classes.
    figsize (tuple): Size of the figure.

    Returns:
    None
    """
    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16}, linewidths=0.5)

    # Add labels, title, and axes
    plt.xlabel('Target (Actual Class)', fontsize=12)
    plt.ylabel('Output (Predicted Class)', fontsize=12)
    plt.title(title, fontsize=14)

    # Custom tick labels for the classes
    plt.xticks([0.5, 1.5], class_labels, rotation=0)
    plt.yticks([0.5, 1.5], class_labels, rotation=0)

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
def run_fl_training(cfg, cloud_server, edge_servers,train_loader, testloader, X_train_tensor, X_test_tensor, method_name,  save_path="model_checkpoint"):
    """
    Run the Federated Learning (FL) training loop with multiple rounds and evaluate the global model performance.

    Args:
        cfg (dict): Configuration settings for the FL training, including the number of rounds.
        cloud_server (CloudServer): The cloud server that coordinates model aggregation and updates with edge servers.
        edge_servers (list): List of EdgeServer objects responsible for training local models using vehicle data.
        testloader (DataLoader): DataLoader object for the test dataset, used to evaluate the global model.
        X_train_tensor (torch.Tensor): Tensor containing a sample of the training data for SHAP analysis.
        X_test_tensor (torch.Tensor): Tensor containing a sample of the test data for SHAP analysis.
        method_name (str): The name of the method used for saving models and results.
        save_path (str, optional): Directory path where the models will be saved. Defaults to "model_checkpoint".

    Returns:
        None: This function does not return any value. It saves models and results at each round of FL, performs evaluation, and stores SHAP analysis.

    The training process includes:
        - Running multiple rounds of training across edge servers.
        - Aggregating the results at the cloud server.
        - Evaluating the global model after each round.
        - Logging the time taken for each round and total training time.
        - Saving the model checkpoints after each round.
        - Saving round results to a CSV file for further analysis.
        - Running SHAP analysis on the final global model to assess feature importance.

    The function outputs the following at each round:
        - Loss, Accuracy, Precision, Recall, F1 Score for the global model.
        - Total round time and overall training time.
        - A final SHAP analysis of the trained global model.
    """
    fl_time = []
    round_results = []
    train_losses = []  # Track training loss for each round
    test_losses = []   # Track testing loss for each round
    results_path = f"/content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/results"
    os.makedirs(results_path, exist_ok=True)

    start_time = time.time()
    total_time = 0

    for round_num in range(cfg['num_rounds']):
        print(f'\n  FL Global Training Round SFL2: {round_num + 1} \n')

        round_start_time = time.time()  # Start time for this round

        # Ensuring completion and collecting results
        edge_results = cache_based_mechanism(edge_servers, cloud_server, round_num + 1)

        # Calculate the total time for this round
        total_round_time = time.time() - round_start_time  # Calculate round time
        fl_time.append(total_round_time)  # Store round time
        total_time += total_round_time ## Total time

        # Evaluating model performance
        loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
        print(f'Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 = {f1}, Total Time for  {round_num + 1}= {total_round_time:.2f} seconds')

        train_loss, _, _, _, _, _ = evaluate_model(cloud_server.model,train_loader)
        train_losses.append(train_loss)
        test_losses.append(loss)
        # Saving the model after each round
        save_model(cloud_server.model, round_num + 1, method_name, file_path=save_path)

        # Collecting round results
        round_results.append({
            "Round": round_num + 1,
            "Loss": loss,
            "Accuracy": accuracy,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Total Round Time": total_round_time,  # Store the time taken for this round
            "Edge Results": edge_results,  # Includes vehicles and times for each edge server
            "Train_Loss":train_loss,
            "Test_loss":loss
        })
    # Logging total training time
    end_time = time.time()
    total_time_taken = end_time - start_time
    print(f"Total training time for all rounds by end and start time by SFL2: {total_time:.2f} seconds")
    print(f"Total training time for all rounds: {total_time:.2f} seconds")
    # Final model evaluation
    # Measure testing time
    test_start_time = time.time()
    loss, accuracy, precision, recall, f1, conf_matrix = evaluate_model(cloud_server.model, testloader)
    test_end_time = time.time()

    testing_time = test_end_time - test_start_time

    print(f'Final model results: Loss = {loss}, Accuracy = {accuracy}, Precision = {precision}, Recall = {recall}, F1 = {f1}')
    print(f'Confusion Matrix:\n{conf_matrix}')
    print(f'Testing Time: {testing_time:.2f} seconds')
    # Appending the final round results
    round_results.append({
        "Round": "Final",
        "Loss": loss,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "FL Time": fl_time,  # Include all round times
        "Confusion Matrix": conf_matrix,
    })

    # Saving the final model
    save_model(cloud_server.model, cfg['num_rounds'], method_name, file_path=save_path)

    # Append total time to the round results
    round_results.append({
        "Round": "Total Time",
        "FL Time": total_time,
        "Round Times": fl_time,  # Optional: store each round time
        "Testing Time": testing_time
})

    # Save results to CSV
    df_results = pd.DataFrame(round_results)
    df_results.to_csv(os.path.join(results_path, f"{method_name}_results.csv"), index=False)
    print(f"Training results saved to {results_path}/{method_name}_results.csv")
    plot_confusion_matrix(conf_matrix)
    ## Generate Lime explanation
    lime_start_time = time.time()
    explanation, selected_instance, instance_index = generate_lime_explanation(X_train_tensor, X_test_tensor, cloud_server.model, method_name)
    lime_end_time = time.time()

    lime_time = lime_end_time - lime_start_time
    print(f"Total time taken for Lime Explanation: {lime_time:.2f} seconds")

    # Running SHAP analysis
    shap_start_time = time.time()
    shap_method(cloud_server.model, method_name, X_train_tensor[:100], X_test_tensor)
    shap_end_time = time.time()
    shap_time = shap_end_time - shap_start_time
    print(f"Total time taken for Shap Explanation: {shap_time:.2f} seconds")

    return df_results

# %%
results=run_fl_training(cfg, cloud_server, edge_servers,raw_train_loader, testloader, X_train_tensor, X_test_tensor, method_name="SFL2", save_path="model_checkpoint")
# Out:
#   FL Global Training Round SFL2: 1
#
#
# Starting the training process for round 1 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...
# [SFL2] Launching training for edge edge-7 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...[SFL2] Launching training for edge edge-3 with cache size 4...[SFL2] Launching training for edge edge-4 with cache size 4...
#
#
# [edge-5] Vehicle 53 trained with time: 21.056930780410767
# [edge-6] Vehicle 57 trained with time: 23.642050743103027
# [edge-0] Vehicle 38 trained with time: 26.719096899032593
# [edge-0] Vehicle 54 trained with time: 26.85719609260559
# [edge-3] Vehicle 0 trained with time: 29.48615050315857
# [edge-2] Vehicle 9 trained with time: 33.40130424499512
# [edge-6] Vehicle 27 trained with time: 33.68452858924866
# [edge-7] Vehicle 34 trained with time: 37.51836276054382
# [edge-0] Vehicle 11 trained with time: 37.67360997200012
# [edge-5] Vehicle 12 trained with time: 38.350647926330566
# [edge-3] Vehicle 24 trained with time: 38.65809917449951
# [edge-1] Vehicle 58 trained with time: 39.49977731704712
# [edge-4] Vehicle 52 trained with time: 39.60307788848877
# [edge-4] Vehicle 26 trained with time: 40.50502038002014
# [edge-2] Vehicle 45 trained with time: 41.611119985580444
# [edge-4] Vehicle 28 trained with time: 42.87456798553467
# [edge-0] Vehicle 23 trained with time: 44.61451864242554
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-4] Vehicle 44 trained with time: 44.713292360305786
# [edge-7] Vehicle 51 trained with time: 44.817095041275024
# [edge-4] Vehicle 39 trained with time: 46.097280979156494
# [edge-5] Vehicle 13 trained with time: 46.85732078552246
# [edge-6] Vehicle 2 trained with time: 49.83954572677612[edge-2] Vehicle 49 trained with time: 49.815091609954834
#
# [edge-7] Vehicle 56 trained with time: 50.93454074859619
# [edge-5] Vehicle 48 trained with time: 54.23399758338928
# [edge-2] Vehicle 31 trained with time: 55.371023416519165
# [edge-3] Vehicle 22 trained with time: 55.560253381729126
# [edge-7] Vehicle 6 trained with time: 57.225252628326416
# [edge-5] Vehicle 32 trained with time: 57.31802487373352
# [edge-6] Vehicle 37 trained with time: 59.40497922897339
# [edge-2] Vehicle 36 trained with time: 60.0765643119812
# [edge-5] Vehicle 46 trained with time: 61.73669147491455
# [edge-5] Vehicle 42 trained with time: 63.159895181655884
# [edge-6] Vehicle 5 trained with time: 63.63039255142212
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-1] Vehicle 55 trained with time: 66.55514121055603[edge-1] Vehicle 16 trained with time: 66.55726361274719
#
# [edge-8] Vehicle 15 trained with time: 23.41009759902954
# [edge-3] Vehicle 29 trained with time: 68.56615328788757
# [edge-1] Vehicle 33 trained with time: 68.62393307685852
# [edge-5] Vehicle 35 trained with time: 74.13915014266968
# [edge-5] Training completed with 4 models.
# [edge-4] Vehicle 25 trained with time: 74.50783443450928
# [edge-3] Vehicle 4 trained with time: 75.82542133331299
# [edge-3] Vehicle 59 trained with time: 77.13278198242188
# [edge-3] Vehicle 41 trained with time: 78.86119270324707
# [edge-2] Vehicle 30 trained with time: 78.92597723007202
# [edge-2] Training completed with 4 models.
# [edge-8] Vehicle 14 trained with time: 37.21208095550537
# [edge-8] Vehicle 8 trained with time: 37.249855518341064
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 84.69663691520691
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 86.69058752059937
# [edge-1] Vehicle 19 trained with time: 89.12278199195862
# [edge-3] Vehicle 10 trained with time: 90.11881303787231
# [edge-9] Vehicle 40 trained with time: 28.31192421913147
# [edge-4] Vehicle 18 trained with time: 93.56410622596741
# [edge-4] Training completed with 4 models.
# [edge-3] Vehicle 21 trained with time: 97.27398800849915
# [edge-9] Vehicle 17 trained with time: 36.827285051345825
# [edge-3] Vehicle 50 trained with time: 102.95858097076416
# [edge-3] Training completed with 4 models.
# [edge-1] Vehicle 20 trained with time: 109.87366485595703
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 46.122496366500854
# [edge-9] Vehicle 7 trained with time: 46.35839509963989
# [edge-9] Vehicle 47 trained with time: 50.850366830825806
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 1 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.37324052862590074, Accuracy = 0.9113217716622808, Precision = 0.9632312863372093, Recall = 0.862315746670733, F1 = 0.9099842303442505, Total Time for  1= 121.11 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_1.pth
#
#   FL Global Training Round SFL2: 2
#
#
# Starting the training process for round 2 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...[SFL2] Launching training for edge edge-7 with cache size 4...
#
# [SFL2] Launching training for edge edge-5 with cache size 4...[SFL2] Launching training for edge edge-4 with cache size 4...
#
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 20.875328063964844
# [edge-6] Vehicle 57 trained with time: 23.375492334365845
# [edge-0] Vehicle 38 trained with time: 26.978545427322388
# [edge-0] Vehicle 54 trained with time: 27.168864250183105
# [edge-3] Vehicle 0 trained with time: 29.05717444419861
# [edge-6] Vehicle 27 trained with time: 33.111644983291626
# [edge-2] Vehicle 9 trained with time: 34.199318170547485
# [edge-0] Vehicle 11 trained with time: 37.284741163253784
# [edge-7] Vehicle 34 trained with time: 37.391088247299194
# [edge-3] Vehicle 24 trained with time: 37.85306787490845
# [edge-1] Vehicle 58 trained with time: 38.59310030937195
# [edge-5] Vehicle 12 trained with time: 38.76101303100586
# [edge-4] Vehicle 52 trained with time: 38.845879793167114
# [edge-4] Vehicle 26 trained with time: 39.559316635131836
# [edge-2] Vehicle 45 trained with time: 40.952229738235474
# [edge-4] Vehicle 44 trained with time: 41.263383626937866
# [edge-4] Vehicle 28 trained with time: 42.50759267807007
# [edge-0] Vehicle 23 trained with time: 44.19853234291077
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-7] Vehicle 51 trained with time: 44.35043740272522
# [edge-4] Vehicle 39 trained with time: 44.628108739852905
# [edge-5] Vehicle 13 trained with time: 46.087663650512695
# [edge-6] Vehicle 2 trained with time: 47.208834171295166
# [edge-7] Vehicle 56 trained with time: 49.47946238517761
# [edge-2] Vehicle 49 trained with time: 49.68332552909851
# [edge-5] Vehicle 48 trained with time: 51.80612063407898
# [edge-3] Vehicle 22 trained with time: 54.011985540390015
# [edge-7] Vehicle 6 trained with time: 54.186925172805786
# [edge-2] Vehicle 31 trained with time: 54.85963559150696
# [edge-5] Vehicle 32 trained with time: 55.125786542892456
# [edge-2] Vehicle 36 trained with time: 56.39196586608887
# [edge-6] Vehicle 37 trained with time: 57.83018779754639
# [edge-5] Vehicle 46 trained with time: 61.901522636413574
# [edge-6] Vehicle 5 trained with time: 62.20888423919678
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-5] Vehicle 42 trained with time: 63.73682498931885
# [edge-1] Vehicle 16 trained with time: 66.45601058006287
# [edge-8] Vehicle 15 trained with time: 23.26781463623047
# [edge-3] Vehicle 29 trained with time: 67.98271560668945
# [edge-1] Vehicle 55 trained with time: 69.02798056602478
# [edge-1] Vehicle 33 trained with time: 69.45910620689392
# [edge-5] Vehicle 35 trained with time: 71.23549199104309
# [edge-5] Training completed with 4 models.
# [edge-4] Vehicle 25 trained with time: 71.67409062385559
# [edge-3] Vehicle 4 trained with time: 76.71128559112549
# [edge-3] Vehicle 59 trained with time: 76.84058666229248
# [edge-3] Vehicle 41 trained with time: 77.2251045703888
# [edge-2] Vehicle 30 trained with time: 79.56517362594604
# [edge-2] Training completed with 4 models.
# [edge-8] Vehicle 8 trained with time: 36.58195471763611
# [edge-8] Vehicle 14 trained with time: 36.643017292022705
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 83.0524070262909
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 85.34442186355591
# [edge-1] Vehicle 19 trained with time: 89.06194114685059
# [edge-3] Vehicle 10 trained with time: 90.22969365119934
# [edge-9] Vehicle 40 trained with time: 27.941149473190308
# [edge-3] Vehicle 21 trained with time: 96.21675300598145
# [edge-4] Vehicle 18 trained with time: 96.19455051422119
# [edge-4] Training completed with 4 models.
# [edge-9] Vehicle 17 trained with time: 35.36141014099121
# [edge-3] Vehicle 50 trained with time: 100.72446417808533
# [edge-3] Training completed with 4 models.
# [edge-1] Vehicle 20 trained with time: 107.72284412384033
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 7 trained with time: 46.38177132606506
# [edge-9] Vehicle 1 trained with time: 46.710559129714966
# [edge-9] Vehicle 47 trained with time: 48.684706926345825
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 2 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.2604113257856464, Accuracy = 0.9221013918391935, Precision = 0.9602497871965716, Recall = 0.886848971569923, F1 = 0.922090962579845, Total Time for  2= 112.93 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_2.pth
#
#   FL Global Training Round SFL2: 3
#
#
# Starting the training process for round 3 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...[SFL2] Launching training for edge edge-6 with cache size 4...
#
# [SFL2] Launching training for edge edge-7 with cache size 4...
# [SFL2] Launching training for edge edge-4 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 20.965874910354614
# [edge-6] Vehicle 57 trained with time: 23.211763381958008
# [edge-0] Vehicle 38 trained with time: 27.814160346984863[edge-0] Vehicle 54 trained with time: 27.816853284835815
#
# [edge-3] Vehicle 0 trained with time: 28.520627975463867
# [edge-6] Vehicle 27 trained with time: 32.441932678222656
# [edge-2] Vehicle 9 trained with time: 33.59638166427612
# [edge-0] Vehicle 11 trained with time: 37.40623140335083
# [edge-4] Vehicle 52 trained with time: 37.580270528793335
# [edge-5] Vehicle 12 trained with time: 37.62537884712219
# [edge-7] Vehicle 34 trained with time: 37.78855228424072
# [edge-3] Vehicle 24 trained with time: 38.02391266822815
# [edge-4] Vehicle 26 trained with time: 38.656461000442505
# [edge-1] Vehicle 58 trained with time: 39.36292505264282
# [edge-2] Vehicle 45 trained with time: 40.22178292274475
# [edge-4] Vehicle 28 trained with time: 42.23341202735901
# [edge-4] Vehicle 44 trained with time: 43.511794567108154
# [edge-7] Vehicle 51 trained with time: 43.61892080307007
# [edge-0] Vehicle 23 trained with time: 43.954846143722534
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-4] Vehicle 39 trained with time: 44.09450960159302
# [edge-5] Vehicle 13 trained with time: 45.45738244056702
# [edge-6] Vehicle 2 trained with time: 48.23892378807068
# [edge-2] Vehicle 49 trained with time: 48.878018617630005
# [edge-7] Vehicle 56 trained with time: 49.31622791290283
# [edge-5] Vehicle 48 trained with time: 51.78426909446716
# [edge-2] Vehicle 31 trained with time: 52.6783230304718
# [edge-3] Vehicle 22 trained with time: 53.808271646499634
# [edge-7] Vehicle 6 trained with time: 55.575791358947754
# [edge-5] Vehicle 32 trained with time: 55.8564338684082
# [edge-2] Vehicle 36 trained with time: 56.1766037940979
# [edge-6] Vehicle 37 trained with time: 57.591432094573975
# [edge-5] Vehicle 46 trained with time: 60.31336307525635
# [edge-6] Vehicle 5 trained with time: 60.562572956085205
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-5] Vehicle 42 trained with time: 61.093825578689575
# [edge-1] Vehicle 55 trained with time: 64.2681040763855
# [edge-1] Vehicle 16 trained with time: 64.3990261554718
# [edge-1] Vehicle 33 trained with time: 64.64942932128906
# [edge-8] Vehicle 15 trained with time: 23.401053428649902
# [edge-3] Vehicle 29 trained with time: 67.73855519294739
# [edge-5] Vehicle 35 trained with time: 70.7155089378357
# [edge-5] Training completed with 4 models.
# [edge-4] Vehicle 25 trained with time: 70.85923290252686
# [edge-3] Vehicle 4 trained with time: 75.77020931243896
# [edge-3] Vehicle 59 trained with time: 76.52146530151367
# [edge-3] Vehicle 41 trained with time: 76.98853063583374
# [edge-2] Vehicle 30 trained with time: 77.3445794582367
# [edge-2] Training completed with 4 models.
# [edge-8] Vehicle 8 trained with time: 36.28626751899719
# [edge-8] Vehicle 14 trained with time: 36.28252840042114
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 83.3697099685669
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 83.80932712554932
# [edge-1] Vehicle 19 trained with time: 86.04461574554443
# [edge-3] Vehicle 10 trained with time: 88.32761836051941
# [edge-9] Vehicle 40 trained with time: 28.00345754623413
# [edge-3] Vehicle 21 trained with time: 94.673086643219
# [edge-4] Vehicle 18 trained with time: 95.70388793945312
# [edge-4] Training completed with 4 models.
# [edge-9] Vehicle 17 trained with time: 35.069659948349
# [edge-3] Vehicle 50 trained with time: 100.77714443206787
# [edge-3] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 45.656418561935425
# [edge-9] Vehicle 7 trained with time: 46.16599774360657
# [edge-1] Vehicle 20 trained with time: 108.3185203075409
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 47 trained with time: 48.398754358291626
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 3 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.2513327389170014, Accuracy = 0.9230384437892126, Precision = 0.9588955084399275, Recall = 0.8900952187319983, F1 = 0.9232153463867596, Total Time for  3= 111.11 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_3.pth
#
#   FL Global Training Round SFL2: 4
#
#
# Starting the training process for round 4 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...[SFL2] Launching training for edge edge-7 with cache size 4...
#
# [SFL2] Launching training for edge edge-4 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 20.90496277809143
# [edge-6] Vehicle 57 trained with time: 23.411184310913086
# [edge-0] Vehicle 38 trained with time: 25.952322483062744
# [edge-0] Vehicle 54 trained with time: 26.133845329284668
# [edge-3] Vehicle 0 trained with time: 28.807590007781982
# [edge-6] Vehicle 27 trained with time: 33.084197998046875
# [edge-2] Vehicle 9 trained with time: 33.866443395614624
# [edge-0] Vehicle 11 trained with time: 37.72304964065552
# [edge-4] Vehicle 52 trained with time: 37.77816033363342
# [edge-3] Vehicle 24 trained with time: 38.44890809059143
# [edge-7] Vehicle 34 trained with time: 38.57694888114929
# [edge-5] Vehicle 12 trained with time: 38.962488412857056[edge-4] Vehicle 26 trained with time: 38.9938805103302
#
# [edge-1] Vehicle 58 trained with time: 40.093088150024414
# [edge-2] Vehicle 45 trained with time: 40.41608166694641
# [edge-4] Vehicle 44 trained with time: 41.48137974739075
# [edge-4] Vehicle 28 trained with time: 41.82817840576172
# [edge-4] Vehicle 39 trained with time: 43.16707634925842
# [edge-0] Vehicle 23 trained with time: 44.819366216659546
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-7] Vehicle 51 trained with time: 44.885470390319824
# [edge-5] Vehicle 13 trained with time: 45.82750082015991
# [edge-6] Vehicle 2 trained with time: 46.2960102558136
# [edge-2] Vehicle 49 trained with time: 48.46964931488037
# [edge-7] Vehicle 56 trained with time: 50.20769190788269
# [edge-5] Vehicle 48 trained with time: 53.16162395477295
# [edge-2] Vehicle 31 trained with time: 53.40795159339905
# [edge-3] Vehicle 22 trained with time: 55.016602754592896
# [edge-7] Vehicle 6 trained with time: 55.955546855926514
# [edge-5] Vehicle 32 trained with time: 57.27454233169556
# [edge-2] Vehicle 36 trained with time: 57.95871925354004
# [edge-6] Vehicle 37 trained with time: 58.326735734939575
# [edge-6] Vehicle 5 trained with time: 62.804322719573975
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-5] Vehicle 46 trained with time: 63.14729952812195
# [edge-5] Vehicle 42 trained with time: 63.19333600997925
# [edge-1] Vehicle 16 trained with time: 66.54748106002808
# [edge-1] Vehicle 55 trained with time: 66.91149115562439
# [edge-8] Vehicle 15 trained with time: 23.43894600868225
# [edge-3] Vehicle 29 trained with time: 68.80440330505371
# [edge-1] Vehicle 33 trained with time: 69.38069796562195
# [edge-5] Vehicle 35 trained with time: 72.34001636505127
# [edge-5] Training completed with 4 models.
# [edge-4] Vehicle 25 trained with time: 72.49677610397339
# [edge-3] Vehicle 4 trained with time: 78.26442289352417[edge-3] Vehicle 59 trained with time: 78.26960253715515
#
# [edge-3] Vehicle 41 trained with time: 79.17415142059326
# [edge-2] Vehicle 30 trained with time: 80.467933177948
# [edge-2] Training completed with 4 models.
# [edge-8] Vehicle 8 trained with time: 37.52112936973572
# [edge-8] Vehicle 14 trained with time: 37.53304147720337
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 84.56791019439697
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 86.24193072319031
# [edge-1] Vehicle 19 trained with time: 88.18872594833374
# [edge-3] Vehicle 10 trained with time: 90.5748462677002
# [edge-9] Vehicle 40 trained with time: 28.349918842315674
# [edge-3] Vehicle 21 trained with time: 97.9015576839447
# [edge-4] Vehicle 18 trained with time: 97.99595761299133
# [edge-4] Training completed with 4 models.
# [edge-9] Vehicle 17 trained with time: 36.05044651031494
# [edge-3] Vehicle 50 trained with time: 104.2034318447113
# [edge-3] Training completed with 4 models.
# [edge-9] Vehicle 7 trained with time: 47.20499062538147
# [edge-9] Vehicle 1 trained with time: 47.63536262512207
# [edge-1] Vehicle 20 trained with time: 111.7613296508789
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 47 trained with time: 51.05202913284302
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 4 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.2502733516610659, Accuracy = 0.9240283370146088, Precision = 0.9577855777685729, Recall = 0.8932127003490224, F1 = 0.9243728126468463, Total Time for  4= 115.89 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_4.pth
#
#   FL Global Training Round SFL2: 5
#
#
# Starting the training process for round 5 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...[SFL2] Launching training for edge edge-7 with cache size 4...
#
# [SFL2] Launching training for edge edge-4 with cache size 4...[SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
#
# [edge-5] Vehicle 53 trained with time: 21.116928815841675
# [edge-6] Vehicle 57 trained with time: 23.268470525741577
# [edge-0] Vehicle 38 trained with time: 26.95459008216858
# [edge-0] Vehicle 54 trained with time: 26.97224736213684
# [edge-3] Vehicle 0 trained with time: 29.372597694396973
# [edge-6] Vehicle 27 trained with time: 32.52346348762512
# [edge-2] Vehicle 9 trained with time: 32.88901090621948
# [edge-0] Vehicle 11 trained with time: 37.96701383590698
# [edge-7] Vehicle 34 trained with time: 37.89431047439575
# [edge-3] Vehicle 24 trained with time: 38.06465744972229
# [edge-1] Vehicle 58 trained with time: 38.93767023086548
# [edge-4] Vehicle 52 trained with time: 38.51144027709961
# [edge-5] Vehicle 12 trained with time: 39.09768033027649
# [edge-4] Vehicle 26 trained with time: 39.44483494758606
# [edge-2] Vehicle 45 trained with time: 41.084312200546265
# [edge-4] Vehicle 28 trained with time: 42.431946992874146
# [edge-4] Vehicle 44 trained with time: 43.29427886009216
# [edge-0] Vehicle 23 trained with time: 44.85336685180664
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-7] Vehicle 51 trained with time: 44.808839559555054
# [edge-4] Vehicle 39 trained with time: 45.00122618675232
# [edge-5] Vehicle 13 trained with time: 46.18689441680908
# [edge-2] Vehicle 49 trained with time: 48.44670104980469
# [edge-6] Vehicle 2 trained with time: 48.550764322280884
# [edge-7] Vehicle 56 trained with time: 49.2146999835968
# [edge-5] Vehicle 48 trained with time: 51.00795865058899
# [edge-2] Vehicle 31 trained with time: 53.31968903541565
# [edge-3] Vehicle 22 trained with time: 53.26434016227722
# [edge-7] Vehicle 6 trained with time: 53.84852337837219
# [edge-5] Vehicle 32 trained with time: 56.122100830078125
# [edge-2] Vehicle 36 trained with time: 57.43132162094116
# [edge-6] Vehicle 37 trained with time: 58.518805503845215
# [edge-5] Vehicle 46 trained with time: 60.041648626327515
# [edge-5] Vehicle 42 trained with time: 60.236377000808716
# [edge-6] Vehicle 5 trained with time: 63.05410361289978
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-1] Vehicle 16 trained with time: 63.63456845283508
# [edge-1] Vehicle 55 trained with time: 64.71940159797668
# [edge-1] Vehicle 33 trained with time: 65.48324394226074
# [edge-3] Vehicle 29 trained with time: 67.6955337524414
# [edge-8] Vehicle 15 trained with time: 23.527090787887573
# [edge-4] Vehicle 25 trained with time: 69.75242328643799
# [edge-3] Vehicle 59 trained with time: 74.98519158363342
# [edge-3] Vehicle 4 trained with time: 75.44279718399048
# [edge-3] Vehicle 41 trained with time: 77.76373600959778
# [edge-8] Vehicle 8 trained with time: 37.2684371471405
# [edge-8] Vehicle 14 trained with time: 37.28256416320801
# [edge-8] Training completed with 3 models.
# [edge-2] Vehicle 30 trained with time: 82.144855260849
# [edge-2] Training completed with 4 models.
# [edge-5] Vehicle 35 trained with time: 83.04293942451477
# [edge-5] Training completed with 4 models.
# [edge-7] Vehicle 43 trained with time: 84.86968612670898
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 85.5759060382843
# [edge-1] Vehicle 19 trained with time: 88.62957668304443
# [edge-3] Vehicle 10 trained with time: 90.27954697608948
# [edge-9] Vehicle 40 trained with time: 29.02684211730957
# [edge-3] Vehicle 21 trained with time: 96.61763715744019
# [edge-9] Vehicle 17 trained with time: 37.122153520584106
# [edge-3] Vehicle 50 trained with time: 105.58457660675049
# [edge-3] Training completed with 4 models.
# [edge-4] Vehicle 18 trained with time: 106.1041989326477
# [edge-4] Training completed with 4 models.
# [edge-9] Vehicle 7 trained with time: 46.81765675544739
# [edge-9] Vehicle 1 trained with time: 47.13360929489136
# [edge-1] Vehicle 20 trained with time: 114.62090015411377
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 47 trained with time: 51.69290256500244
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 5 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.25053054192775864, Accuracy = 0.9255607340005425, Precision = 0.9576334993629098, Recall = 0.8964521703771475, F1 = 0.9260334006573719, Total Time for  5= 116.98 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_5.pth
#
#   FL Global Training Round SFL2: 6
#
#
# Starting the training process for round 6 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...
# [SFL2] Launching training for edge edge-7 with cache size 4...
# [SFL2] Launching training for edge edge-4 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 21.126855850219727
# [edge-6] Vehicle 57 trained with time: 23.364851236343384
# [edge-0] Vehicle 38 trained with time: 27.099106073379517
# [edge-0] Vehicle 54 trained with time: 27.15654969215393
# [edge-3] Vehicle 0 trained with time: 28.723012447357178
# [edge-2] Vehicle 9 trained with time: 32.315667152404785
# [edge-6] Vehicle 27 trained with time: 33.67756533622742
# [edge-0] Vehicle 11 trained with time: 36.65347981452942
# [edge-7] Vehicle 34 trained with time: 36.90557670593262
# [edge-3] Vehicle 24 trained with time: 37.7805712223053
# [edge-5] Vehicle 12 trained with time: 38.3360435962677
# [edge-4] Vehicle 52 trained with time: 38.95929503440857
# [edge-4] Vehicle 26 trained with time: 39.342451333999634
# [edge-1] Vehicle 58 trained with time: 39.507869720458984
# [edge-2] Vehicle 45 trained with time: 41.04040503501892
# [edge-4] Vehicle 28 trained with time: 41.22652578353882
# [edge-4] Vehicle 44 trained with time: 42.72854232788086
# [edge-0] Vehicle 23 trained with time: 44.36275005340576
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-4] Vehicle 39 trained with time: 44.528379917144775
# [edge-7] Vehicle 51 trained with time: 44.497278451919556
# [edge-5] Vehicle 13 trained with time: 45.1191930770874
# [edge-6] Vehicle 2 trained with time: 47.3670654296875
# [edge-2] Vehicle 49 trained with time: 48.42599844932556
# [edge-7] Vehicle 56 trained with time: 49.47866153717041
# [edge-5] Vehicle 48 trained with time: 51.38150095939636
# [edge-3] Vehicle 22 trained with time: 52.988121032714844
# [edge-2] Vehicle 31 trained with time: 54.01029682159424
# [edge-5] Vehicle 32 trained with time: 55.613423109054565
# [edge-7] Vehicle 6 trained with time: 55.740784883499146
# [edge-2] Vehicle 36 trained with time: 56.68427848815918
# [edge-6] Vehicle 37 trained with time: 59.51795196533203
# [edge-5] Vehicle 46 trained with time: 61.216365337371826
# [edge-1] Vehicle 16 trained with time: 62.088900327682495
# [edge-5] Vehicle 42 trained with time: 62.560163736343384
# [edge-6] Vehicle 5 trained with time: 63.008333921432495
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-1] Vehicle 55 trained with time: 63.835062980651855
# [edge-1] Vehicle 33 trained with time: 65.77906227111816
# [edge-3] Vehicle 29 trained with time: 65.88649415969849
# [edge-8] Vehicle 15 trained with time: 23.216680765151978
# [edge-5] Vehicle 35 trained with time: 69.46596956253052
# [edge-5] Training completed with 4 models.
# [edge-4] Vehicle 25 trained with time: 70.20391941070557
# [edge-3] Vehicle 59 trained with time: 75.33874726295471
# [edge-3] Vehicle 4 trained with time: 75.6303493976593
# [edge-3] Vehicle 41 trained with time: 76.33618783950806
# [edge-2] Vehicle 30 trained with time: 77.64712285995483
# [edge-2] Training completed with 4 models.
# [edge-8] Vehicle 14 trained with time: 36.4149432182312
# [edge-8] Vehicle 8 trained with time: 36.480302572250366
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 82.5065381526947
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 85.2060079574585
# [edge-1] Vehicle 19 trained with time: 86.03036332130432
# [edge-3] Vehicle 10 trained with time: 89.91713070869446
# [edge-9] Vehicle 40 trained with time: 28.380475282669067
# [edge-4] Vehicle 18 trained with time: 92.49240064620972
# [edge-4] Training completed with 4 models.
# [edge-3] Vehicle 21 trained with time: 95.38947701454163
# [edge-9] Vehicle 17 trained with time: 36.270514249801636
# [edge-3] Vehicle 50 trained with time: 100.01644492149353
# [edge-3] Training completed with 4 models.
# [edge-1] Vehicle 20 trained with time: 107.02248549461365
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 45.65939950942993
# [edge-9] Vehicle 7 trained with time: 45.76464295387268
# [edge-9] Vehicle 47 trained with time: 48.52320218086243
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 6 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.2498342941743286, Accuracy = 0.9248315244003396, Precision = 0.9602663496532058, Recall = 0.8923113415336654, F1 = 0.9250425056557112, Total Time for  6= 113.61 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_6.pth
#
#   FL Global Training Round SFL2: 7
#
#
# Starting the training process for round 7 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...
# [SFL2] Launching training for edge edge-7 with cache size 4...
# [SFL2] Launching training for edge edge-4 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 21.048253536224365
# [edge-6] Vehicle 57 trained with time: 23.380150079727173
# [edge-0] Vehicle 38 trained with time: 26.043713808059692
# [edge-0] Vehicle 54 trained with time: 26.644747734069824
# [edge-3] Vehicle 0 trained with time: 28.5711727142334
# [edge-2] Vehicle 9 trained with time: 32.49175453186035
# [edge-6] Vehicle 27 trained with time: 33.250523805618286
# [edge-7] Vehicle 34 trained with time: 37.37898278236389
# [edge-0] Vehicle 11 trained with time: 37.98325514793396
# [edge-3] Vehicle 24 trained with time: 37.90945029258728
# [edge-4] Vehicle 52 trained with time: 38.41849946975708
# [edge-1] Vehicle 58 trained with time: 38.619868993759155
# [edge-5] Vehicle 12 trained with time: 38.68040728569031
# [edge-4] Vehicle 26 trained with time: 39.53414034843445
# [edge-2] Vehicle 45 trained with time: 39.88159728050232
# [edge-4] Vehicle 28 trained with time: 41.626665115356445
# [edge-4] Vehicle 44 trained with time: 42.865071296691895
# [edge-0] Vehicle 23 trained with time: 43.7620894908905
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-4] Vehicle 39 trained with time: 44.910380125045776
# [edge-7] Vehicle 51 trained with time: 45.30576133728027
# [edge-5] Vehicle 13 trained with time: 45.61986708641052
# [edge-6] Vehicle 2 trained with time: 47.75479078292847
# [edge-2] Vehicle 49 trained with time: 48.59300255775452
# [edge-7] Vehicle 56 trained with time: 49.87915754318237
# [edge-2] Vehicle 31 trained with time: 52.896429777145386
# [edge-5] Vehicle 48 trained with time: 53.230877161026
# [edge-3] Vehicle 22 trained with time: 53.23088359832764
# [edge-7] Vehicle 6 trained with time: 54.21179008483887
# [edge-5] Vehicle 32 trained with time: 56.4750337600708
# [edge-2] Vehicle 36 trained with time: 56.63576602935791
# [edge-6] Vehicle 37 trained with time: 57.68851852416992
# [edge-5] Vehicle 46 trained with time: 60.77907419204712
# [edge-5] Vehicle 42 trained with time: 62.13383603096008
# [edge-6] Vehicle 5 trained with time: 62.69485807418823
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-1] Vehicle 16 trained with time: 62.88299560546875
# [edge-1] Vehicle 55 trained with time: 64.97360420227051
# [edge-1] Vehicle 33 trained with time: 67.10487151145935
# [edge-8] Vehicle 15 trained with time: 23.43902015686035
# [edge-3] Vehicle 29 trained with time: 67.81505727767944
# [edge-4] Vehicle 25 trained with time: 69.9184958934784
# [edge-5] Vehicle 35 trained with time: 75.96380710601807
# [edge-5] Training completed with 4 models.
# [edge-3] Vehicle 4 trained with time: 76.35128116607666
# [edge-3] Vehicle 59 trained with time: 76.62106370925903
# [edge-3] Vehicle 41 trained with time: 77.33990955352783
# [edge-8] Vehicle 14 trained with time: 37.58889818191528
# [edge-8] Vehicle 8 trained with time: 37.7494101524353
# [edge-8] Training completed with 3 models.
# [edge-3] Vehicle 3 trained with time: 85.34994721412659
# [edge-2] Vehicle 30 trained with time: 85.59880375862122
# [edge-2] Training completed with 4 models.
# [edge-7] Vehicle 43 trained with time: 85.75337529182434
# [edge-7] Training completed with 4 models.
# [edge-1] Vehicle 19 trained with time: 87.98065972328186
# [edge-3] Vehicle 10 trained with time: 90.55711460113525
# [edge-9] Vehicle 40 trained with time: 28.36378526687622
# [edge-3] Vehicle 21 trained with time: 97.34896731376648
# [edge-9] Vehicle 17 trained with time: 37.09725522994995
# [edge-4] Vehicle 18 trained with time: 105.67696070671082
# [edge-4] Training completed with 4 models.
# [edge-3] Vehicle 50 trained with time: 106.76119136810303
# [edge-3] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 45.50089478492737
# [edge-9] Vehicle 7 trained with time: 46.3283474445343
# [edge-9] Vehicle 47 trained with time: 51.87347054481506
# [edge-9] Training completed with 4 models.
# [edge-1] Vehicle 20 trained with time: 115.13420796394348
# [edge-1] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 7 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# ...
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 8 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.24761023146043148, Accuracy = 0.9237676533894156, Precision = 0.9612102120801436, Recall = 0.8892277455863915, F1 = 0.9238189114975709, Total Time for  8= 116.43 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_8.pth
#
#   FL Global Training Round SFL2: 9
#
#
# Starting the training process for round 9 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...[SFL2] Launching training for edge edge-7 with cache size 4...
#
# [SFL2] Launching training for edge edge-4 with cache size 4...
# [SFL2] Launching training for edge edge-5 with cache size 4...
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 21.071197509765625
# [edge-6] Vehicle 57 trained with time: 23.308064222335815
# [edge-0] Vehicle 54 trained with time: 27.75268864631653[edge-0] Vehicle 38 trained with time: 27.767497777938843
#
# [edge-3] Vehicle 0 trained with time: 29.018248796463013
# [edge-6] Vehicle 27 trained with time: 33.21604108810425
# [edge-2] Vehicle 9 trained with time: 34.02857518196106
# [edge-7] Vehicle 34 trained with time: 37.37162685394287
# [edge-0] Vehicle 11 trained with time: 37.704352617263794
# [edge-3] Vehicle 24 trained with time: 38.00329232215881
# [edge-4] Vehicle 52 trained with time: 38.894333600997925
# [edge-5] Vehicle 12 trained with time: 39.27143669128418
# [edge-4] Vehicle 26 trained with time: 39.418986320495605
# [edge-1] Vehicle 58 trained with time: 39.97032594680786
# [edge-2] Vehicle 45 trained with time: 40.89857721328735
# [edge-4] Vehicle 44 trained with time: 42.69492173194885
# [edge-4] Vehicle 28 trained with time: 42.86195421218872
# [edge-4] Vehicle 39 trained with time: 43.21156907081604
# [edge-7] Vehicle 51 trained with time: 44.294610023498535
# [edge-0] Vehicle 23 trained with time: 44.98981308937073
# [edge-0] Training completed with 4 models.
# [SFL2] Launching training for edge edge-8 with cache size 4...
# [edge-5] Vehicle 13 trained with time: 45.498713970184326
# [edge-6] Vehicle 2 trained with time: 48.854496479034424[edge-2] Vehicle 49 trained with time: 48.84183430671692
#
# [edge-7] Vehicle 56 trained with time: 49.22851634025574
# [edge-5] Vehicle 48 trained with time: 52.08138132095337
# [edge-2] Vehicle 31 trained with time: 52.63451528549194
# [edge-3] Vehicle 22 trained with time: 53.498650312423706
# [edge-7] Vehicle 6 trained with time: 54.37431573867798
# [edge-2] Vehicle 36 trained with time: 56.071776151657104
# [edge-5] Vehicle 32 trained with time: 56.328550577163696
# [edge-6] Vehicle 37 trained with time: 59.26889133453369
# [edge-6] Vehicle 5 trained with time: 62.09428834915161
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-5] Vehicle 46 trained with time: 62.23821759223938
# [edge-5] Vehicle 42 trained with time: 62.44071674346924
# [edge-1] Vehicle 55 trained with time: 66.80521368980408
# [edge-1] Vehicle 16 trained with time: 66.82965636253357
# [edge-3] Vehicle 29 trained with time: 67.29584574699402
# [edge-8] Vehicle 15 trained with time: 23.462172508239746
# [edge-5] Vehicle 35 trained with time: 68.69217133522034
# [edge-5] Training completed with 4 models.
# [edge-1] Vehicle 33 trained with time: 69.0978856086731
# [edge-4] Vehicle 25 trained with time: 72.10215401649475
# [edge-3] Vehicle 4 trained with time: 74.37396454811096
# [edge-3] Vehicle 59 trained with time: 76.11705231666565
# [edge-2] Vehicle 30 trained with time: 76.65937995910645
# [edge-2] Training completed with 4 models.
# [edge-3] Vehicle 41 trained with time: 78.21230864524841
# [edge-8] Vehicle 8 trained with time: 36.623694896698
# [edge-8] Vehicle 14 trained with time: 36.62167930603027
# [edge-8] Training completed with 3 models.
# [edge-7] Vehicle 43 trained with time: 82.24698305130005
# [edge-7] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 84.63843750953674
# [edge-1] Vehicle 19 trained with time: 88.05835151672363
# [edge-3] Vehicle 10 trained with time: 89.83141946792603
# [edge-9] Vehicle 40 trained with time: 28.35528564453125
# [edge-4] Vehicle 18 trained with time: 94.18148159980774
# [edge-4] Training completed with 4 models.
# [edge-3] Vehicle 21 trained with time: 95.54488778114319
# [edge-9] Vehicle 17 trained with time: 35.784971475601196
# [edge-3] Vehicle 50 trained with time: 102.79797172546387
# [edge-3] Training completed with 4 models.
# [edge-9] Vehicle 7 trained with time: 46.311588764190674
# [edge-1] Vehicle 20 trained with time: 109.06857991218567
# [edge-1] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 46.87788224220276
# [edge-9] Vehicle 47 trained with time: 50.48332190513611
# [edge-9] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 9 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.25172370583376147, Accuracy = 0.9238557221817105, Precision = 0.9603877873311107, Recall = 0.8902307614109993, F1 = 0.9239794464901823, Total Time for  9= 114.57 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_9.pth
#
#   FL Global Training Round SFL2: 10
#
#
# Starting the training process for round 10 on edge servers...
#
# [SFL2] Launching training for edge edge-0 with cache size 4...
# [SFL2] Launching training for edge edge-1 with cache size 4...
# [SFL2] Launching training for edge edge-2 with cache size 4...
# [SFL2] Launching training for edge edge-6 with cache size 4...[SFL2] Launching training for edge edge-7 with cache size 4...
#
# [SFL2] Launching training for edge edge-4 with cache size 4...[SFL2] Launching training for edge edge-5 with cache size 4...
#
# [SFL2] Launching training for edge edge-3 with cache size 4...
# [edge-5] Vehicle 53 trained with time: 21.025827646255493
# [edge-6] Vehicle 57 trained with time: 23.109037399291992
# [edge-0] Vehicle 38 trained with time: 26.478597402572632
# [edge-0] Vehicle 54 trained with time: 26.675132751464844
# [edge-3] Vehicle 0 trained with time: 28.822143077850342
# [edge-2] Vehicle 9 trained with time: 33.139023542404175
# [edge-6] Vehicle 27 trained with time: 33.269720792770386
# [edge-7] Vehicle 34 trained with time: 37.26246166229248
# [edge-0] Vehicle 11 trained with time: 37.292986154556274
# [edge-3] Vehicle 24 trained with time: 38.16690492630005
# [edge-5] Vehicle 12 trained with time: 38.3605010509491
# [edge-4] Vehicle 52 trained with time: 38.922088623046875
# [edge-1] Vehicle 58 trained with time: 38.959171295166016
# [edge-4] Vehicle 26 trained with time: 40.29862952232361
# [edge-2] Vehicle 45 trained with time: 41.86390233039856
# [edge-4] Vehicle 44 trained with time: 42.6344997882843[edge-4] Vehicle 28 trained with time: 42.631081342697144
#
# [edge-0] Vehicle 23 trained with time: 43.71428346633911
# [edge-0] Training completed with 4 models.
# [edge-4] Vehicle 39 trained with time: 43.8657112121582[SFL2] Launching training for edge edge-8 with cache size 4...
#
# [edge-5] Vehicle 13 trained with time: 45.90533900260925
# [edge-7] Vehicle 51 trained with time: 46.174877405166626
# [edge-6] Vehicle 2 trained with time: 48.97249102592468
# [edge-2] Vehicle 49 trained with time: 49.1117479801178
# [edge-7] Vehicle 56 trained with time: 50.796109199523926
# [edge-5] Vehicle 48 trained with time: 52.44644832611084
# [edge-3] Vehicle 22 trained with time: 54.234824657440186
# [edge-2] Vehicle 31 trained with time: 55.23051595687866
# [edge-7] Vehicle 6 trained with time: 56.524458169937134
# [edge-5] Vehicle 32 trained with time: 56.599008560180664
# [edge-2] Vehicle 36 trained with time: 57.983402729034424
# [edge-6] Vehicle 37 trained with time: 58.1451256275177
# [edge-5] Vehicle 46 trained with time: 61.27900052070618
# [edge-6] Vehicle 5 trained with time: 61.95476150512695
# [edge-6] Training completed with 4 models.
# [SFL2] Launching training for edge edge-9 with cache size 4...
# [edge-5] Vehicle 42 trained with time: 62.24369168281555
# [edge-1] Vehicle 16 trained with time: 62.892874240875244
# [edge-1] Vehicle 55 trained with time: 65.0072329044342
# [edge-1] Vehicle 33 trained with time: 65.9979043006897
# [edge-8] Vehicle 15 trained with time: 23.459556579589844
# [edge-3] Vehicle 29 trained with time: 67.37100577354431
# [edge-4] Vehicle 25 trained with time: 70.58605575561523
# [edge-3] Vehicle 4 trained with time: 74.6065936088562
# [edge-5] Vehicle 35 trained with time: 75.11915493011475
# [edge-5] Training completed with 4 models.
# [edge-3] Vehicle 59 trained with time: 76.46954870223999
# [edge-3] Vehicle 41 trained with time: 78.90354871749878
# [edge-8] Vehicle 14 trained with time: 37.13228249549866[edge-8] Vehicle 8 trained with time: 37.16114020347595
#
# [edge-8] Training completed with 3 models.
# [edge-2] Vehicle 30 trained with time: 83.2519199848175
# [edge-2] Training completed with 4 models.
# [edge-3] Vehicle 3 trained with time: 85.04747581481934
# [edge-7] Vehicle 43 trained with time: 86.5777862071991
# [edge-7] Training completed with 4 models.
# [edge-1] Vehicle 19 trained with time: 88.06603670120239
# [edge-3] Vehicle 10 trained with time: 90.42274403572083
# [edge-9] Vehicle 40 trained with time: 29.062453031539917
# [edge-3] Vehicle 21 trained with time: 96.60268497467041
# [edge-9] Vehicle 17 trained with time: 36.12030625343323
# [edge-4] Vehicle 18 trained with time: 101.91121816635132
# [edge-4] Training completed with 4 models.
# [edge-3] Vehicle 50 trained with time: 105.64186096191406
# [edge-3] Training completed with 4 models.
# [edge-9] Vehicle 1 trained with time: 48.42393493652344
# [edge-9] Vehicle 7 trained with time: 48.46070647239685
# [edge-9] Vehicle 47 trained with time: 49.70546889305115
# [edge-9] Training completed with 4 models.
# [edge-1] Vehicle 20 trained with time: 113.42912459373474
# [edge-1] Training completed with 4 models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-0] Parameters set.
# [edge-0] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-1] Parameters set.
# [edge-1] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-2] Parameters set.
# [edge-2] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-3] Parameters set.
# [edge-3] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-4] Parameters set.
# [edge-4] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-5] Parameters set.
# [edge-5] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-6] Parameters set.
# [edge-6] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-7] Parameters set.
# [edge-7] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-8] Parameters set.
# [edge-8] Aggregated 3 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [edge-9] Parameters set.
# [edge-9] Aggregated 4 local models.
# [weighted_aggregation] Weighted aggregation completed.
# [set_parameters] Parameters set to the model.
# [Cloud] Aggregated 4 sub-global models.
# [update_edge_servers] Updating edge servers with global parameters...
# [edge-0] Parameters set.
# [edge-1] Parameters set.
# [edge-2] Parameters set.
# [edge-3] Parameters set.
# [edge-4] Parameters set.
# [edge-5] Parameters set.
# [edge-6] Parameters set.
# [edge-7] Parameters set.
# [edge-8] Parameters set.
# [edge-9] Parameters set.
# [update_edge_servers] Edge servers updated.
#
# [SFL2] Round 10 summary:
# Edge edge-0 trained 4/4 vehicles.
# Edge edge-1 trained 4/6 vehicles.
# Edge edge-2 trained 4/6 vehicles.
# Edge edge-3 trained 4/11 vehicles.
# Edge edge-4 trained 4/7 vehicles.
# Edge edge-5 trained 4/8 vehicles.
# Edge edge-6 trained 4/5 vehicles.
# Edge edge-7 trained 4/5 vehicles.
# Edge edge-8 trained 3/3 vehicles.
# Edge edge-9 trained 4/5 vehicles.
# Loss = 0.24784443517121585, Accuracy = 0.9237676533894156, Precision = 0.9590244613758157, Recall = 0.8914303141201586, F1 = 0.9239928348143726, Total Time for  10= 115.43 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_10.pth
# Total training time for all rounds by end and start time by SFL2: 1155.10 seconds
# Total training time for all rounds: 1155.10 seconds
# Final model results: Loss = 0.24784443517121585, Accuracy = 0.9237676533894156, Precision = 0.9590244613758157, Recall = 0.8914303141201586, F1 = 0.9239928348143726
# Confusion Matrix:
# [[130694   5620]
#  [ 16020 131535]]
# Testing Time: 4.97 seconds
# Model saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/model_checkpoint/SFL2/model_SFL2_round_10.pth
# Training results saved to /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/results/SFL2_results.csv
# LIME explanation plot saved to /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/lime_resultslime_explanation_SFL2.png
# Total time taken for Lime Explanation: 1.62 seconds
# SHAP summary plot saved as /content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/shap_results/shap_summary_SFL2.png
# Total time taken for Shap Explanation: 1018.04 seconds

# %%
method_name="SFL2"
results_path = f"/content/drive/MyDrive/car_hacking_results/SFL2-debugging_exp2-13-02-2025/results"
plot_path = f"{results_path}_{method_name}.png"

df_plot = results[pd.to_numeric(results['Round'], errors='coerce').notnull()]
# Plotting the training and test loss per round
plt.figure(figsize=(10, 6))
plt.plot(df_plot['Round'], df_plot['Train_Loss'], label="Training Loss", marker='o')
plt.plot(df_plot['Round'], df_plot['Test_loss'], label="Testing Loss", marker='o')
plt.xlabel("FL Training Round")
plt.ylabel("Loss")
plt.title("Training and Testing Loss per Federated Learning Round")
plt.xticks(df_plot['Round'].astype(int))  # Display only the round numbers on the x-axis
plt.legend()
plt.grid(True)

# Save the plot
plot_path = f"{results_path}/{method_name}.png"
plt.savefig(plot_path, bbox_inches='tight')
plt.show()
